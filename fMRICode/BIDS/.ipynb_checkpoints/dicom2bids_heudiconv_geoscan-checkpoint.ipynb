# %% [markdown]
# # DICOM-to-BIDS conversion using `heudiconv` and `singularity`
#
# * This notebook walks through the steps for doing DICOM to BIDS conversion using `heudiconv` with the Singularity image for a single participant to identify the correct parameters
#
#
# * For a new project the initial configuration steps will need to be completed to create the `heuristic.py` file. But this only needs to be done once and then it should be straight forward to run new participants.
#
# * There is a tutorial on using heudiconv:
#     - http://reproducibility.stanford.edu/bids-tutorial-series-part-2a/
#
#   that was used as a basis for this but required some tweaks.
#
#
# #### HISTORY
#
# * 9/9/21 dcosme - separated into two notebooks; this notebooks is to identify the parameters, the other creates jobs for each participant to convert
# * 4/1/20 mbod - initial setup for MURI DICOMS

# %% [markdown]
# ## Location of files
#
# 1. DICOMS for UPenn data are in:
#     ```
#     /fmriDataRaw/fmri_data_raw/{project}/
#
#     ```
#
#     * DICOMS (`.dcm` files) should match:
#     ```
#     /fmriDataRaw/fmri_data_raw/{project}/{subject}/{scan}/*.dcm
#     ```
#
#
# 2. BIDS files should be in  (may need to create these directories)
#     ```
#     /data00/projects/{project}/data/bids_data
#     ```
#
# 3. Config files for `heudiconv` will be in
#     ```
#     /data00/projects/{project}/scripts/BIDS/heudiconv
#     ```

# %%
raw_directory = '/fmriDataRaw/fmri_data_raw/geoscan_R01'
# !ls $raw_directory
# Out:
# GS004-T2  GS008  GS017_t2  GS020     GS022_t3  GS024_t3  GS025_t3  GS028  GS032
# GS005	  GS016  GS017_t3  GS022_t2  GS024_t2  GS025_t2  GS026	   GS031

# %%
bids_directory = '/data00/projects/geoscan_v2/data/bids_data'
# !ls  $bids_directory
# Out:
# CHANGES			  README     sub-GS022		   task-rest_bold.json
# dataset_description.json  sub-GS005  sub-GS024
# participants.json	  sub-GS008  sub-GS025
# participants.tsv	  sub-GS017  task-image_bold.json

# %% [markdown]
# ### Setup

# %%
import pandas as pd

# %% [markdown]
# ## Create the configuration files for a new project
#
# * For a new project you need to run `heudiconv` in heuristic mode once on a representative participant (i.e. has all the possible scans for a subject in study) and it will generate:
#     - a TSV file called `dicominfo.tsv` that contains the details of each of the scans in the dataset
#     - a Python template file called `heuristic.py` that you edit to setup the dicom volumes to NIFTI mapping
#
#
# * To run `heudiconv` in heuristic mode with Singularity image, edit the cell below using the correct paths for your directory (replace {Project Name}). Use:
#     ```
#     !singularity run --cleanenv \
#         -B /data00/projects/{Project Name}/data/bids_data:/base  \
#         -B /fmriDataRaw/fmri_data_raw:/raw \
#         /data00/tools/singularity_images/heudiconv_0.8.0 \
#         -d /raw/{Project Name}/{subject}/*/*.dcm \
#         -o heudiconv/ -f convertall -s {subject} -c none --overwrite
#     ```
#      where
#      * `-B /data00/BIDS:/base` makes a file mapping for singularity to where the data should be written (i.e. `/data00/BIDS/{project...}`)
#      * `-B /fmriDataRaw/fmri_data_raw:/raw` maps the DICOM directory to singularity location `/raw`
#      * `/data00/tools/singularity_images/heudiconv_0.8.0` is the path to the `heudiconv` Singularity image you want to use. (On 4/22/20 that is version 0.8.0 - but this will change and we try to keep an updated version)
#      * `-d /raw/{Project Name}/{subject}/*/*.dcm` is the file matching template for finding DICOM files. Here `/raw` maps to `/fmriDataRaw/fmri_data_raw` so we are looking for files that end with `.dcm` in `/fmriDataRaw/fmri_data_raw/{Project Name}/{subject}/*/*.dcm` - where subject will be specified with the -s param, e.g. `MURI155`
#      * `-o /base/{Project Name}/heudiconv/` is the location for output files from `heudiconv` to be written
#      * `-f convertall` means include all dicom files and scans (i.e. not just one type like anatomical or ignore localizers etc)
#      * `-c none` puts it into heuristic mode. This option specifies which tool to use to do dicom2nifti conversion and will be changed once the configuration is set up.

# %%
sub = "GS025"

# !singularity run --cleanenv \
    -B /data00/projects/geoscan_v2/data/bids_data:/base  \
    -B /fmriDataRaw/fmri_data_raw:/raw \
    /data00/tools/singularity_images/heudiconv_0.8.0 \
    -d /raw/geoscan_R01/{subject}_t2/*/*.dcm \
    -o heudiconv/ -ss t2 -f convertall -s 'GS025' -c none --overwrite
# Out:
# INFO: Running heudiconv version 0.8.0 latest 0.11.3
# INFO: Need to process 1 study sessions
# INFO: PROCESSING STARTS: {'subject': 'GS025', 'outdir': '/fmriNASTest/data00/projects/geoscan_v2/scripts/BIDS/heudiconv/', 'session': 't2'}
# INFO: Processing 1179 dicoms
# INFO: Analyzing 1179 dicoms
# INFO: Generated sequence info for 17 studies with 1164 entries total
# INFO: PROCESSING DONE: {'subject': 'GS025', 'outdir': '/fmriNASTest/data00/projects/geoscan_v2/scripts/BIDS/heudiconv/', 'session': 't2'}

# %% [markdown]
# * The output from this run is in a hidden folder called .heudiconv

# %%
# !ls -a heudiconv/.heudiconv/GS025/info
#more heudiconv/code/heuristic.py
# Out:
# .		      filegroup_ses-t2.json  GS025_ses-t3.auto.txt
# ..		      filegroup_ses-t3.json  GS025_ses-t3.edit.txt
# dicominfo_ses-t2.tsv  GS025_ses-t2.auto.txt  heuristic.py
# dicominfo_ses-t3.tsv  GS025_ses-t2.edit.txt

# %% [markdown]
# * We can look at the `dicominfo.tsv` in Pandas

# %%
scan_df=pd.read_csv('heudiconv/.heudiconv/{sub}/info/dicominfo_ses-t2.tsv'.format(sub=sub), sep='\t')
scan_df
# Out:
#     total_files_till_now                                   example_dcm_file  \
# 0                      9  1.3.12.2.1107.5.2.43.66044.2021120118233350460...
# 1                    137  1.3.12.2.1107.5.2.43.66044.2021120118242911163...
# 2                    142  1.3.12.2.1107.5.2.43.66044.2021120118243264539...
# 3                    145  1.3.12.2.1107.5.2.43.66044.2021120118243264659...
# 4                    148  1.3.12.2.1107.5.2.43.66044.2021120118243264729...
# 5                    280  1.3.12.2.1107.5.2.43.66044.2021120118274430061...
# 6                    284  1.3.12.2.1107.5.2.43.66044.2021120118342991498...
# 7                    416  1.3.12.2.1107.5.2.43.66044.2021120118354376532...
# 8                    420  1.3.12.2.1107.5.2.43.66044.2021120118422846619...
# 9                    552  1.3.12.2.1107.5.2.43.66044.2021120118434340833...
# 10                   556  1.3.12.2.1107.5.2.43.66044.2021120118502814311...
# 11                   688  1.3.12.2.1107.5.2.43.66044.2021120118522090043...
# 12                   692  1.3.12.2.1107.5.2.43.66044.2021120118590557249...
# 13                   824  1.3.12.2.1107.5.2.43.66044.2021120119012885809...
# 14                   828  1.3.12.2.1107.5.2.43.66044.2021120119081360259...
# 15                  1004  1.3.12.2.1107.5.2.43.66044.2021120119134843519...
# 16                  1164  1.3.12.2.1107.5.2.43.66044.2021120119173110395...
#
#                  series_id                                       dcm_dir_name  \
# 0   1-localizer_multislice  1.3.12.2.1107.5.2.43.66044.2021120118232768356...
# 1           2-AAHead_Scout  1.3.12.2.1107.5.2.43.66044.2021120118242921346...
# 2           3-AAHead_Scout  1.3.12.2.1107.5.2.43.66044.2021120118243262381...
# 3           4-AAHead_Scout  1.3.12.2.1107.5.2.43.66044.2021120118243262429...
# 4           5-AAHead_Scout  1.3.12.2.1107.5.2.43.66044.2021120118243262452...
# 5       6-BOLD_IMAGE_run01  1.3.12.2.1107.5.2.43.66044.2021120118260579495...
# 6            7-FieldMap_PA  1.3.12.2.1107.5.2.43.66044.2021120118341985854...
# 7       8-BOLD_IMAGE_run02  1.3.12.2.1107.5.2.43.66044.2021120118344063819...
# 8            9-FieldMap_PA  1.3.12.2.1107.5.2.43.66044.2021120118421931246...
# 9      10-BOLD_IMAGE_run03  1.3.12.2.1107.5.2.43.66044.2021120118424059730...
# 10          11-FieldMap_PA  1.3.12.2.1107.5.2.43.66044.2021120118501897263...
# 11     12-BOLD_IMAGE_run04  1.3.12.2.1107.5.2.43.66044.2021120118503967680...
# 12          13-FieldMap_PA  1.3.12.2.1107.5.2.43.66044.2021120118585640409...
# 13     14-BOLD_IMAGE_run05  1.3.12.2.1107.5.2.43.66044.2021120118591778613...
# 14          15-FieldMap_PA  1.3.12.2.1107.5.2.43.66044.2021120119080441530...
# 15         16-T2_1mm_SPACE  1.3.12.2.1107.5.2.43.66044.2021120119134847598...
# 16  17-MPRAGE_TI1100_ipat2  1.3.12.2.1107.5.2.43.66044.2021120119141041752...
#
#     series_files  unspecified  dim1  dim2  dim3  dim4  ...  study_description  \
# 0              9          NaN   512   512     9     1  ...        CAMRIS^Falk
# 1            128          NaN   160   160   128     1  ...        CAMRIS^Falk
# 2              5          NaN   162   162     5     1  ...        CAMRIS^Falk
# 3              3          NaN   162   162     3     1  ...        CAMRIS^Falk
# 4              3          NaN   162   162     3     1  ...        CAMRIS^Falk
# 5            132          NaN    84    84    46   132  ...        CAMRIS^Falk
# 6              4          NaN    84    84    46     4  ...        CAMRIS^Falk
# 7            132          NaN    84    84    46   132  ...        CAMRIS^Falk
# 8              4          NaN    84    84    46     4  ...        CAMRIS^Falk
# 9            132          NaN    84    84    46   132  ...        CAMRIS^Falk
# 10             4          NaN    84    84    46     4  ...        CAMRIS^Falk
# 11           132          NaN    84    84    46   132  ...        CAMRIS^Falk
# 12             4          NaN    84    84    46     4  ...        CAMRIS^Falk
# 13           132          NaN    84    84    46   132  ...        CAMRIS^Falk
# 14             4          NaN    84    84    46     4  ...        CAMRIS^Falk
# 15           176          NaN   256   256   176     1  ...        CAMRIS^Falk
# 16           160          NaN   256   192   160     1  ...        CAMRIS^Falk
#
#     referring_physician_name    series_description  sequence_name  \
# 0                        NaN  localizer_multislice         *fl2d1
# 1                        NaN          AAHead_Scout      *fl3d1_ns
# 2                        NaN  AAHead_Scout_MPR_sag      *fl3d1_ns
# 3                        NaN  AAHead_Scout_MPR_cor      *fl3d1_ns
# 4                        NaN  AAHead_Scout_MPR_tra      *fl3d1_ns
# 5                        NaN      BOLD_IMAGE_run01    epfid2d1_84
# 6                        NaN           FieldMap_PA    epfid2d1_84
# 7                        NaN      BOLD_IMAGE_run02    epfid2d1_84
# 8                        NaN           FieldMap_PA    epfid2d1_84
# 9                        NaN      BOLD_IMAGE_run03    epfid2d1_84
# 10                       NaN           FieldMap_PA    epfid2d1_84
# 11                       NaN      BOLD_IMAGE_run04    epfid2d1_84
# 12                       NaN           FieldMap_PA    epfid2d1_84
# 13                       NaN      BOLD_IMAGE_run05    epfid2d1_84
# 14                       NaN           FieldMap_PA    epfid2d1_84
# 15                       NaN          T2_1mm_SPACE     *spc_282ns
# 16                       NaN   MPRAGE_TI1100_ipat2     *tfl3d1_16
#
#                                            image_type  accession_number  \
# 0          ('ORIGINAL', 'PRIMARY', 'M', 'ND', 'NORM')               NaN
# 1          ('ORIGINAL', 'PRIMARY', 'M', 'ND', 'NORM')               NaN
# 2         ('DERIVED', 'PRIMARY', 'MPR', 'ND', 'NORM')               NaN
# 3         ('DERIVED', 'PRIMARY', 'MPR', 'ND', 'NORM')               NaN
# 4         ('DERIVED', 'PRIMARY', 'MPR', 'ND', 'NORM')               NaN
# 5   ('ORIGINAL', 'PRIMARY', 'M', 'ND', 'NORM', 'MO...               NaN
# 6   ('ORIGINAL', 'PRIMARY', 'M', 'ND', 'NORM', 'MO...               NaN
# 7   ('ORIGINAL', 'PRIMARY', 'M', 'ND', 'NORM', 'MO...               NaN
# 8   ('ORIGINAL', 'PRIMARY', 'M', 'ND', 'NORM', 'MO...               NaN
# 9   ('ORIGINAL', 'PRIMARY', 'M', 'ND', 'NORM', 'MO...               NaN
# 10  ('ORIGINAL', 'PRIMARY', 'M', 'ND', 'NORM', 'MO...               NaN
# 11  ('ORIGINAL', 'PRIMARY', 'M', 'ND', 'NORM', 'MO...               NaN
# 12  ('ORIGINAL', 'PRIMARY', 'M', 'ND', 'NORM', 'MO...               NaN
# 13  ('ORIGINAL', 'PRIMARY', 'M', 'ND', 'NORM', 'MO...               NaN
# 14  ('ORIGINAL', 'PRIMARY', 'M', 'ND', 'NORM', 'MO...               NaN
# 15         ('ORIGINAL', 'PRIMARY', 'M', 'ND', 'NORM')               NaN
# 16         ('ORIGINAL', 'PRIMARY', 'M', 'ND', 'NORM')               NaN
#
#    patient_age  patient_sex      date  \
# 0         028Y            M  20211201
# 1         028Y            M  20211201
# 2         028Y            M  20211201
# 3         028Y            M  20211201
# 4         028Y            M  20211201
# 5         028Y            M  20211201
# 6         028Y            M  20211201
# 7         028Y            M  20211201
# 8         028Y            M  20211201
# 9         028Y            M  20211201
# 10        028Y            M  20211201
# 11        028Y            M  20211201
# 12        028Y            M  20211201
# 13        028Y            M  20211201
# 14        028Y            M  20211201
# 15        028Y            M  20211201
# 16        028Y            M  20211201
#
#                                            series_uid
# 0   1.3.12.2.1107.5.2.43.66044.2021120118232768356...
# 1   1.3.12.2.1107.5.2.43.66044.2021120118242921346...
# 2   1.3.12.2.1107.5.2.43.66044.2021120118243262381...
# 3   1.3.12.2.1107.5.2.43.66044.2021120118243262429...
# 4   1.3.12.2.1107.5.2.43.66044.2021120118243262452...
# 5   1.3.12.2.1107.5.2.43.66044.2021120118260579495...
# 6   1.3.12.2.1107.5.2.43.66044.2021120118341985854...
# 7   1.3.12.2.1107.5.2.43.66044.2021120118344063819...
# 8   1.3.12.2.1107.5.2.43.66044.2021120118421931246...
# 9   1.3.12.2.1107.5.2.43.66044.2021120118424059730...
# 10  1.3.12.2.1107.5.2.43.66044.2021120118501897263...
# 11  1.3.12.2.1107.5.2.43.66044.2021120118503967680...
# 12  1.3.12.2.1107.5.2.43.66044.2021120118585640409...
# 13  1.3.12.2.1107.5.2.43.66044.2021120118591778613...
# 14  1.3.12.2.1107.5.2.43.66044.2021120119080441530...
# 15  1.3.12.2.1107.5.2.43.66044.2021120119134847598...
# 16  1.3.12.2.1107.5.2.43.66044.2021120119141041752...
#
# [17 rows x 26 columns]

# %% [markdown]
# * The goal is to set up a mapping between values some of these fields and a BIDS compliant file
#
#
# * The most useful fields for this are the `series_id` or `series_description` and the 4 dimension fields.
#   * `dim4` is the number of volumes and using this can help when there is a partial (i.e. scan started and stopped quickly) scan before a complete one where the `series_id` will be the same.

# %%
scan_df[['series_id', 'series_description', 'dim1','dim2','dim3','dim4']]
# Out:
#                  series_id    series_description  dim1  dim2  dim3  dim4
# 0   1-localizer_multislice  localizer_multislice   512   512     9     1
# 1           2-AAHead_Scout          AAHead_Scout   160   160   128     1
# 2           3-AAHead_Scout  AAHead_Scout_MPR_sag   162   162     5     1
# 3           4-AAHead_Scout  AAHead_Scout_MPR_cor   162   162     3     1
# 4           5-AAHead_Scout  AAHead_Scout_MPR_tra   162   162     3     1
# 5       6-BOLD_IMAGE_run01      BOLD_IMAGE_run01    84    84    46   132
# 6            7-FieldMap_PA           FieldMap_PA    84    84    46     4
# 7       8-BOLD_IMAGE_run02      BOLD_IMAGE_run02    84    84    46   132
# 8            9-FieldMap_PA           FieldMap_PA    84    84    46     4
# 9      10-BOLD_IMAGE_run03      BOLD_IMAGE_run03    84    84    46   132
# 10          11-FieldMap_PA           FieldMap_PA    84    84    46     4
# 11     12-BOLD_IMAGE_run04      BOLD_IMAGE_run04    84    84    46   132
# 12          13-FieldMap_PA           FieldMap_PA    84    84    46     4
# 13     14-BOLD_IMAGE_run05      BOLD_IMAGE_run05    84    84    46   132
# 14          15-FieldMap_PA           FieldMap_PA    84    84    46     4
# 15         16-T2_1mm_SPACE          T2_1mm_SPACE   256   256   176     1
# 16  17-MPRAGE_TI1100_ipat2   MPRAGE_TI1100_ipat2   256   192   160     1

# %% [markdown]
# * There is a Python file called `heuristic.py` that needs to be edited to set up the mappings between dicom files and these scan data and the location within the BIDS structure in the output folder.
#
#
# * The two things that need to be added to this files are:
#     1. __KEYS__ that provide a file template and mapping to where in the BIDS output a certain filetype should be written
#     2. __MATCHES__ are condition statements that match a scan using the fields in the dataframe above and map them to a specific key
#
#
#
# * __KEYS__
# Use the ‘create_key’ function to create keys inside of the ‘infotodict’ function. See how keys are created for the t1 scan, the different functional runs, and the field maps. These are put into a dictionary, and the values will be added using the conditional matching.
#
# ```python
#  t1w = create_key('sub-{subject}/anat/sub-{subject}_T1w')
#
#     func_read=create_key('sub-{subject}/func/sub-{subject}_task-read_run-{item:01d}_bold')
#     func_share=create_key('sub-{subject}/func/sub-{subject}_task-share_run-{item:01d}_bold')
#
#     fmap_AP=create_key('sub-{subject}/fmap/sub-{subject}_acq-{item:01d}_dir-AP_epi')
#
#
#     info = {
#             t1w: [],
#             func_read: [], func_share: [],
#             fmap_AP: []
#            }
#
# ```
#
# ![](img/heudiconv1.png)
#
#
# * __CONDITIONAL MATCHES__
# Now, using the information from the dicominfo.tsv, we will go through the series and put the scans only when they have the full number of scans.
# ```python
# if (s.dim1 == 256) and (s.dim2 == 192) and ('MPRAGE_TI1100_ipat2' in s.series_id):
#             info[t1w].append(s.series_id)
#
#         if (s.dim4 == 824 or s.dim4 == 813) and ('read' in s.series_id):
#             info[func_read].append(s.series_id)
#
#         if (s.dim4 == 865 or s.dim4 == 854 or s.dim4 == 568) and ('share' in s.series_id):
#             info[func_share].append(s.series_id)
#
#         if (s.dim4 == 3) and ('epi' in s.series_id):
#             info[fmap_AP].append(s.series_id)
# ```
# ![](img/heudiconv2.png)

# %% [markdown]
# * Once these are added to `heuristic.py` which we keep in:
#     ```
#     {Your Project}/scripts/BIDS/heudiconv/code
#     ```
#
#
# * and we delete the `.heudiconv` heuristic folder. Then we are ready to convert DICOM files to NIFTIs and set them up in a BIDS compliant structure!

# %%
rm -fr heudiconv/.heudiconv

# %%
# !singularity run --cleanenv \
    -B /data00/projects/geoscan_v2:/base  \
    -B /fmriDataRaw/fmri_data_raw:/raw \
    /data00/tools/singularity_images/heudiconv_0.8.0 \
    -d /raw/geoscan_R01/{subject}_t2/*/*.dcm \
    -o /base/data/bids_data/ \
    -f /base/scripts/BIDS/heudiconv/code/heuristic.py -ss t2 -s 'GS025'  -c dcm2niix -b --overwrite
# Out:
# INFO: Running heudiconv version 0.8.0 latest 0.11.3
# INFO: Need to process 1 study sessions
# INFO: PROCESSING STARTS: {'subject': 'GS025', 'outdir': '/base/data/bids_data/', 'session': 't2'}
# INFO: Processing 1179 dicoms
# INFO: Reloading existing filegroup.json because /base/data/bids_data/.heudiconv/GS025/ses-t2/info/GS025_ses-t2.edit.txt exists
# INFO: Doing conversion using dcm2niix
# INFO: Converting /base/data/bids_data/sub-GS025/ses-t2/anat/sub-GS025_ses-t2_T1 (160 DICOMs) -> /base/data/bids_data/sub-GS025/ses-t2/anat . Converter: dcm2niix . Output types: ('nii.gz',)
# 220612-21:25:42,96 nipype.utils INFO:
# 	 Running nipype version 1.4.2 (latest: 1.8.1)
# INFO: Running nipype version 1.4.2 (latest: 1.8.1)
# 220612-21:25:42,106 nipype.workflow INFO:
# 	 [Node] Setting-up "convert" in "/tmp/dcm2niix2mb2gegf/convert".
# INFO: [Node] Setting-up "convert" in "/tmp/dcm2niix2mb2gegf/convert".
# 220612-21:25:42,174 nipype.workflow INFO:
# 	 [Node] Running "convert" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z y -x n -t n -m n -f /base/data/bids_data/sub-GS025/ses-t2/anat/sub-GS025_ses-t2_T1 -o . -s n -v n /tmp/dcm2niix2mb2gegf/convert
# INFO: [Node] Running "convert" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z y -x n -t n -m n -f /base/data/bids_data/sub-GS025/ses-t2/anat/sub-GS025_ses-t2_T1 -o . -s n -v n /tmp/dcm2niix2mb2gegf/convert
# 220612-21:25:42,700 nipype.interface INFO:
# 	 stdout 2022-06-12T21:25:42.700700:Chris Rorden's dcm2niiX version v1.0.20190410  GCC6.3.0 (64-bit Linux)
# INFO: stdout 2022-06-12T21:25:42.700700:Chris Rorden's dcm2niiX version v1.0.20190410  GCC6.3.0 (64-bit Linux)
# 220612-21:25:42,701 nipype.interface INFO:
# 	 stdout 2022-06-12T21:25:42.700700:Found 160 DICOM file(s)
# INFO: stdout 2022-06-12T21:25:42.700700:Found 160 DICOM file(s)
# 220612-21:25:42,701 nipype.interface INFO:
# 	 stdout 2022-06-12T21:25:42.700700:Convert 160 DICOM as ./base/data/bids_data/sub-GS025/ses-t2/anat/sub-GS025_ses-t2_T1 (192x256x160x1)
# INFO: stdout 2022-06-12T21:25:42.700700:Convert 160 DICOM as ./base/data/bids_data/sub-GS025/ses-t2/anat/sub-GS025_ses-t2_T1 (192x256x160x1)
# 220612-21:25:42,997 nipype.interface INFO:
# 	 stdout 2022-06-12T21:25:42.997645:Compress: "/usr/bin/pigz" -b 960 -n -f -6 "./base/data/bids_data/sub-GS025/ses-t2/anat/sub-GS025_ses-t2_T1.nii"
# INFO: stdout 2022-06-12T21:25:42.997645:Compress: "/usr/bin/pigz" -b 960 -n -f -6 "./base/data/bids_data/sub-GS025/ses-t2/anat/sub-GS025_ses-t2_T1.nii"
# 220612-21:25:42,997 nipype.interface INFO:
# 	 stdout 2022-06-12T21:25:42.997645:Conversion required 0.726148 seconds (0.251398 for core code).
# INFO: stdout 2022-06-12T21:25:42.997645:Conversion required 0.726148 seconds (0.251398 for core code).
# 220612-21:25:43,38 nipype.workflow INFO:
# 	 [Node] Finished "convert".
# INFO: [Node] Finished "convert".
# WARNING: Failed to find task field in /base/data/bids_data/sub-GS025/ses-t2/anat/sub-GS025_ses-t2_T1.json.
# 220612-21:25:43,244 nipype.workflow INFO:
# 	 [Node] Setting-up "embedder" in "/tmp/embedmetazgn5u_jo/embedder".
# INFO: [Node] Setting-up "embedder" in "/tmp/embedmetazgn5u_jo/embedder".
# 220612-21:25:43,290 nipype.workflow INFO:
# 	 [Node] Running "embedder" ("nipype.interfaces.utility.wrappers.Function")
# INFO: [Node] Running "embedder" ("nipype.interfaces.utility.wrappers.Function")
# 220612-21:25:43,329 nipype.workflow WARNING:
# 	 Storing result file without outputs
# WARNING: Storing result file without outputs
# 220612-21:25:43,330 nipype.workflow WARNING:
# 	 [Node] Error on "embedder" (/tmp/embedmetazgn5u_jo/embedder)
# WARNING: [Node] Error on "embedder" (/tmp/embedmetazgn5u_jo/embedder)
# ERROR: Embedding failed: 'NoneType' object is not iterable
# INFO: Post-treating /base/data/bids_data/sub-GS025/ses-t2/anat/sub-GS025_ses-t2_T1.json file
# INFO: Converting /base/data/bids_data/sub-GS025/ses-t2/anat/sub-GS025_ses-t2_T2 (176 DICOMs) -> /base/data/bids_data/sub-GS025/ses-t2/anat . Converter: dcm2niix . Output types: ('nii.gz',)
# 220612-21:25:43,391 nipype.workflow INFO:
# 	 [Node] Setting-up "convert" in "/tmp/dcm2niix9zfd7faw/convert".
# INFO: [Node] Setting-up "convert" in "/tmp/dcm2niix9zfd7faw/convert".
# 220612-21:25:43,460 nipype.workflow INFO:
# 	 [Node] Running "convert" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z y -x n -t n -m n -f /base/data/bids_data/sub-GS025/ses-t2/anat/sub-GS025_ses-t2_T2 -o . -s n -v n /tmp/dcm2niix9zfd7faw/convert
# INFO: [Node] Running "convert" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z y -x n -t n -m n -f /base/data/bids_data/sub-GS025/ses-t2/anat/sub-GS025_ses-t2_T2 -o . -s n -v n /tmp/dcm2niix9zfd7faw/convert
# 220612-21:25:43,950 nipype.interface INFO:
# 	 stdout 2022-06-12T21:25:43.950099:Chris Rorden's dcm2niiX version v1.0.20190410  GCC6.3.0 (64-bit Linux)
# INFO: stdout 2022-06-12T21:25:43.950099:Chris Rorden's dcm2niiX version v1.0.20190410  GCC6.3.0 (64-bit Linux)
# 220612-21:25:43,950 nipype.interface INFO:
# 	 stdout 2022-06-12T21:25:43.950099:Found 176 DICOM file(s)
# INFO: stdout 2022-06-12T21:25:43.950099:Found 176 DICOM file(s)
# 220612-21:25:43,951 nipype.interface INFO:
# 	 stdout 2022-06-12T21:25:43.950099:Convert 176 DICOM as ./base/data/bids_data/sub-GS025/ses-t2/anat/sub-GS025_ses-t2_T2 (256x256x176x1)
# INFO: stdout 2022-06-12T21:25:43.950099:Convert 176 DICOM as ./base/data/bids_data/sub-GS025/ses-t2/anat/sub-GS025_ses-t2_T2 (256x256x176x1)
# 220612-21:25:44,459 nipype.interface INFO:
# 	 stdout 2022-06-12T21:25:44.459246:Compress: "/usr/bin/pigz" -b 960 -n -f -6 "./base/data/bids_data/sub-GS025/ses-t2/anat/sub-GS025_ses-t2_T2.nii"
# INFO: stdout 2022-06-12T21:25:44.459246:Compress: "/usr/bin/pigz" -b 960 -n -f -6 "./base/data/bids_data/sub-GS025/ses-t2/anat/sub-GS025_ses-t2_T2.nii"
# 220612-21:25:44,459 nipype.interface INFO:
# 	 stdout 2022-06-12T21:25:44.459246:Conversion required 0.976616 seconds (0.322021 for core code).
# INFO: stdout 2022-06-12T21:25:44.459246:Conversion required 0.976616 seconds (0.322021 for core code).
# 220612-21:25:44,492 nipype.workflow INFO:
# 	 [Node] Finished "convert".
# INFO: [Node] Finished "convert".
# WARNING: Failed to find task field in /base/data/bids_data/sub-GS025/ses-t2/anat/sub-GS025_ses-t2_T2.json.
# 220612-21:25:45,339 nipype.workflow INFO:
# 	 [Node] Setting-up "embedder" in "/tmp/embedmetaui7x7071/embedder".
# INFO: [Node] Setting-up "embedder" in "/tmp/embedmetaui7x7071/embedder".
# 220612-21:25:45,364 nipype.workflow INFO:
# 	 [Node] Running "embedder" ("nipype.interfaces.utility.wrappers.Function")
# INFO: [Node] Running "embedder" ("nipype.interfaces.utility.wrappers.Function")
# 220612-21:25:45,375 nipype.workflow WARNING:
# 	 Storing result file without outputs
# WARNING: Storing result file without outputs
# 220612-21:25:45,376 nipype.workflow WARNING:
# 	 [Node] Error on "embedder" (/tmp/embedmetaui7x7071/embedder)
# WARNING: [Node] Error on "embedder" (/tmp/embedmetaui7x7071/embedder)
# ERROR: Embedding failed: 'NoneType' object is not iterable
# INFO: Post-treating /base/data/bids_data/sub-GS025/ses-t2/anat/sub-GS025_ses-t2_T2.json file
# INFO: Converting /base/data/bids_data/sub-GS025/ses-t2/fmaps/sub-GS025_ses-t2_acq-1_epi (4 DICOMs) -> /base/data/bids_data/sub-GS025/ses-t2/fmaps . Converter: dcm2niix . Output types: ('nii.gz',)
# 220612-21:25:45,440 nipype.workflow INFO:
# 	 [Node] Setting-up "convert" in "/tmp/dcm2niix8tz5_gd8/convert".
# INFO: [Node] Setting-up "convert" in "/tmp/dcm2niix8tz5_gd8/convert".
# 220612-21:25:45,446 nipype.workflow INFO:
# 	 [Node] Running "convert" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z y -x n -t n -m n -f /base/data/bids_data/sub-GS025/ses-t2/fmaps/sub-GS025_ses-t2_acq-1_epi -o . -s n -v n /tmp/dcm2niix8tz5_gd8/convert
# INFO: [Node] Running "convert" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z y -x n -t n -m n -f /base/data/bids_data/sub-GS025/ses-t2/fmaps/sub-GS025_ses-t2_acq-1_epi -o . -s n -v n /tmp/dcm2niix8tz5_gd8/convert
# 220612-21:25:45,507 nipype.interface INFO:
# 	 stdout 2022-06-12T21:25:45.507670:Chris Rorden's dcm2niiX version v1.0.20190410  GCC6.3.0 (64-bit Linux)
# INFO: stdout 2022-06-12T21:25:45.507670:Chris Rorden's dcm2niiX version v1.0.20190410  GCC6.3.0 (64-bit Linux)
# 220612-21:25:45,508 nipype.interface INFO:
# 	 stdout 2022-06-12T21:25:45.507670:Found 4 DICOM file(s)
# INFO: stdout 2022-06-12T21:25:45.507670:Found 4 DICOM file(s)
# 220612-21:25:45,508 nipype.interface INFO:
# 	 stdout 2022-06-12T21:25:45.507670:slices stacked despite varying acquisition numbers (if this is not desired recompile with 'mySegmentByAcq')
# INFO: stdout 2022-06-12T21:25:45.507670:slices stacked despite varying acquisition numbers (if this is not desired recompile with 'mySegmentByAcq')
# 220612-21:25:45,508 nipype.interface INFO:
# 	 stdout 2022-06-12T21:25:45.507670:Convert 4 DICOM as ./base/data/bids_data/sub-GS025/ses-t2/fmaps/sub-GS025_ses-t2_acq-1_epi (84x84x46x4)
# INFO: stdout 2022-06-12T21:25:45.507670:Convert 4 DICOM as ./base/data/bids_data/sub-GS025/ses-t2/fmaps/sub-GS025_ses-t2_acq-1_epi (84x84x46x4)
# 220612-21:25:45,599 nipype.interface INFO:
# 	 stdout 2022-06-12T21:25:45.599357:Compress: "/usr/bin/pigz" -b 960 -n -f -6 "./base/data/bids_data/sub-GS025/ses-t2/fmaps/sub-GS025_ses-t2_acq-1_epi.nii"
# INFO: stdout 2022-06-12T21:25:45.599357:Compress: "/usr/bin/pigz" -b 960 -n -f -6 "./base/data/bids_data/sub-GS025/ses-t2/fmaps/sub-GS025_ses-t2_acq-1_epi.nii"
# 220612-21:25:45,599 nipype.interface INFO:
# 	 stdout 2022-06-12T21:25:45.599357:Conversion required 0.131952 seconds (0.034707 for core code).
# INFO: stdout 2022-06-12T21:25:45.599357:Conversion required 0.131952 seconds (0.034707 for core code).
# 220612-21:25:45,627 nipype.workflow INFO:
# 	 [Node] Finished "convert".
# INFO: [Node] Finished "convert".
# WARNING: Failed to find task field in /base/data/bids_data/sub-GS025/ses-t2/fmaps/sub-GS025_ses-t2_acq-1_epi.json.
# 220612-21:25:45,800 nipype.workflow INFO:
# 	 [Node] Setting-up "embedder" in "/tmp/embedmetapnp7q21m/embedder".
# INFO: [Node] Setting-up "embedder" in "/tmp/embedmetapnp7q21m/embedder".
# 220612-21:25:45,824 nipype.workflow INFO:
# 	 [Node] Running "embedder" ("nipype.interfaces.utility.wrappers.Function")
# INFO: [Node] Running "embedder" ("nipype.interfaces.utility.wrappers.Function")
# 220612-21:25:45,847 nipype.workflow WARNING:
# 	 Storing result file without outputs
# WARNING: Storing result file without outputs
# 220612-21:25:45,848 nipype.workflow WARNING:
# 	 [Node] Error on "embedder" (/tmp/embedmetapnp7q21m/embedder)
# WARNING: [Node] Error on "embedder" (/tmp/embedmetapnp7q21m/embedder)
# ERROR: Embedding failed: 'NoneType' object is not iterable
# INFO: Post-treating /base/data/bids_data/sub-GS025/ses-t2/fmaps/sub-GS025_ses-t2_acq-1_epi.json file
# INFO: Converting /base/data/bids_data/sub-GS025/ses-t2/fmaps/sub-GS025_ses-t2_acq-2_epi (4 DICOMs) -> /base/data/bids_data/sub-GS025/ses-t2/fmaps . Converter: dcm2niix . Output types: ('nii.gz',)
# 220612-21:25:45,913 nipype.workflow INFO:
# 	 [Node] Setting-up "convert" in "/tmp/dcm2niixg7n6u5pf/convert".
# INFO: [Node] Setting-up "convert" in "/tmp/dcm2niixg7n6u5pf/convert".
# 220612-21:25:45,923 nipype.workflow INFO:
# 	 [Node] Running "convert" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z y -x n -t n -m n -f /base/data/bids_data/sub-GS025/ses-t2/fmaps/sub-GS025_ses-t2_acq-2_epi -o . -s n -v n /tmp/dcm2niixg7n6u5pf/convert
# INFO: [Node] Running "convert" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z y -x n -t n -m n -f /base/data/bids_data/sub-GS025/ses-t2/fmaps/sub-GS025_ses-t2_acq-2_epi -o . -s n -v n /tmp/dcm2niixg7n6u5pf/convert
# 220612-21:25:45,984 nipype.interface INFO:
# 	 stdout 2022-06-12T21:25:45.984415:Chris Rorden's dcm2niiX version v1.0.20190410  GCC6.3.0 (64-bit Linux)
# INFO: stdout 2022-06-12T21:25:45.984415:Chris Rorden's dcm2niiX version v1.0.20190410  GCC6.3.0 (64-bit Linux)
# 220612-21:25:45,985 nipype.interface INFO:
# 	 stdout 2022-06-12T21:25:45.984415:Found 4 DICOM file(s)
# INFO: stdout 2022-06-12T21:25:45.984415:Found 4 DICOM file(s)
# 220612-21:25:45,985 nipype.interface INFO:
# 	 stdout 2022-06-12T21:25:45.984415:slices stacked despite varying acquisition numbers (if this is not desired recompile with 'mySegmentByAcq')
# INFO: stdout 2022-06-12T21:25:45.984415:slices stacked despite varying acquisition numbers (if this is not desired recompile with 'mySegmentByAcq')
# 220612-21:25:45,985 nipype.interface INFO:
# 	 stdout 2022-06-12T21:25:45.984415:Convert 4 DICOM as ./base/data/bids_data/sub-GS025/ses-t2/fmaps/sub-GS025_ses-t2_acq-2_epi (84x84x46x4)
# INFO: stdout 2022-06-12T21:25:45.984415:Convert 4 DICOM as ./base/data/bids_data/sub-GS025/ses-t2/fmaps/sub-GS025_ses-t2_acq-2_epi (84x84x46x4)
# 220612-21:25:46,72 nipype.interface INFO:
# 	 stdout 2022-06-12T21:25:46.072676:Compress: "/usr/bin/pigz" -b 960 -n -f -6 "./base/data/bids_data/sub-GS025/ses-t2/fmaps/sub-GS025_ses-t2_acq-2_epi.nii"
# INFO: stdout 2022-06-12T21:25:46.072676:Compress: "/usr/bin/pigz" -b 960 -n -f -6 "./base/data/bids_data/sub-GS025/ses-t2/fmaps/sub-GS025_ses-t2_acq-2_epi.nii"
# 220612-21:25:46,73 nipype.interface INFO:
# 	 stdout 2022-06-12T21:25:46.072676:Conversion required 0.128947 seconds (0.033620 for core code).
# INFO: stdout 2022-06-12T21:25:46.072676:Conversion required 0.128947 seconds (0.033620 for core code).
# 220612-21:25:46,116 nipype.workflow INFO:
# 	 [Node] Finished "convert".
# INFO: [Node] Finished "convert".
# WARNING: Failed to find task field in /base/data/bids_data/sub-GS025/ses-t2/fmaps/sub-GS025_ses-t2_acq-2_epi.json.
# 220612-21:25:46,267 nipype.workflow INFO:
# 	 [Node] Setting-up "embedder" in "/tmp/embedmetahthsrya8/embedder".
# INFO: [Node] Setting-up "embedder" in "/tmp/embedmetahthsrya8/embedder".
# 220612-21:25:46,276 nipype.workflow INFO:
# 	 [Node] Running "embedder" ("nipype.interfaces.utility.wrappers.Function")
# INFO: [Node] Running "embedder" ("nipype.interfaces.utility.wrappers.Function")
# 220612-21:25:46,299 nipype.workflow WARNING:
# 	 Storing result file without outputs
# WARNING: Storing result file without outputs
# 220612-21:25:46,300 nipype.workflow WARNING:
# 	 [Node] Error on "embedder" (/tmp/embedmetahthsrya8/embedder)
# WARNING: [Node] Error on "embedder" (/tmp/embedmetahthsrya8/embedder)
# ERROR: Embedding failed: 'NoneType' object is not iterable
# INFO: Post-treating /base/data/bids_data/sub-GS025/ses-t2/fmaps/sub-GS025_ses-t2_acq-2_epi.json file
# INFO: Converting /base/data/bids_data/sub-GS025/ses-t2/fmaps/sub-GS025_ses-t2_acq-3_epi (4 DICOMs) -> /base/data/bids_data/sub-GS025/ses-t2/fmaps . Converter: dcm2niix . Output types: ('nii.gz',)
# 220612-21:25:46,352 nipype.workflow INFO:
# 	 [Node] Setting-up "convert" in "/tmp/dcm2niix9kt84mjt/convert".
# INFO: [Node] Setting-up "convert" in "/tmp/dcm2niix9kt84mjt/convert".
# 220612-21:25:46,358 nipype.workflow INFO:
# 	 [Node] Running "convert" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z y -x n -t n -m n -f /base/data/bids_data/sub-GS025/ses-t2/fmaps/sub-GS025_ses-t2_acq-3_epi -o . -s n -v n /tmp/dcm2niix9kt84mjt/convert
# INFO: [Node] Running "convert" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z y -x n -t n -m n -f /base/data/bids_data/sub-GS025/ses-t2/fmaps/sub-GS025_ses-t2_acq-3_epi -o . -s n -v n /tmp/dcm2niix9kt84mjt/convert
# 220612-21:25:46,417 nipype.interface INFO:
# 	 stdout 2022-06-12T21:25:46.417363:Chris Rorden's dcm2niiX version v1.0.20190410  GCC6.3.0 (64-bit Linux)
# INFO: stdout 2022-06-12T21:25:46.417363:Chris Rorden's dcm2niiX version v1.0.20190410  GCC6.3.0 (64-bit Linux)
# 220612-21:25:46,417 nipype.interface INFO:
# 	 stdout 2022-06-12T21:25:46.417363:Found 4 DICOM file(s)
# INFO: stdout 2022-06-12T21:25:46.417363:Found 4 DICOM file(s)
# 220612-21:25:46,417 nipype.interface INFO:
# 	 stdout 2022-06-12T21:25:46.417363:slices stacked despite varying acquisition numbers (if this is not desired recompile with 'mySegmentByAcq')
# INFO: stdout 2022-06-12T21:25:46.417363:slices stacked despite varying acquisition numbers (if this is not desired recompile with 'mySegmentByAcq')
# 220612-21:25:46,417 nipype.interface INFO:
# 	 stdout 2022-06-12T21:25:46.417363:Convert 4 DICOM as ./base/data/bids_data/sub-GS025/ses-t2/fmaps/sub-GS025_ses-t2_acq-3_epi (84x84x46x4)
# INFO: stdout 2022-06-12T21:25:46.417363:Convert 4 DICOM as ./base/data/bids_data/sub-GS025/ses-t2/fmaps/sub-GS025_ses-t2_acq-3_epi (84x84x46x4)
# 220612-21:25:46,504 nipype.interface INFO:
# 	 stdout 2022-06-12T21:25:46.504636:Compress: "/usr/bin/pigz" -b 960 -n -f -6 "./base/data/bids_data/sub-GS025/ses-t2/fmaps/sub-GS025_ses-t2_acq-3_epi.nii"
# INFO: stdout 2022-06-12T21:25:46.504636:Compress: "/usr/bin/pigz" -b 960 -n -f -6 "./base/data/bids_data/sub-GS025/ses-t2/fmaps/sub-GS025_ses-t2_acq-3_epi.nii"
# 220612-21:25:46,504 nipype.interface INFO:
# 	 stdout 2022-06-12T21:25:46.504636:Conversion required 0.127050 seconds (0.034480 for core code).
# INFO: stdout 2022-06-12T21:25:46.504636:Conversion required 0.127050 seconds (0.034480 for core code).
# 220612-21:25:46,541 nipype.workflow INFO:
# 	 [Node] Finished "convert".
# INFO: [Node] Finished "convert".
# WARNING: Failed to find task field in /base/data/bids_data/sub-GS025/ses-t2/fmaps/sub-GS025_ses-t2_acq-3_epi.json.
# 220612-21:25:46,698 nipype.workflow INFO:
# 	 [Node] Setting-up "embedder" in "/tmp/embedmetavu2lut5o/embedder".
# INFO: [Node] Setting-up "embedder" in "/tmp/embedmetavu2lut5o/embedder".
# 220612-21:25:46,709 nipype.workflow INFO:
# 	 [Node] Running "embedder" ("nipype.interfaces.utility.wrappers.Function")
# INFO: [Node] Running "embedder" ("nipype.interfaces.utility.wrappers.Function")
# 220612-21:25:46,732 nipype.workflow WARNING:
# 	 Storing result file without outputs
# WARNING: Storing result file without outputs
# 220612-21:25:46,733 nipype.workflow WARNING:
# 	 [Node] Error on "embedder" (/tmp/embedmetavu2lut5o/embedder)
# WARNING: [Node] Error on "embedder" (/tmp/embedmetavu2lut5o/embedder)
# ERROR: Embedding failed: 'NoneType' object is not iterable
# INFO: Post-treating /base/data/bids_data/sub-GS025/ses-t2/fmaps/sub-GS025_ses-t2_acq-3_epi.json file
# INFO: Converting /base/data/bids_data/sub-GS025/ses-t2/fmaps/sub-GS025_ses-t2_acq-4_epi (4 DICOMs) -> /base/data/bids_data/sub-GS025/ses-t2/fmaps . Converter: dcm2niix . Output types: ('nii.gz',)
# 220612-21:25:46,777 nipype.workflow INFO:
# 	 [Node] Setting-up "convert" in "/tmp/dcm2niix6m5ofsyp/convert".
# INFO: [Node] Setting-up "convert" in "/tmp/dcm2niix6m5ofsyp/convert".
# 220612-21:25:46,782 nipype.workflow INFO:
# 	 [Node] Running "convert" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z y -x n -t n -m n -f /base/data/bids_data/sub-GS025/ses-t2/fmaps/sub-GS025_ses-t2_acq-4_epi -o . -s n -v n /tmp/dcm2niix6m5ofsyp/convert
# INFO: [Node] Running "convert" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z y -x n -t n -m n -f /base/data/bids_data/sub-GS025/ses-t2/fmaps/sub-GS025_ses-t2_acq-4_epi -o . -s n -v n /tmp/dcm2niix6m5ofsyp/convert
# 220612-21:25:46,842 nipype.interface INFO:
# 	 stdout 2022-06-12T21:25:46.841895:Chris Rorden's dcm2niiX version v1.0.20190410  GCC6.3.0 (64-bit Linux)
# INFO: stdout 2022-06-12T21:25:46.841895:Chris Rorden's dcm2niiX version v1.0.20190410  GCC6.3.0 (64-bit Linux)
# 220612-21:25:46,842 nipype.interface INFO:
# 	 stdout 2022-06-12T21:25:46.841895:Found 4 DICOM file(s)
# INFO: stdout 2022-06-12T21:25:46.841895:Found 4 DICOM file(s)
# 220612-21:25:46,842 nipype.interface INFO:
# 	 stdout 2022-06-12T21:25:46.841895:slices stacked despite varying acquisition numbers (if this is not desired recompile with 'mySegmentByAcq')
# INFO: stdout 2022-06-12T21:25:46.841895:slices stacked despite varying acquisition numbers (if this is not desired recompile with 'mySegmentByAcq')
# 220612-21:25:46,842 nipype.interface INFO:
# 	 stdout 2022-06-12T21:25:46.841895:Convert 4 DICOM as ./base/data/bids_data/sub-GS025/ses-t2/fmaps/sub-GS025_ses-t2_acq-4_epi (84x84x46x4)
# INFO: stdout 2022-06-12T21:25:46.841895:Convert 4 DICOM as ./base/data/bids_data/sub-GS025/ses-t2/fmaps/sub-GS025_ses-t2_acq-4_epi (84x84x46x4)
# 220612-21:25:46,938 nipype.interface INFO:
# 	 stdout 2022-06-12T21:25:46.938388:Compress: "/usr/bin/pigz" -b 960 -n -f -6 "./base/data/bids_data/sub-GS025/ses-t2/fmaps/sub-GS025_ses-t2_acq-4_epi.nii"
# INFO: stdout 2022-06-12T21:25:46.938388:Compress: "/usr/bin/pigz" -b 960 -n -f -6 "./base/data/bids_data/sub-GS025/ses-t2/fmaps/sub-GS025_ses-t2_acq-4_epi.nii"
# 220612-21:25:46,938 nipype.interface INFO:
# 	 stdout 2022-06-12T21:25:46.938388:Conversion required 0.138647 seconds (0.037259 for core code).
# INFO: stdout 2022-06-12T21:25:46.938388:Conversion required 0.138647 seconds (0.037259 for core code).
# 220612-21:25:46,964 nipype.workflow INFO:
# 	 [Node] Finished "convert".
# INFO: [Node] Finished "convert".
# WARNING: Failed to find task field in /base/data/bids_data/sub-GS025/ses-t2/fmaps/sub-GS025_ses-t2_acq-4_epi.json.
# 220612-21:25:47,128 nipype.workflow INFO:
# 	 [Node] Setting-up "embedder" in "/tmp/embedmeta6amc0oji/embedder".
# INFO: [Node] Setting-up "embedder" in "/tmp/embedmeta6amc0oji/embedder".
# 220612-21:25:47,137 nipype.workflow INFO:
# 	 [Node] Running "embedder" ("nipype.interfaces.utility.wrappers.Function")
# INFO: [Node] Running "embedder" ("nipype.interfaces.utility.wrappers.Function")
# 220612-21:25:47,160 nipype.workflow WARNING:
# 	 Storing result file without outputs
# WARNING: Storing result file without outputs
# 220612-21:25:47,160 nipype.workflow WARNING:
# 	 [Node] Error on "embedder" (/tmp/embedmeta6amc0oji/embedder)
# WARNING: [Node] Error on "embedder" (/tmp/embedmeta6amc0oji/embedder)
# ERROR: Embedding failed: 'NoneType' object is not iterable
# INFO: Post-treating /base/data/bids_data/sub-GS025/ses-t2/fmaps/sub-GS025_ses-t2_acq-4_epi.json file
# INFO: Converting /base/data/bids_data/sub-GS025/ses-t2/fmaps/sub-GS025_ses-t2_acq-5_epi (4 DICOMs) -> /base/data/bids_data/sub-GS025/ses-t2/fmaps . Converter: dcm2niix . Output types: ('nii.gz',)
# 220612-21:25:47,209 nipype.workflow INFO:
# 	 [Node] Setting-up "convert" in "/tmp/dcm2niix8ipgwy5n/convert".
# INFO: [Node] Setting-up "convert" in "/tmp/dcm2niix8ipgwy5n/convert".
# 220612-21:25:47,215 nipype.workflow INFO:
# 	 [Node] Running "convert" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z y -x n -t n -m n -f /base/data/bids_data/sub-GS025/ses-t2/fmaps/sub-GS025_ses-t2_acq-5_epi -o . -s n -v n /tmp/dcm2niix8ipgwy5n/convert
# INFO: [Node] Running "convert" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z y -x n -t n -m n -f /base/data/bids_data/sub-GS025/ses-t2/fmaps/sub-GS025_ses-t2_acq-5_epi -o . -s n -v n /tmp/dcm2niix8ipgwy5n/convert
# 220612-21:25:47,271 nipype.interface INFO:
# 	 stdout 2022-06-12T21:25:47.271809:Chris Rorden's dcm2niiX version v1.0.20190410  GCC6.3.0 (64-bit Linux)
# INFO: stdout 2022-06-12T21:25:47.271809:Chris Rorden's dcm2niiX version v1.0.20190410  GCC6.3.0 (64-bit Linux)
# 220612-21:25:47,272 nipype.interface INFO:
# 	 stdout 2022-06-12T21:25:47.271809:Found 4 DICOM file(s)
# INFO: stdout 2022-06-12T21:25:47.271809:Found 4 DICOM file(s)
# 220612-21:25:47,272 nipype.interface INFO:
# 	 stdout 2022-06-12T21:25:47.271809:slices stacked despite varying acquisition numbers (if this is not desired recompile with 'mySegmentByAcq')
# INFO: stdout 2022-06-12T21:25:47.271809:slices stacked despite varying acquisition numbers (if this is not desired recompile with 'mySegmentByAcq')
# 220612-21:25:47,272 nipype.interface INFO:
# 	 stdout 2022-06-12T21:25:47.271809:Convert 4 DICOM as ./base/data/bids_data/sub-GS025/ses-t2/fmaps/sub-GS025_ses-t2_acq-5_epi (84x84x46x4)
# INFO: stdout 2022-06-12T21:25:47.271809:Convert 4 DICOM as ./base/data/bids_data/sub-GS025/ses-t2/fmaps/sub-GS025_ses-t2_acq-5_epi (84x84x46x4)
# 220612-21:25:47,367 nipype.interface INFO:
# 	 stdout 2022-06-12T21:25:47.366952:Compress: "/usr/bin/pigz" -b 960 -n -f -6 "./base/data/bids_data/sub-GS025/ses-t2/fmaps/sub-GS025_ses-t2_acq-5_epi.nii"
# INFO: stdout 2022-06-12T21:25:47.366952:Compress: "/usr/bin/pigz" -b 960 -n -f -6 "./base/data/bids_data/sub-GS025/ses-t2/fmaps/sub-GS025_ses-t2_acq-5_epi.nii"
# 220612-21:25:47,367 nipype.interface INFO:
# 	 stdout 2022-06-12T21:25:47.366952:Conversion required 0.135383 seconds (0.034505 for core code).
# INFO: stdout 2022-06-12T21:25:47.366952:Conversion required 0.135383 seconds (0.034505 for core code).
# 220612-21:25:47,394 nipype.workflow INFO:
# 	 [Node] Finished "convert".
# INFO: [Node] Finished "convert".
# WARNING: Failed to find task field in /base/data/bids_data/sub-GS025/ses-t2/fmaps/sub-GS025_ses-t2_acq-5_epi.json.
# 220612-21:25:47,539 nipype.workflow INFO:
# 	 [Node] Setting-up "embedder" in "/tmp/embedmetaufiid6a0/embedder".
# INFO: [Node] Setting-up "embedder" in "/tmp/embedmetaufiid6a0/embedder".
# 220612-21:25:47,548 nipype.workflow INFO:
# 	 [Node] Running "embedder" ("nipype.interfaces.utility.wrappers.Function")
# INFO: [Node] Running "embedder" ("nipype.interfaces.utility.wrappers.Function")
# 220612-21:25:47,571 nipype.workflow WARNING:
# 	 Storing result file without outputs
# WARNING: Storing result file without outputs
# 220612-21:25:47,572 nipype.workflow WARNING:
# 	 [Node] Error on "embedder" (/tmp/embedmetaufiid6a0/embedder)
# WARNING: [Node] Error on "embedder" (/tmp/embedmetaufiid6a0/embedder)
# ERROR: Embedding failed: 'NoneType' object is not iterable
# INFO: Post-treating /base/data/bids_data/sub-GS025/ses-t2/fmaps/sub-GS025_ses-t2_acq-5_epi.json file
# INFO: Lock 139765392184208 acquired on /base/data/bids_data/heudiconv.lock
# INFO: Populating template files under /base/data/bids_data/
# INFO: Lock 139765392184208 released on /base/data/bids_data/heudiconv.lock
# INFO: PROCESSING DONE: {'subject': 'GS025', 'outdir': '/base/data/bids_data/', 'session': 't2'}
