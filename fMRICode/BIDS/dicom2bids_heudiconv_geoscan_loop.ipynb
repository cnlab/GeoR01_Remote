# %% [markdown]
# # DICOM-to-BIDS conversion using `heudiconv` and `singularity`
#
# * This notebook creates jobs for each participant and executes them by looping across participants in this notebook or by creating slurm jobs that can be run in parallel on the slurm cluser
#
#
# #### HISTORY
#
# * 9/9/21 dcosme - initial code

# %% [markdown]
# ## Do the DICOM to BIDS conversion for new data using existing config setup
#
# * Now we have set up a mapping and edited the `heuristics.py` file we can do dicom2bids conversion with the following Singularity command.
#
# * __N.B.__ Make sure the source folder in:
#    ```
#    /fmriDataRaw/fmri_data_raw/bbprime
#    ```
#
# * The only thing that needs to be changed is the subject identifier:
#    ```
#    -s BPP00
#    ```
#
#    it should match the folder name of the subject's data in
#    ```
#    /fmriDataRaw/fmri_data_raw/bbprime
#    ```

# %% [markdown]
# ## Loop through participants
# The code below creates a job that can be executed in this notebook
#
# ### Define variables

# %%
import os

project = 'geoscan_v2'
job_dir = os.path.join('/data00/projects/' + project + '/scripts/BIDS/jobs')
subs = ['GEO015',
        'GEO033',
        'GEO036',
        'GEO037',
        'GEO061',
        'GEO067',
        'GEO071',
        'GEO074',
        'GEO078']

job_file_template = r'''#!/bin/bash
singularity run --cleanenv \
    -B /data00/projects/geoscan_v2:/base  \
    -B /fmriDataRaw/fmri_data_raw:/raw \
    /data00/tools/singularity_images/heudiconv_0.8.0 \
    -d /raw/geoscan/T3/{subject}_T3/*.dcm \
    -o /base/data/bids_data/ \
    -f /base/scripts/BIDS/heudiconv/code/heuristic.py -ss t3 -s {ID} -c dcm2niix -b --overwrite
'''

# %% [markdown]
# ### Loop through specified participants

# %%
# make the job directory if it doens't exist
if os.path.exists(job_dir) == False:
    os.mkdir(job_dir)

# loop over participants
for s in subs:
    print('-------------- Creating: {} -------------'.format(s))
    
    file_path = os.path.join(job_dir, 'heudiconv_{}.job').format(s)
    print(file_path)

    with open(file_path.format(s), 'w') as job:
        job.write(job_file_template.format(ID=s, subject='{subject}'))
    
    # !bash $file_path
    print('~~~~=====~~~~ Sub {} Completed ~~~~=====~~~~'.format(s))
# Out:
# -------------- Creating: GEO015 -------------
# /data00/projects/geoscan_v2/scripts/BIDS/jobs/heudiconv_GEO015.job
# INFO: Running heudiconv version 0.8.0 latest 0.11.3
# INFO: Need to process 1 study sessions
# INFO: PROCESSING STARTS: {'subject': 'GEO015', 'outdir': '/base/data/bids_data/', 'session': 't3'}
# INFO: Processing 2984 dicoms
# INFO: Analyzing 2984 dicoms
# INFO: Generated sequence info for 11 studies with 2984 entries total
# INFO: Doing conversion using dcm2niix
# INFO: Converting /base/data/bids_data/sub-GEO015/ses-t3/anat/sub-GEO015_ses-t3_T1w (160 DICOMs) -> /base/data/bids_data/sub-GEO015/ses-t3/anat . Converter: dcm2niix . Output types: ('nii.gz',)
# 220613-16:18:25,46 nipype.utils INFO:
# 	 Running nipype version 1.4.2 (latest: 1.8.1)
# INFO: Running nipype version 1.4.2 (latest: 1.8.1)
# 220613-16:18:25,104 nipype.workflow INFO:
# 	 [Node] Setting-up "convert" in "/tmp/dcm2niixxo_mszj4/convert".
# INFO: [Node] Setting-up "convert" in "/tmp/dcm2niixxo_mszj4/convert".
# 220613-16:18:25,170 nipype.workflow INFO:
# 	 [Node] Running "convert" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z y -x n -t n -m n -f /base/data/bids_data/sub-GEO015/ses-t3/anat/sub-GEO015_ses-t3_T1w -o . -s n -v n /tmp/dcm2niixxo_mszj4/convert
# INFO: [Node] Running "convert" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z y -x n -t n -m n -f /base/data/bids_data/sub-GEO015/ses-t3/anat/sub-GEO015_ses-t3_T1w -o . -s n -v n /tmp/dcm2niixxo_mszj4/convert
# 220613-16:18:25,645 nipype.interface INFO:
# 	 stdout 2022-06-13T16:18:25.645290:Chris Rorden's dcm2niiX version v1.0.20190410  GCC6.3.0 (64-bit Linux)
# INFO: stdout 2022-06-13T16:18:25.645290:Chris Rorden's dcm2niiX version v1.0.20190410  GCC6.3.0 (64-bit Linux)
# 220613-16:18:25,645 nipype.interface INFO:
# 	 stdout 2022-06-13T16:18:25.645290:Found 160 DICOM file(s)
# INFO: stdout 2022-06-13T16:18:25.645290:Found 160 DICOM file(s)
# 220613-16:18:25,645 nipype.interface INFO:
# 	 stdout 2022-06-13T16:18:25.645290:Convert 160 DICOM as ./base/data/bids_data/sub-GEO015/ses-t3/anat/sub-GEO015_ses-t3_T1w (192x256x160x1)
# INFO: stdout 2022-06-13T16:18:25.645290:Convert 160 DICOM as ./base/data/bids_data/sub-GEO015/ses-t3/anat/sub-GEO015_ses-t3_T1w (192x256x160x1)
# 220613-16:18:25,956 nipype.interface INFO:
# 	 stdout 2022-06-13T16:18:25.956648:Compress: "/usr/bin/pigz" -b 960 -n -f -6 "./base/data/bids_data/sub-GEO015/ses-t3/anat/sub-GEO015_ses-t3_T1w.nii"
# INFO: stdout 2022-06-13T16:18:25.956648:Compress: "/usr/bin/pigz" -b 960 -n -f -6 "./base/data/bids_data/sub-GEO015/ses-t3/anat/sub-GEO015_ses-t3_T1w.nii"
# 220613-16:18:25,956 nipype.interface INFO:
# 	 stdout 2022-06-13T16:18:25.956648:Conversion required 0.692995 seconds (0.232694 for core code).
# INFO: stdout 2022-06-13T16:18:25.956648:Conversion required 0.692995 seconds (0.232694 for core code).
# 220613-16:18:25,989 nipype.workflow INFO:
# 	 [Node] Finished "convert".
# INFO: [Node] Finished "convert".
# WARNING: Failed to find task field in /base/data/bids_data/sub-GEO015/ses-t3/anat/sub-GEO015_ses-t3_T1w.json.
# 220613-16:18:26,738 nipype.workflow INFO:
# 	 [Node] Setting-up "embedder" in "/tmp/embedmetaybl2kj31/embedder".
# INFO: [Node] Setting-up "embedder" in "/tmp/embedmetaybl2kj31/embedder".
# 220613-16:18:26,790 nipype.workflow INFO:
# 	 [Node] Running "embedder" ("nipype.interfaces.utility.wrappers.Function")
# INFO: [Node] Running "embedder" ("nipype.interfaces.utility.wrappers.Function")
# 220613-16:18:31,852 nipype.workflow WARNING:
# 	 Storing result file without outputs
# WARNING: Storing result file without outputs
# 220613-16:18:31,853 nipype.workflow WARNING:
# 	 [Node] Error on "embedder" (/tmp/embedmetaybl2kj31/embedder)
# WARNING: [Node] Error on "embedder" (/tmp/embedmetaybl2kj31/embedder)
# ERROR: Embedding failed: 'NoneType' object is not subscriptable
# INFO: Post-treating /base/data/bids_data/sub-GEO015/ses-t3/anat/sub-GEO015_ses-t3_T1w.json file
# INFO: Converting /base/data/bids_data/sub-GEO015/ses-t3/anat/sub-GEO015_ses-t3_T2w (176 DICOMs) -> /base/data/bids_data/sub-GEO015/ses-t3/anat . Converter: dcm2niix . Output types: ('nii.gz',)
# 220613-16:18:32,32 nipype.workflow INFO:
# 	 [Node] Setting-up "convert" in "/tmp/dcm2niix7h94gwxl/convert".
# INFO: [Node] Setting-up "convert" in "/tmp/dcm2niix7h94gwxl/convert".
# 220613-16:18:32,98 nipype.workflow INFO:
# 	 [Node] Running "convert" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z y -x n -t n -m n -f /base/data/bids_data/sub-GEO015/ses-t3/anat/sub-GEO015_ses-t3_T2w -o . -s n -v n /tmp/dcm2niix7h94gwxl/convert
# INFO: [Node] Running "convert" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z y -x n -t n -m n -f /base/data/bids_data/sub-GEO015/ses-t3/anat/sub-GEO015_ses-t3_T2w -o . -s n -v n /tmp/dcm2niix7h94gwxl/convert
# 220613-16:18:32,614 nipype.interface INFO:
# 	 stdout 2022-06-13T16:18:32.613975:Chris Rorden's dcm2niiX version v1.0.20190410  GCC6.3.0 (64-bit Linux)
# INFO: stdout 2022-06-13T16:18:32.613975:Chris Rorden's dcm2niiX version v1.0.20190410  GCC6.3.0 (64-bit Linux)
# 220613-16:18:32,614 nipype.interface INFO:
# 	 stdout 2022-06-13T16:18:32.613975:Found 176 DICOM file(s)
# INFO: stdout 2022-06-13T16:18:32.613975:Found 176 DICOM file(s)
# 220613-16:18:32,614 nipype.interface INFO:
# 	 stdout 2022-06-13T16:18:32.613975:Convert 176 DICOM as ./base/data/bids_data/sub-GEO015/ses-t3/anat/sub-GEO015_ses-t3_T2w (256x256x176x1)
# INFO: stdout 2022-06-13T16:18:32.613975:Convert 176 DICOM as ./base/data/bids_data/sub-GEO015/ses-t3/anat/sub-GEO015_ses-t3_T2w (256x256x176x1)
# 220613-16:18:33,97 nipype.interface INFO:
# 	 stdout 2022-06-13T16:18:33.097431:Compress: "/usr/bin/pigz" -b 960 -n -f -6 "./base/data/bids_data/sub-GEO015/ses-t3/anat/sub-GEO015_ses-t3_T2w.nii"
# INFO: stdout 2022-06-13T16:18:33.097431:Compress: "/usr/bin/pigz" -b 960 -n -f -6 "./base/data/bids_data/sub-GEO015/ses-t3/anat/sub-GEO015_ses-t3_T2w.nii"
# 220613-16:18:33,97 nipype.interface INFO:
# 	 stdout 2022-06-13T16:18:33.097431:Conversion required 0.971655 seconds (0.344329 for core code).
# INFO: stdout 2022-06-13T16:18:33.097431:Conversion required 0.971655 seconds (0.344329 for core code).
# 220613-16:18:33,146 nipype.workflow INFO:
# 	 [Node] Finished "convert".
# INFO: [Node] Finished "convert".
# WARNING: Failed to find task field in /base/data/bids_data/sub-GEO015/ses-t3/anat/sub-GEO015_ses-t3_T2w.json.
# 220613-16:18:33,712 nipype.workflow INFO:
# 	 [Node] Setting-up "embedder" in "/tmp/embedmetag24zenki/embedder".
# INFO: [Node] Setting-up "embedder" in "/tmp/embedmetag24zenki/embedder".
# 220613-16:18:33,734 nipype.workflow INFO:
# 	 [Node] Running "embedder" ("nipype.interfaces.utility.wrappers.Function")
# INFO: [Node] Running "embedder" ("nipype.interfaces.utility.wrappers.Function")
# 220613-16:18:39,183 nipype.workflow WARNING:
# 	 Storing result file without outputs
# WARNING: Storing result file without outputs
# 220613-16:18:39,184 nipype.workflow WARNING:
# 	 [Node] Error on "embedder" (/tmp/embedmetag24zenki/embedder)
# WARNING: [Node] Error on "embedder" (/tmp/embedmetag24zenki/embedder)
# ERROR: Embedding failed: 'NoneType' object is not subscriptable
# INFO: Post-treating /base/data/bids_data/sub-GEO015/ses-t3/anat/sub-GEO015_ses-t3_T2w.json file
# INFO: Converting /base/data/bids_data/sub-GEO015/ses-t3/func/sub-GEO015_ses-t3_task-image_run-1_bold (395 DICOMs) -> /base/data/bids_data/sub-GEO015/ses-t3/func . Converter: dcm2niix . Output types: ('nii.gz',)
# 220613-16:18:39,574 nipype.workflow INFO:
# 	 [Node] Setting-up "convert" in "/tmp/dcm2niix9v26ilim/convert".
# INFO: [Node] Setting-up "convert" in "/tmp/dcm2niix9v26ilim/convert".
# 220613-16:18:39,716 nipype.workflow INFO:
# 	 [Node] Running "convert" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z y -x n -t n -m n -f /base/data/bids_data/sub-GEO015/ses-t3/func/sub-GEO015_ses-t3_task-image_run-1_bold -o . -s n -v n /tmp/dcm2niix9v26ilim/convert
# INFO: [Node] Running "convert" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z y -x n -t n -m n -f /base/data/bids_data/sub-GEO015/ses-t3/func/sub-GEO015_ses-t3_task-image_run-1_bold -o . -s n -v n /tmp/dcm2niix9v26ilim/convert
# 220613-16:18:42,66 nipype.interface INFO:
# 	 stdout 2022-06-13T16:18:42.065855:Chris Rorden's dcm2niiX version v1.0.20190410  GCC6.3.0 (64-bit Linux)
# INFO: stdout 2022-06-13T16:18:42.065855:Chris Rorden's dcm2niiX version v1.0.20190410  GCC6.3.0 (64-bit Linux)
# 220613-16:18:42,66 nipype.interface INFO:
# 	 stdout 2022-06-13T16:18:42.065855:Found 395 DICOM file(s)
# INFO: stdout 2022-06-13T16:18:42.065855:Found 395 DICOM file(s)
# 220613-16:18:42,66 nipype.interface INFO:
# 	 stdout 2022-06-13T16:18:42.065855:slices stacked despite varying acquisition numbers (if this is not desired recompile with 'mySegmentByAcq')
# INFO: stdout 2022-06-13T16:18:42.065855:slices stacked despite varying acquisition numbers (if this is not desired recompile with 'mySegmentByAcq')
# 220613-16:18:42,66 nipype.interface INFO:
# 	 stdout 2022-06-13T16:18:42.065855:Convert 395 DICOM as ./base/data/bids_data/sub-GEO015/ses-t3/func/sub-GEO015_ses-t3_task-image_run-1_bold (84x84x56x395)
# INFO: stdout 2022-06-13T16:18:42.065855:Convert 395 DICOM as ./base/data/bids_data/sub-GEO015/ses-t3/func/sub-GEO015_ses-t3_task-image_run-1_bold (84x84x56x395)
# 220613-16:18:45,147 nipype.interface INFO:
# 	 stdout 2022-06-13T16:18:45.147760:Compress: "/usr/bin/pigz" -b 960 -n -f -6 "./base/data/bids_data/sub-GEO015/ses-t3/func/sub-GEO015_ses-t3_task-image_run-1_bold.nii"
# INFO: stdout 2022-06-13T16:18:45.147760:Compress: "/usr/bin/pigz" -b 960 -n -f -6 "./base/data/bids_data/sub-GEO015/ses-t3/func/sub-GEO015_ses-t3_task-image_run-1_bold.nii"
# 220613-16:18:45,148 nipype.interface INFO:
# 	 stdout 2022-06-13T16:18:45.147760:Conversion required 5.397032 seconds (1.872105 for core code).
# INFO: stdout 2022-06-13T16:18:45.147760:Conversion required 5.397032 seconds (1.872105 for core code).
# 220613-16:18:45,208 nipype.workflow INFO:
# 	 [Node] Finished "convert".
# INFO: [Node] Finished "convert".
# 220613-16:18:46,660 nipype.workflow INFO:
# 	 [Node] Setting-up "embedder" in "/tmp/embedmetamq1_dx1i/embedder".
# INFO: [Node] Setting-up "embedder" in "/tmp/embedmetamq1_dx1i/embedder".
# 220613-16:18:46,724 nipype.workflow INFO:
# 	 [Node] Running "embedder" ("nipype.interfaces.utility.wrappers.Function")
# INFO: [Node] Running "embedder" ("nipype.interfaces.utility.wrappers.Function")
# 220613-16:19:12,379 nipype.workflow WARNING:
# 	 Storing result file without outputs
# WARNING: Storing result file without outputs
# 220613-16:19:12,381 nipype.workflow WARNING:
# 	 [Node] Error on "embedder" (/tmp/embedmetamq1_dx1i/embedder)
# WARNING: [Node] Error on "embedder" (/tmp/embedmetamq1_dx1i/embedder)
# ERROR: Embedding failed: 'NoneType' object is not subscriptable
# INFO: Post-treating /base/data/bids_data/sub-GEO015/ses-t3/func/sub-GEO015_ses-t3_task-image_run-1_bold.json file
# INFO: Converting /base/data/bids_data/sub-GEO015/ses-t3/func/sub-GEO015_ses-t3_task-image_run-2_bold (395 DICOMs) -> /base/data/bids_data/sub-GEO015/ses-t3/func . Converter: dcm2niix . Output types: ('nii.gz',)
# 220613-16:19:14,388 nipype.workflow INFO:
# 	 [Node] Setting-up "convert" in "/tmp/dcm2niixvq6jjhk8/convert".
# INFO: [Node] Setting-up "convert" in "/tmp/dcm2niixvq6jjhk8/convert".
# 220613-16:19:14,537 nipype.workflow INFO:
# 	 [Node] Running "convert" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z y -x n -t n -m n -f /base/data/bids_data/sub-GEO015/ses-t3/func/sub-GEO015_ses-t3_task-image_run-2_bold -o . -s n -v n /tmp/dcm2niixvq6jjhk8/convert
# INFO: [Node] Running "convert" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z y -x n -t n -m n -f /base/data/bids_data/sub-GEO015/ses-t3/func/sub-GEO015_ses-t3_task-image_run-2_bold -o . -s n -v n /tmp/dcm2niixvq6jjhk8/convert
# 220613-16:19:17,69 nipype.interface INFO:
# 	 stdout 2022-06-13T16:19:17.068994:Chris Rorden's dcm2niiX version v1.0.20190410  GCC6.3.0 (64-bit Linux)
# INFO: stdout 2022-06-13T16:19:17.068994:Chris Rorden's dcm2niiX version v1.0.20190410  GCC6.3.0 (64-bit Linux)
# 220613-16:19:17,69 nipype.interface INFO:
# 	 stdout 2022-06-13T16:19:17.068994:Found 395 DICOM file(s)
# INFO: stdout 2022-06-13T16:19:17.068994:Found 395 DICOM file(s)
# 220613-16:19:17,69 nipype.interface INFO:
# 	 stdout 2022-06-13T16:19:17.068994:slices stacked despite varying acquisition numbers (if this is not desired recompile with 'mySegmentByAcq')
# INFO: stdout 2022-06-13T16:19:17.068994:slices stacked despite varying acquisition numbers (if this is not desired recompile with 'mySegmentByAcq')
# 220613-16:19:17,69 nipype.interface INFO:
# 	 stdout 2022-06-13T16:19:17.068994:Convert 395 DICOM as ./base/data/bids_data/sub-GEO015/ses-t3/func/sub-GEO015_ses-t3_task-image_run-2_bold (84x84x56x395)
# INFO: stdout 2022-06-13T16:19:17.068994:Convert 395 DICOM as ./base/data/bids_data/sub-GEO015/ses-t3/func/sub-GEO015_ses-t3_task-image_run-2_bold (84x84x56x395)
# 220613-16:19:20,312 nipype.interface INFO:
# 	 stdout 2022-06-13T16:19:20.312646:Compress: "/usr/bin/pigz" -b 960 -n -f -6 "./base/data/bids_data/sub-GEO015/ses-t3/func/sub-GEO015_ses-t3_task-image_run-2_bold.nii"
# INFO: stdout 2022-06-13T16:19:20.312646:Compress: "/usr/bin/pigz" -b 960 -n -f -6 "./base/data/bids_data/sub-GEO015/ses-t3/func/sub-GEO015_ses-t3_task-image_run-2_bold.nii"
# 220613-16:19:20,312 nipype.interface INFO:
# 	 stdout 2022-06-13T16:19:20.312646:Conversion required 5.643682 seconds (1.871635 for core code).
# INFO: stdout 2022-06-13T16:19:20.312646:Conversion required 5.643682 seconds (1.871635 for core code).
# 220613-16:19:20,444 nipype.workflow INFO:
# 	 [Node] Finished "convert".
# INFO: [Node] Finished "convert".
# 220613-16:19:22,50 nipype.workflow INFO:
# 	 [Node] Setting-up "embedder" in "/tmp/embedmeta546q840u/embedder".
# INFO: [Node] Setting-up "embedder" in "/tmp/embedmeta546q840u/embedder".
# 220613-16:19:22,186 nipype.workflow INFO:
# 	 [Node] Running "embedder" ("nipype.interfaces.utility.wrappers.Function")
# INFO: [Node] Running "embedder" ("nipype.interfaces.utility.wrappers.Function")
# 220613-16:19:47,420 nipype.workflow WARNING:
# 	 Storing result file without outputs
# WARNING: Storing result file without outputs
# 220613-16:19:47,422 nipype.workflow WARNING:
# 	 [Node] Error on "embedder" (/tmp/embedmeta546q840u/embedder)
# WARNING: [Node] Error on "embedder" (/tmp/embedmeta546q840u/embedder)
# ERROR: Embedding failed: 'NoneType' object is not subscriptable
# INFO: Post-treating /base/data/bids_data/sub-GEO015/ses-t3/func/sub-GEO015_ses-t3_task-image_run-2_bold.json file
# INFO: Converting /base/data/bids_data/sub-GEO015/ses-t3/func/sub-GEO015_ses-t3_task-image_run-3_bold (395 DICOMs) -> /base/data/bids_data/sub-GEO015/ses-t3/func . Converter: dcm2niix . Output types: ('nii.gz',)
# 220613-16:19:49,525 nipype.workflow INFO:
# 	 [Node] Setting-up "convert" in "/tmp/dcm2niix14tx73re/convert".
# INFO: [Node] Setting-up "convert" in "/tmp/dcm2niix14tx73re/convert".
# 220613-16:19:49,663 nipype.workflow INFO:
# 	 [Node] Running "convert" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z y -x n -t n -m n -f /base/data/bids_data/sub-GEO015/ses-t3/func/sub-GEO015_ses-t3_task-image_run-3_bold -o . -s n -v n /tmp/dcm2niix14tx73re/convert
# INFO: [Node] Running "convert" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z y -x n -t n -m n -f /base/data/bids_data/sub-GEO015/ses-t3/func/sub-GEO015_ses-t3_task-image_run-3_bold -o . -s n -v n /tmp/dcm2niix14tx73re/convert
# 220613-16:19:52,9 nipype.interface INFO:
# 	 stdout 2022-06-13T16:19:52.009340:Chris Rorden's dcm2niiX version v1.0.20190410  GCC6.3.0 (64-bit Linux)
# INFO: stdout 2022-06-13T16:19:52.009340:Chris Rorden's dcm2niiX version v1.0.20190410  GCC6.3.0 (64-bit Linux)
# 220613-16:19:52,9 nipype.interface INFO:
# 	 stdout 2022-06-13T16:19:52.009340:Found 395 DICOM file(s)
# INFO: stdout 2022-06-13T16:19:52.009340:Found 395 DICOM file(s)
# 220613-16:19:52,9 nipype.interface INFO:
# 	 stdout 2022-06-13T16:19:52.009340:slices stacked despite varying acquisition numbers (if this is not desired recompile with 'mySegmentByAcq')
# INFO: stdout 2022-06-13T16:19:52.009340:slices stacked despite varying acquisition numbers (if this is not desired recompile with 'mySegmentByAcq')
# 220613-16:19:52,9 nipype.interface INFO:
# 	 stdout 2022-06-13T16:19:52.009340:Convert 395 DICOM as ./base/data/bids_data/sub-GEO015/ses-t3/func/sub-GEO015_ses-t3_task-image_run-3_bold (84x84x56x395)
# INFO: stdout 2022-06-13T16:19:52.009340:Convert 395 DICOM as ./base/data/bids_data/sub-GEO015/ses-t3/func/sub-GEO015_ses-t3_task-image_run-3_bold (84x84x56x395)
# 220613-16:19:55,113 nipype.interface INFO:
# 	 stdout 2022-06-13T16:19:55.113769:Compress: "/usr/bin/pigz" -b 960 -n -f -6 "./base/data/bids_data/sub-GEO015/ses-t3/func/sub-GEO015_ses-t3_task-image_run-3_bold.nii"
# INFO: stdout 2022-06-13T16:19:55.113769:Compress: "/usr/bin/pigz" -b 960 -n -f -6 "./base/data/bids_data/sub-GEO015/ses-t3/func/sub-GEO015_ses-t3_task-image_run-3_bold.nii"
# 220613-16:19:55,114 nipype.interface INFO:
# 	 stdout 2022-06-13T16:19:55.113769:Conversion required 5.321280 seconds (1.798250 for core code).
# INFO: stdout 2022-06-13T16:19:55.113769:Conversion required 5.321280 seconds (1.798250 for core code).
# 220613-16:19:55,199 nipype.workflow INFO:
# 	 [Node] Finished "convert".
# INFO: [Node] Finished "convert".
# 220613-16:19:56,725 nipype.workflow INFO:
# 	 [Node] Setting-up "embedder" in "/tmp/embedmetax9bpi3w5/embedder".
# INFO: [Node] Setting-up "embedder" in "/tmp/embedmetax9bpi3w5/embedder".
# 220613-16:19:56,767 nipype.workflow INFO:
# 	 [Node] Running "embedder" ("nipype.interfaces.utility.wrappers.Function")
# INFO: [Node] Running "embedder" ("nipype.interfaces.utility.wrappers.Function")
# 220613-16:20:22,70 nipype.workflow WARNING:
# 	 Storing result file without outputs
# WARNING: Storing result file without outputs
# 220613-16:20:22,72 nipype.workflow WARNING:
# 	 [Node] Error on "embedder" (/tmp/embedmetax9bpi3w5/embedder)
# WARNING: [Node] Error on "embedder" (/tmp/embedmetax9bpi3w5/embedder)
# ERROR: Embedding failed: 'NoneType' object is not subscriptable
# INFO: Post-treating /base/data/bids_data/sub-GEO015/ses-t3/func/sub-GEO015_ses-t3_task-image_run-3_bold.json file
# INFO: Converting /base/data/bids_data/sub-GEO015/ses-t3/func/sub-GEO015_ses-t3_task-image_run-4_bold (395 DICOMs) -> /base/data/bids_data/sub-GEO015/ses-t3/func . Converter: dcm2niix . Output types: ('nii.gz',)
# 220613-16:20:23,916 nipype.workflow INFO:
# 	 [Node] Setting-up "convert" in "/tmp/dcm2niix_tyqoree/convert".
# INFO: [Node] Setting-up "convert" in "/tmp/dcm2niix_tyqoree/convert".
# 220613-16:20:24,62 nipype.workflow INFO:
# 	 [Node] Running "convert" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z y -x n -t n -m n -f /base/data/bids_data/sub-GEO015/ses-t3/func/sub-GEO015_ses-t3_task-image_run-4_bold -o . -s n -v n /tmp/dcm2niix_tyqoree/convert
# INFO: [Node] Running "convert" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z y -x n -t n -m n -f /base/data/bids_data/sub-GEO015/ses-t3/func/sub-GEO015_ses-t3_task-image_run-4_bold -o . -s n -v n /tmp/dcm2niix_tyqoree/convert
# 220613-16:20:26,409 nipype.interface INFO:
# 	 stdout 2022-06-13T16:20:26.409210:Chris Rorden's dcm2niiX version v1.0.20190410  GCC6.3.0 (64-bit Linux)
# INFO: stdout 2022-06-13T16:20:26.409210:Chris Rorden's dcm2niiX version v1.0.20190410  GCC6.3.0 (64-bit Linux)
# 220613-16:20:26,410 nipype.interface INFO:
# 	 stdout 2022-06-13T16:20:26.409210:Found 395 DICOM file(s)
# INFO: stdout 2022-06-13T16:20:26.409210:Found 395 DICOM file(s)
# 220613-16:20:26,410 nipype.interface INFO:
# 	 stdout 2022-06-13T16:20:26.409210:slices stacked despite varying acquisition numbers (if this is not desired recompile with 'mySegmentByAcq')
# INFO: stdout 2022-06-13T16:20:26.409210:slices stacked despite varying acquisition numbers (if this is not desired recompile with 'mySegmentByAcq')
# 220613-16:20:26,410 nipype.interface INFO:
# 	 stdout 2022-06-13T16:20:26.409210:Convert 395 DICOM as ./base/data/bids_data/sub-GEO015/ses-t3/func/sub-GEO015_ses-t3_task-image_run-4_bold (84x84x56x395)
# INFO: stdout 2022-06-13T16:20:26.409210:Convert 395 DICOM as ./base/data/bids_data/sub-GEO015/ses-t3/func/sub-GEO015_ses-t3_task-image_run-4_bold (84x84x56x395)
# 220613-16:20:29,435 nipype.interface INFO:
# 	 stdout 2022-06-13T16:20:29.435666:Compress: "/usr/bin/pigz" -b 960 -n -f -6 "./base/data/bids_data/sub-GEO015/ses-t3/func/sub-GEO015_ses-t3_task-image_run-4_bold.nii"
# INFO: stdout 2022-06-13T16:20:29.435666:Compress: "/usr/bin/pigz" -b 960 -n -f -6 "./base/data/bids_data/sub-GEO015/ses-t3/func/sub-GEO015_ses-t3_task-image_run-4_bold.nii"
# 220613-16:20:29,436 nipype.interface INFO:
# 	 stdout 2022-06-13T16:20:29.435666:Conversion required 5.241819 seconds (1.771228 for core code).
# INFO: stdout 2022-06-13T16:20:29.435666:Conversion required 5.241819 seconds (1.771228 for core code).
# 220613-16:20:29,529 nipype.workflow INFO:
# 	 [Node] Finished "convert".
# INFO: [Node] Finished "convert".
# 220613-16:20:31,382 nipype.workflow INFO:
# 	 [Node] Setting-up "embedder" in "/tmp/embedmetabcgioo7o/embedder".
# INFO: [Node] Setting-up "embedder" in "/tmp/embedmetabcgioo7o/embedder".
# 220613-16:20:31,474 nipype.workflow INFO:
# 	 [Node] Running "embedder" ("nipype.interfaces.utility.wrappers.Function")
# INFO: [Node] Running "embedder" ("nipype.interfaces.utility.wrappers.Function")
# 220613-16:20:56,277 nipype.workflow WARNING:
# 	 Storing result file without outputs
# WARNING: Storing result file without outputs
# 220613-16:20:56,279 nipype.workflow WARNING:
# 	 [Node] Error on "embedder" (/tmp/embedmetabcgioo7o/embedder)
# WARNING: [Node] Error on "embedder" (/tmp/embedmetabcgioo7o/embedder)
# ERROR: Embedding failed: 'NoneType' object is not subscriptable
# INFO: Post-treating /base/data/bids_data/sub-GEO015/ses-t3/func/sub-GEO015_ses-t3_task-image_run-4_bold.json file
# INFO: Converting /base/data/bids_data/sub-GEO015/ses-t3/func/sub-GEO015_ses-t3_task-image_run-5_bold (395 DICOMs) -> /base/data/bids_data/sub-GEO015/ses-t3/func . Converter: dcm2niix . Output types: ('nii.gz',)
# 220613-16:20:58,131 nipype.workflow INFO:
# 	 [Node] Setting-up "convert" in "/tmp/dcm2niix_x5ovzql/convert".
# INFO: [Node] Setting-up "convert" in "/tmp/dcm2niix_x5ovzql/convert".
# 220613-16:20:58,267 nipype.workflow INFO:
# 	 [Node] Running "convert" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z y -x n -t n -m n -f /base/data/bids_data/sub-GEO015/ses-t3/func/sub-GEO015_ses-t3_task-image_run-5_bold -o . -s n -v n /tmp/dcm2niix_x5ovzql/convert
# INFO: [Node] Running "convert" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z y -x n -t n -m n -f /base/data/bids_data/sub-GEO015/ses-t3/func/sub-GEO015_ses-t3_task-image_run-5_bold -o . -s n -v n /tmp/dcm2niix_x5ovzql/convert
# 220613-16:21:00,660 nipype.interface INFO:
# 	 stdout 2022-06-13T16:21:00.660553:Chris Rorden's dcm2niiX version v1.0.20190410  GCC6.3.0 (64-bit Linux)
# INFO: stdout 2022-06-13T16:21:00.660553:Chris Rorden's dcm2niiX version v1.0.20190410  GCC6.3.0 (64-bit Linux)
# 220613-16:21:00,661 nipype.interface INFO:
# 	 stdout 2022-06-13T16:21:00.660553:Found 395 DICOM file(s)
# INFO: stdout 2022-06-13T16:21:00.660553:Found 395 DICOM file(s)
# 220613-16:21:00,661 nipype.interface INFO:
# 	 stdout 2022-06-13T16:21:00.660553:slices stacked despite varying acquisition numbers (if this is not desired recompile with 'mySegmentByAcq')
# INFO: stdout 2022-06-13T16:21:00.660553:slices stacked despite varying acquisition numbers (if this is not desired recompile with 'mySegmentByAcq')
# 220613-16:21:00,661 nipype.interface INFO:
# 	 stdout 2022-06-13T16:21:00.660553:Convert 395 DICOM as ./base/data/bids_data/sub-GEO015/ses-t3/func/sub-GEO015_ses-t3_task-image_run-5_bold (84x84x56x395)
# INFO: stdout 2022-06-13T16:21:00.660553:Convert 395 DICOM as ./base/data/bids_data/sub-GEO015/ses-t3/func/sub-GEO015_ses-t3_task-image_run-5_bold (84x84x56x395)
# 220613-16:21:03,886 nipype.interface INFO:
# 	 stdout 2022-06-13T16:21:03.886672:Compress: "/usr/bin/pigz" -b 960 -n -f -6 "./base/data/bids_data/sub-GEO015/ses-t3/func/sub-GEO015_ses-t3_task-image_run-5_bold.nii"
# INFO: stdout 2022-06-13T16:21:03.886672:Compress: "/usr/bin/pigz" -b 960 -n -f -6 "./base/data/bids_data/sub-GEO015/ses-t3/func/sub-GEO015_ses-t3_task-image_run-5_bold.nii"
# 220613-16:21:03,887 nipype.interface INFO:
# 	 stdout 2022-06-13T16:21:03.886672:Conversion required 5.492909 seconds (1.791645 for core code).
# INFO: stdout 2022-06-13T16:21:03.886672:Conversion required 5.492909 seconds (1.791645 for core code).
# 220613-16:21:03,972 nipype.workflow INFO:
# 	 [Node] Finished "convert".
# INFO: [Node] Finished "convert".
# 220613-16:21:05,415 nipype.workflow INFO:
# 	 [Node] Setting-up "embedder" in "/tmp/embedmetabdh0elkd/embedder".
# INFO: [Node] Setting-up "embedder" in "/tmp/embedmetabdh0elkd/embedder".
# 220613-16:21:05,456 nipype.workflow INFO:
# 	 [Node] Running "embedder" ("nipype.interfaces.utility.wrappers.Function")
# INFO: [Node] Running "embedder" ("nipype.interfaces.utility.wrappers.Function")
# 220613-16:21:30,54 nipype.workflow WARNING:
# 	 Storing result file without outputs
# WARNING: Storing result file without outputs
# 220613-16:21:30,56 nipype.workflow WARNING:
# 	 [Node] Error on "embedder" (/tmp/embedmetabdh0elkd/embedder)
# WARNING: [Node] Error on "embedder" (/tmp/embedmetabdh0elkd/embedder)
# ERROR: Embedding failed: 'NoneType' object is not subscriptable
# INFO: Post-treating /base/data/bids_data/sub-GEO015/ses-t3/func/sub-GEO015_ses-t3_task-image_run-5_bold.json file
# INFO: Converting /base/data/bids_data/sub-GEO015/ses-t3/func/sub-GEO015_ses-t3_task-retrans_run-1_bold (484 DICOMs) -> /base/data/bids_data/sub-GEO015/ses-t3/func . Converter: dcm2niix . Output types: ('nii.gz',)
# 220613-16:21:32,141 nipype.workflow INFO:
# 	 [Node] Setting-up "convert" in "/tmp/dcm2niix4glxj1sf/convert".
# INFO: [Node] Setting-up "convert" in "/tmp/dcm2niix4glxj1sf/convert".
# 220613-16:21:32,310 nipype.workflow INFO:
# 	 [Node] Running "convert" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z y -x n -t n -m n -f /base/data/bids_data/sub-GEO015/ses-t3/func/sub-GEO015_ses-t3_task-retrans_run-1_bold -o . -s n -v n /tmp/dcm2niix4glxj1sf/convert
# INFO: [Node] Running "convert" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z y -x n -t n -m n -f /base/data/bids_data/sub-GEO015/ses-t3/func/sub-GEO015_ses-t3_task-retrans_run-1_bold -o . -s n -v n /tmp/dcm2niix4glxj1sf/convert
# 220613-16:21:35,195 nipype.interface INFO:
# 	 stdout 2022-06-13T16:21:35.195660:Chris Rorden's dcm2niiX version v1.0.20190410  GCC6.3.0 (64-bit Linux)
# INFO: stdout 2022-06-13T16:21:35.195660:Chris Rorden's dcm2niiX version v1.0.20190410  GCC6.3.0 (64-bit Linux)
# 220613-16:21:35,196 nipype.interface INFO:
# 	 stdout 2022-06-13T16:21:35.195660:Found 484 DICOM file(s)
# INFO: stdout 2022-06-13T16:21:35.195660:Found 484 DICOM file(s)
# 220613-16:21:35,196 nipype.interface INFO:
# 	 stdout 2022-06-13T16:21:35.195660:slices stacked despite varying acquisition numbers (if this is not desired recompile with 'mySegmentByAcq')
# INFO: stdout 2022-06-13T16:21:35.195660:slices stacked despite varying acquisition numbers (if this is not desired recompile with 'mySegmentByAcq')
# 220613-16:21:35,196 nipype.interface INFO:
# 	 stdout 2022-06-13T16:21:35.195660:Convert 484 DICOM as ./base/data/bids_data/sub-GEO015/ses-t3/func/sub-GEO015_ses-t3_task-retrans_run-1_bold (84x84x56x484)
# INFO: stdout 2022-06-13T16:21:35.195660:Convert 484 DICOM as ./base/data/bids_data/sub-GEO015/ses-t3/func/sub-GEO015_ses-t3_task-retrans_run-1_bold (84x84x56x484)
# 220613-16:21:38,981 nipype.interface INFO:
# 	 stdout 2022-06-13T16:21:38.981636:Compress: "/usr/bin/pigz" -b 960 -n -f -6 "./base/data/bids_data/sub-GEO015/ses-t3/func/sub-GEO015_ses-t3_task-retrans_run-1_bold.nii"
# INFO: stdout 2022-06-13T16:21:38.981636:Compress: "/usr/bin/pigz" -b 960 -n -f -6 "./base/data/bids_data/sub-GEO015/ses-t3/func/sub-GEO015_ses-t3_task-retrans_run-1_bold.nii"
# 220613-16:21:38,981 nipype.interface INFO:
# 	 stdout 2022-06-13T16:21:38.981636:Conversion required 6.532103 seconds (2.243167 for core code).
# INFO: stdout 2022-06-13T16:21:38.981636:Conversion required 6.532103 seconds (2.243167 for core code).
# 220613-16:21:39,107 nipype.workflow INFO:
# 	 [Node] Finished "convert".
# INFO: [Node] Finished "convert".
# 220613-16:21:41,214 nipype.workflow INFO:
# 	 [Node] Setting-up "embedder" in "/tmp/embedmetacb7ga7i9/embedder".
# INFO: [Node] Setting-up "embedder" in "/tmp/embedmetacb7ga7i9/embedder".
# 220613-16:21:41,262 nipype.workflow INFO:
# 	 [Node] Running "embedder" ("nipype.interfaces.utility.wrappers.Function")
# INFO: [Node] Running "embedder" ("nipype.interfaces.utility.wrappers.Function")
# 220613-16:22:12,291 nipype.workflow WARNING:
# 	 Storing result file without outputs
# WARNING: Storing result file without outputs
# 220613-16:22:12,293 nipype.workflow WARNING:
# 	 [Node] Error on "embedder" (/tmp/embedmetacb7ga7i9/embedder)
# WARNING: [Node] Error on "embedder" (/tmp/embedmetacb7ga7i9/embedder)
# ERROR: Embedding failed: 'NoneType' object is not subscriptable
# INFO: Post-treating /base/data/bids_data/sub-GEO015/ses-t3/func/sub-GEO015_ses-t3_task-retrans_run-1_bold.json file
# INFO: Converting /base/data/bids_data/sub-GEO015/ses-t3/fmaps/sub-GEO015_ses-t3_acq-1_epi (120 DICOMs) -> /base/data/bids_data/sub-GEO015/ses-t3/fmaps . Converter: dcm2niix . Output types: ('nii.gz',)
# 220613-16:22:13,114 nipype.workflow INFO:
# 	 [Node] Setting-up "convert" in "/tmp/dcm2niixl8triydz/convert".
# INFO: [Node] Setting-up "convert" in "/tmp/dcm2niixl8triydz/convert".
# 220613-16:22:13,158 nipype.workflow INFO:
# 	 [Node] Running "convert" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z y -x n -t n -m n -f /base/data/bids_data/sub-GEO015/ses-t3/fmaps/sub-GEO015_ses-t3_acq-1_epi -o . -s n -v n /tmp/dcm2niixl8triydz/convert
# INFO: [Node] Running "convert" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z y -x n -t n -m n -f /base/data/bids_data/sub-GEO015/ses-t3/fmaps/sub-GEO015_ses-t3_acq-1_epi -o . -s n -v n /tmp/dcm2niixl8triydz/convert
# 220613-16:22:13,660 nipype.interface INFO:
# 	 stdout 2022-06-13T16:22:13.660641:Chris Rorden's dcm2niiX version v1.0.20190410  GCC6.3.0 (64-bit Linux)
# INFO: stdout 2022-06-13T16:22:13.660641:Chris Rorden's dcm2niiX version v1.0.20190410  GCC6.3.0 (64-bit Linux)
# 220613-16:22:13,661 nipype.interface INFO:
# 	 stdout 2022-06-13T16:22:13.660641:Found 120 DICOM file(s)
# INFO: stdout 2022-06-13T16:22:13.660641:Found 120 DICOM file(s)
# 220613-16:22:13,661 nipype.interface INFO:
# 	 stdout 2022-06-13T16:22:13.660641:slices not stacked: echo varies (TE 4.12, 6.58; echo 1, 2). Use 'merge 2D slices' option to force stacking
# INFO: stdout 2022-06-13T16:22:13.660641:slices not stacked: echo varies (TE 4.12, 6.58; echo 1, 2). Use 'merge 2D slices' option to force stacking
# 220613-16:22:13,661 nipype.interface INFO:
# 	 stdout 2022-06-13T16:22:13.660641:Convert 60 DICOM as ./base/data/bids_data/sub-GEO015/ses-t3/fmaps/sub-GEO015_ses-t3_acq-1_epi_e1 (80x80x60x1)
# INFO: stdout 2022-06-13T16:22:13.660641:Convert 60 DICOM as ./base/data/bids_data/sub-GEO015/ses-t3/fmaps/sub-GEO015_ses-t3_acq-1_epi_e1 (80x80x60x1)
# 220613-16:22:13,718 nipype.interface INFO:
# 	 stdout 2022-06-13T16:22:13.718539:Compress: "/usr/bin/pigz" -n -f -6 "./base/data/bids_data/sub-GEO015/ses-t3/fmaps/sub-GEO015_ses-t3_acq-1_epi_e1.nii"
# INFO: stdout 2022-06-13T16:22:13.718539:Compress: "/usr/bin/pigz" -n -f -6 "./base/data/bids_data/sub-GEO015/ses-t3/fmaps/sub-GEO015_ses-t3_acq-1_epi_e1.nii"
# 220613-16:22:13,718 nipype.interface INFO:
# 	 stdout 2022-06-13T16:22:13.718539:Convert 60 DICOM as ./base/data/bids_data/sub-GEO015/ses-t3/fmaps/sub-GEO015_ses-t3_acq-1_epi_e2 (80x80x60x1)
# INFO: stdout 2022-06-13T16:22:13.718539:Convert 60 DICOM as ./base/data/bids_data/sub-GEO015/ses-t3/fmaps/sub-GEO015_ses-t3_acq-1_epi_e2 (80x80x60x1)
# 220613-16:22:13,740 nipype.interface INFO:
# 	 stdout 2022-06-13T16:22:13.740168:Compress: "/usr/bin/pigz" -n -f -6 "./base/data/bids_data/sub-GEO015/ses-t3/fmaps/sub-GEO015_ses-t3_acq-1_epi_e2.nii"
# INFO: stdout 2022-06-13T16:22:13.740168:Compress: "/usr/bin/pigz" -n -f -6 "./base/data/bids_data/sub-GEO015/ses-t3/fmaps/sub-GEO015_ses-t3_acq-1_epi_e2.nii"
# 220613-16:22:13,740 nipype.interface INFO:
# 	 stdout 2022-06-13T16:22:13.740168:Conversion required 0.435832 seconds (0.157654 for core code).
# INFO: stdout 2022-06-13T16:22:13.740168:Conversion required 0.435832 seconds (0.157654 for core code).
# 220613-16:22:13,823 nipype.workflow INFO:
# 	 [Node] Finished "convert".
# INFO: [Node] Finished "convert".
# WARNING: Failed to find task field in /base/data/bids_data/sub-GEO015/ses-t3/fmaps/sub-GEO015_ses-t3_acq-1_echo-1_epi.json.
# WARNING: Failed to find task field in /base/data/bids_data/sub-GEO015/ses-t3/fmaps/sub-GEO015_ses-t3_acq-1_echo-2_epi.json.
# WARNING: For now not embedding BIDS and info generated .nii.gz itself since sequence produced multiple files
# INFO: Converting /base/data/bids_data/sub-GEO015/ses-t3/fmaps/sub-GEO015_ses-t3_acq-2_epi (60 DICOMs) -> /base/data/bids_data/sub-GEO015/ses-t3/fmaps . Converter: dcm2niix . Output types: ('nii.gz',)
# 220613-16:22:14,335 nipype.workflow INFO:
# 	 [Node] Setting-up "convert" in "/tmp/dcm2niixxrsv3beb/convert".
# INFO: [Node] Setting-up "convert" in "/tmp/dcm2niixxrsv3beb/convert".
# 220613-16:22:14,363 nipype.workflow INFO:
# 	 [Node] Running "convert" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z y -x n -t n -m n -f /base/data/bids_data/sub-GEO015/ses-t3/fmaps/sub-GEO015_ses-t3_acq-2_epi -o . -s n -v n /tmp/dcm2niixxrsv3beb/convert
# INFO: [Node] Running "convert" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z y -x n -t n -m n -f /base/data/bids_data/sub-GEO015/ses-t3/fmaps/sub-GEO015_ses-t3_acq-2_epi -o . -s n -v n /tmp/dcm2niixxrsv3beb/convert
# 220613-16:22:14,667 nipype.interface INFO:
# 	 stdout 2022-06-13T16:22:14.666916:Chris Rorden's dcm2niiX version v1.0.20190410  GCC6.3.0 (64-bit Linux)
# INFO: stdout 2022-06-13T16:22:14.666916:Chris Rorden's dcm2niiX version v1.0.20190410  GCC6.3.0 (64-bit Linux)
# 220613-16:22:14,667 nipype.interface INFO:
# 	 stdout 2022-06-13T16:22:14.666916:Found 60 DICOM file(s)
# INFO: stdout 2022-06-13T16:22:14.666916:Found 60 DICOM file(s)
# 220613-16:22:14,667 nipype.interface INFO:
# 	 stdout 2022-06-13T16:22:14.666916:Convert 60 DICOM as ./base/data/bids_data/sub-GEO015/ses-t3/fmaps/sub-GEO015_ses-t3_acq-2_epi_e2_ph (80x80x60x1)
# INFO: stdout 2022-06-13T16:22:14.666916:Convert 60 DICOM as ./base/data/bids_data/sub-GEO015/ses-t3/fmaps/sub-GEO015_ses-t3_acq-2_epi_e2_ph (80x80x60x1)
# 220613-16:22:14,685 nipype.interface INFO:
# 	 stdout 2022-06-13T16:22:14.685949:Compress: "/usr/bin/pigz" -n -f -6 "./base/data/bids_data/sub-GEO015/ses-t3/fmaps/sub-GEO015_ses-t3_acq-2_epi_e2_ph.nii"
# INFO: stdout 2022-06-13T16:22:14.685949:Compress: "/usr/bin/pigz" -n -f -6 "./base/data/bids_data/sub-GEO015/ses-t3/fmaps/sub-GEO015_ses-t3_acq-2_epi_e2_ph.nii"
# 220613-16:22:14,686 nipype.interface INFO:
# 	 stdout 2022-06-13T16:22:14.685949:Conversion required 0.205303 seconds (0.072932 for core code).
# INFO: stdout 2022-06-13T16:22:14.685949:Conversion required 0.205303 seconds (0.072932 for core code).
# 220613-16:22:14,714 nipype.workflow INFO:
# 	 [Node] Finished "convert".
# INFO: [Node] Finished "convert".
# WARNING: Failed to find task field in /base/data/bids_data/sub-GEO015/ses-t3/fmaps/sub-GEO015_ses-t3_acq-2_epi.json.
# 220613-16:22:14,855 nipype.workflow INFO:
# 	 [Node] Setting-up "embedder" in "/tmp/embedmeta4yfd4rak/embedder".
# INFO: [Node] Setting-up "embedder" in "/tmp/embedmeta4yfd4rak/embedder".
# 220613-16:22:14,869 nipype.workflow INFO:
# 	 [Node] Running "embedder" ("nipype.interfaces.utility.wrappers.Function")
# INFO: [Node] Running "embedder" ("nipype.interfaces.utility.wrappers.Function")
# 220613-16:22:17,292 nipype.workflow WARNING:
# 	 Storing result file without outputs
# WARNING: Storing result file without outputs
# 220613-16:22:17,292 nipype.workflow WARNING:
# 	 [Node] Error on "embedder" (/tmp/embedmeta4yfd4rak/embedder)
# WARNING: [Node] Error on "embedder" (/tmp/embedmeta4yfd4rak/embedder)
# ERROR: Embedding failed: 'NoneType' object is not subscriptable
# INFO: Post-treating /base/data/bids_data/sub-GEO015/ses-t3/fmaps/sub-GEO015_ses-t3_acq-2_epi.json file
# INFO: Lock 140455625262920 acquired on /base/data/bids_data/heudiconv.lock
# INFO: Populating template files under /base/data/bids_data/
# INFO: Lock 140455625262920 released on /base/data/bids_data/heudiconv.lock
# INFO: PROCESSING DONE: {'subject': 'GEO015', 'outdir': '/base/data/bids_data/', 'session': 't3'}
# ~~~~=====~~~~ Sub GEO015 Completed ~~~~=====~~~~
# -------------- Creating: GEO033 -------------
# /data00/projects/geoscan_v2/scripts/BIDS/jobs/heudiconv_GEO033.job
# INFO: Running heudiconv version 0.8.0 latest 0.11.3
# INFO: Need to process 1 study sessions
# INFO: PROCESSING STARTS: {'subject': 'GEO033', 'outdir': '/base/data/bids_data/', 'session': 't3'}
# INFO: Processing 2320 dicoms
# INFO: Analyzing 2320 dicoms
# INFO: Generated sequence info for 8 studies with 2320 entries total
# INFO: Doing conversion using dcm2niix
# INFO: Converting /base/data/bids_data/sub-GEO033/ses-t3/anat/sub-GEO033_ses-t3_T1w (160 DICOMs) -> /base/data/bids_data/sub-GEO033/ses-t3/anat . Converter: dcm2niix . Output types: ('nii.gz',)
# 220613-16:26:49,875 nipype.utils INFO:
# 	 Running nipype version 1.4.2 (latest: 1.8.1)
# INFO: Running nipype version 1.4.2 (latest: 1.8.1)
# 220613-16:26:49,904 nipype.workflow INFO:
# 	 [Node] Setting-up "convert" in "/tmp/dcm2niixmvc5rm7o/convert".
# INFO: [Node] Setting-up "convert" in "/tmp/dcm2niixmvc5rm7o/convert".
# 220613-16:26:49,969 nipype.workflow INFO:
# 	 [Node] Running "convert" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z y -x n -t n -m n -f /base/data/bids_data/sub-GEO033/ses-t3/anat/sub-GEO033_ses-t3_T1w -o . -s n -v n /tmp/dcm2niixmvc5rm7o/convert
# INFO: [Node] Running "convert" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z y -x n -t n -m n -f /base/data/bids_data/sub-GEO033/ses-t3/anat/sub-GEO033_ses-t3_T1w -o . -s n -v n /tmp/dcm2niixmvc5rm7o/convert
# 220613-16:26:50,499 nipype.interface INFO:
# 	 stdout 2022-06-13T16:26:50.498773:Chris Rorden's dcm2niiX version v1.0.20190410  GCC6.3.0 (64-bit Linux)
# INFO: stdout 2022-06-13T16:26:50.498773:Chris Rorden's dcm2niiX version v1.0.20190410  GCC6.3.0 (64-bit Linux)
# 220613-16:26:50,499 nipype.interface INFO:
# 	 stdout 2022-06-13T16:26:50.498773:Found 160 DICOM file(s)
# INFO: stdout 2022-06-13T16:26:50.498773:Found 160 DICOM file(s)
# 220613-16:26:50,499 nipype.interface INFO:
# 	 stdout 2022-06-13T16:26:50.498773:Convert 160 DICOM as ./base/data/bids_data/sub-GEO033/ses-t3/anat/sub-GEO033_ses-t3_T1w (192x256x160x1)
# INFO: stdout 2022-06-13T16:26:50.498773:Convert 160 DICOM as ./base/data/bids_data/sub-GEO033/ses-t3/anat/sub-GEO033_ses-t3_T1w (192x256x160x1)
# 220613-16:26:50,867 nipype.interface INFO:
# 	 stdout 2022-06-13T16:26:50.867630:Compress: "/usr/bin/pigz" -b 960 -n -f -6 "./base/data/bids_data/sub-GEO033/ses-t3/anat/sub-GEO033_ses-t3_T1w.nii"
# INFO: stdout 2022-06-13T16:26:50.867630:Compress: "/usr/bin/pigz" -b 960 -n -f -6 "./base/data/bids_data/sub-GEO033/ses-t3/anat/sub-GEO033_ses-t3_T1w.nii"
# 220613-16:26:50,867 nipype.interface INFO:
# 	 stdout 2022-06-13T16:26:50.867630:Conversion required 0.788760 seconds (0.243110 for core code).
# INFO: stdout 2022-06-13T16:26:50.867630:Conversion required 0.788760 seconds (0.243110 for core code).
# 220613-16:26:50,906 nipype.workflow INFO:
# 	 [Node] Finished "convert".
# INFO: [Node] Finished "convert".
# WARNING: Failed to find task field in /base/data/bids_data/sub-GEO033/ses-t3/anat/sub-GEO033_ses-t3_T1w.json.
# 220613-16:26:51,222 nipype.workflow INFO:
# 	 [Node] Setting-up "embedder" in "/tmp/embedmetacsbu0d3s/embedder".
# INFO: [Node] Setting-up "embedder" in "/tmp/embedmetacsbu0d3s/embedder".
# 220613-16:26:51,262 nipype.workflow INFO:
# 	 [Node] Running "embedder" ("nipype.interfaces.utility.wrappers.Function")
# INFO: [Node] Running "embedder" ("nipype.interfaces.utility.wrappers.Function")
# 220613-16:26:55,919 nipype.workflow WARNING:
# 	 Storing result file without outputs
# WARNING: Storing result file without outputs
# 220613-16:26:55,921 nipype.workflow WARNING:
# 	 [Node] Error on "embedder" (/tmp/embedmetacsbu0d3s/embedder)
# WARNING: [Node] Error on "embedder" (/tmp/embedmetacsbu0d3s/embedder)
# ERROR: Embedding failed: 'NoneType' object is not subscriptable
# INFO: Post-treating /base/data/bids_data/sub-GEO033/ses-t3/anat/sub-GEO033_ses-t3_T1w.json file
# INFO: Converting /base/data/bids_data/sub-GEO033/ses-t3/anat/sub-GEO033_ses-t3_T2w (176 DICOMs) -> /base/data/bids_data/sub-GEO033/ses-t3/anat . Converter: dcm2niix . Output types: ('nii.gz',)
# 220613-16:26:56,78 nipype.workflow INFO:
# 	 [Node] Setting-up "convert" in "/tmp/dcm2niixm7pw0536/convert".
# INFO: [Node] Setting-up "convert" in "/tmp/dcm2niixm7pw0536/convert".
# 220613-16:26:56,144 nipype.workflow INFO:
# 	 [Node] Running "convert" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z y -x n -t n -m n -f /base/data/bids_data/sub-GEO033/ses-t3/anat/sub-GEO033_ses-t3_T2w -o . -s n -v n /tmp/dcm2niixm7pw0536/convert
# INFO: [Node] Running "convert" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z y -x n -t n -m n -f /base/data/bids_data/sub-GEO033/ses-t3/anat/sub-GEO033_ses-t3_T2w -o . -s n -v n /tmp/dcm2niixm7pw0536/convert
# 220613-16:26:56,649 nipype.interface INFO:
# 	 stdout 2022-06-13T16:26:56.649563:Chris Rorden's dcm2niiX version v1.0.20190410  GCC6.3.0 (64-bit Linux)
# INFO: stdout 2022-06-13T16:26:56.649563:Chris Rorden's dcm2niiX version v1.0.20190410  GCC6.3.0 (64-bit Linux)
# 220613-16:26:56,650 nipype.interface INFO:
# 	 stdout 2022-06-13T16:26:56.649563:Found 176 DICOM file(s)
# INFO: stdout 2022-06-13T16:26:56.649563:Found 176 DICOM file(s)
# 220613-16:26:56,650 nipype.interface INFO:
# 	 stdout 2022-06-13T16:26:56.649563:Convert 176 DICOM as ./base/data/bids_data/sub-GEO033/ses-t3/anat/sub-GEO033_ses-t3_T2w (256x256x176x1)
# INFO: stdout 2022-06-13T16:26:56.649563:Convert 176 DICOM as ./base/data/bids_data/sub-GEO033/ses-t3/anat/sub-GEO033_ses-t3_T2w (256x256x176x1)
# 220613-16:26:57,107 nipype.interface INFO:
# 	 stdout 2022-06-13T16:26:57.107312:Compress: "/usr/bin/pigz" -b 960 -n -f -6 "./base/data/bids_data/sub-GEO033/ses-t3/anat/sub-GEO033_ses-t3_T2w.nii"
# INFO: stdout 2022-06-13T16:26:57.107312:Compress: "/usr/bin/pigz" -b 960 -n -f -6 "./base/data/bids_data/sub-GEO033/ses-t3/anat/sub-GEO033_ses-t3_T2w.nii"
# 220613-16:26:57,107 nipype.interface INFO:
# 	 stdout 2022-06-13T16:26:57.107312:Conversion required 0.939104 seconds (0.339632 for core code).
# INFO: stdout 2022-06-13T16:26:57.107312:Conversion required 0.939104 seconds (0.339632 for core code).
# 220613-16:26:57,158 nipype.workflow INFO:
# 	 [Node] Finished "convert".
# INFO: [Node] Finished "convert".
# WARNING: Failed to find task field in /base/data/bids_data/sub-GEO033/ses-t3/anat/sub-GEO033_ses-t3_T2w.json.
# 220613-16:26:58,62 nipype.workflow INFO:
# 	 [Node] Setting-up "embedder" in "/tmp/embedmetawya8bxvd/embedder".
# INFO: [Node] Setting-up "embedder" in "/tmp/embedmetawya8bxvd/embedder".
# 220613-16:26:58,82 nipype.workflow INFO:
# 	 [Node] Running "embedder" ("nipype.interfaces.utility.wrappers.Function")
# INFO: [Node] Running "embedder" ("nipype.interfaces.utility.wrappers.Function")
# 220613-16:27:03,592 nipype.workflow WARNING:
# 	 Storing result file without outputs
# WARNING: Storing result file without outputs
# 220613-16:27:03,594 nipype.workflow WARNING:
# 	 [Node] Error on "embedder" (/tmp/embedmetawya8bxvd/embedder)
# WARNING: [Node] Error on "embedder" (/tmp/embedmetawya8bxvd/embedder)
# ERROR: Embedding failed: 'NoneType' object is not subscriptable
# INFO: Post-treating /base/data/bids_data/sub-GEO033/ses-t3/anat/sub-GEO033_ses-t3_T2w.json file
# INFO: Converting /base/data/bids_data/sub-GEO033/ses-t3/func/sub-GEO033_ses-t3_task-image_run-1_bold (395 DICOMs) -> /base/data/bids_data/sub-GEO033/ses-t3/func . Converter: dcm2niix . Output types: ('nii.gz',)
# 220613-16:27:03,962 nipype.workflow INFO:
# 	 [Node] Setting-up "convert" in "/tmp/dcm2niixo1t71f0k/convert".
# INFO: [Node] Setting-up "convert" in "/tmp/dcm2niixo1t71f0k/convert".
# 220613-16:27:04,112 nipype.workflow INFO:
# 	 [Node] Running "convert" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z y -x n -t n -m n -f /base/data/bids_data/sub-GEO033/ses-t3/func/sub-GEO033_ses-t3_task-image_run-1_bold -o . -s n -v n /tmp/dcm2niixo1t71f0k/convert
# INFO: [Node] Running "convert" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z y -x n -t n -m n -f /base/data/bids_data/sub-GEO033/ses-t3/func/sub-GEO033_ses-t3_task-image_run-1_bold -o . -s n -v n /tmp/dcm2niixo1t71f0k/convert
# 220613-16:27:06,386 nipype.interface INFO:
# 	 stdout 2022-06-13T16:27:06.386831:Chris Rorden's dcm2niiX version v1.0.20190410  GCC6.3.0 (64-bit Linux)
# INFO: stdout 2022-06-13T16:27:06.386831:Chris Rorden's dcm2niiX version v1.0.20190410  GCC6.3.0 (64-bit Linux)
# 220613-16:27:06,387 nipype.interface INFO:
# 	 stdout 2022-06-13T16:27:06.386831:Found 395 DICOM file(s)
# INFO: stdout 2022-06-13T16:27:06.386831:Found 395 DICOM file(s)
# 220613-16:27:06,387 nipype.interface INFO:
# 	 stdout 2022-06-13T16:27:06.386831:slices stacked despite varying acquisition numbers (if this is not desired recompile with 'mySegmentByAcq')
# INFO: stdout 2022-06-13T16:27:06.386831:slices stacked despite varying acquisition numbers (if this is not desired recompile with 'mySegmentByAcq')
# 220613-16:27:06,387 nipype.interface INFO:
# 	 stdout 2022-06-13T16:27:06.386831:Convert 395 DICOM as ./base/data/bids_data/sub-GEO033/ses-t3/func/sub-GEO033_ses-t3_task-image_run-1_bold (84x84x56x395)
# INFO: stdout 2022-06-13T16:27:06.386831:Convert 395 DICOM as ./base/data/bids_data/sub-GEO033/ses-t3/func/sub-GEO033_ses-t3_task-image_run-1_bold (84x84x56x395)
# 220613-16:27:09,655 nipype.interface INFO:
# 	 stdout 2022-06-13T16:27:09.655342:Compress: "/usr/bin/pigz" -b 960 -n -f -6 "./base/data/bids_data/sub-GEO033/ses-t3/func/sub-GEO033_ses-t3_task-image_run-1_bold.nii"
# INFO: stdout 2022-06-13T16:27:09.655342:Compress: "/usr/bin/pigz" -b 960 -n -f -6 "./base/data/bids_data/sub-GEO033/ses-t3/func/sub-GEO033_ses-t3_task-image_run-1_bold.nii"
# 220613-16:27:09,655 nipype.interface INFO:
# 	 stdout 2022-06-13T16:27:09.655342:Conversion required 5.509444 seconds (1.813250 for core code).
# INFO: stdout 2022-06-13T16:27:09.655342:Conversion required 5.509444 seconds (1.813250 for core code).
# 220613-16:27:09,705 nipype.workflow INFO:
# 	 [Node] Finished "convert".
# INFO: [Node] Finished "convert".
# 220613-16:27:11,407 nipype.workflow INFO:
# 	 [Node] Setting-up "embedder" in "/tmp/embedmetaeo72h90k/embedder".
# INFO: [Node] Setting-up "embedder" in "/tmp/embedmetaeo72h90k/embedder".
# 220613-16:27:11,461 nipype.workflow INFO:
# 	 [Node] Running "embedder" ("nipype.interfaces.utility.wrappers.Function")
# INFO: [Node] Running "embedder" ("nipype.interfaces.utility.wrappers.Function")
# 220613-16:27:35,685 nipype.workflow WARNING:
# 	 Storing result file without outputs
# WARNING: Storing result file without outputs
# 220613-16:27:35,687 nipype.workflow WARNING:
# 	 [Node] Error on "embedder" (/tmp/embedmetaeo72h90k/embedder)
# WARNING: [Node] Error on "embedder" (/tmp/embedmetaeo72h90k/embedder)
# ERROR: Embedding failed: 'NoneType' object is not subscriptable
# INFO: Post-treating /base/data/bids_data/sub-GEO033/ses-t3/func/sub-GEO033_ses-t3_task-image_run-1_bold.json file
# ...
# 	 [Node] Setting-up "embedder" in "/tmp/embedmetasuvjdbrt/embedder".
# INFO: [Node] Setting-up "embedder" in "/tmp/embedmetasuvjdbrt/embedder".
# 220613-17:35:57,509 nipype.workflow INFO:
# 	 [Node] Running "embedder" ("nipype.interfaces.utility.wrappers.Function")
# INFO: [Node] Running "embedder" ("nipype.interfaces.utility.wrappers.Function")
# 220613-17:36:22,263 nipype.workflow WARNING:
# 	 Storing result file without outputs
# WARNING: Storing result file without outputs
# 220613-17:36:22,265 nipype.workflow WARNING:
# 	 [Node] Error on "embedder" (/tmp/embedmetasuvjdbrt/embedder)
# WARNING: [Node] Error on "embedder" (/tmp/embedmetasuvjdbrt/embedder)
# ERROR: Embedding failed: 'NoneType' object is not subscriptable
# INFO: Post-treating /base/data/bids_data/sub-GEO078/ses-t3/func/sub-GEO078_ses-t3_task-image_run-1_bold.json file
# INFO: Converting /base/data/bids_data/sub-GEO078/ses-t3/func/sub-GEO078_ses-t3_task-image_run-2_bold (395 DICOMs) -> /base/data/bids_data/sub-GEO078/ses-t3/func . Converter: dcm2niix . Output types: ('nii.gz',)
# 220613-17:36:23,946 nipype.workflow INFO:
# 	 [Node] Setting-up "convert" in "/tmp/dcm2niix91yicldi/convert".
# INFO: [Node] Setting-up "convert" in "/tmp/dcm2niix91yicldi/convert".
# 220613-17:36:24,101 nipype.workflow INFO:
# 	 [Node] Running "convert" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z y -x n -t n -m n -f /base/data/bids_data/sub-GEO078/ses-t3/func/sub-GEO078_ses-t3_task-image_run-2_bold -o . -s n -v n /tmp/dcm2niix91yicldi/convert
# INFO: [Node] Running "convert" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z y -x n -t n -m n -f /base/data/bids_data/sub-GEO078/ses-t3/func/sub-GEO078_ses-t3_task-image_run-2_bold -o . -s n -v n /tmp/dcm2niix91yicldi/convert
# 220613-17:36:26,455 nipype.interface INFO:
# 	 stdout 2022-06-13T17:36:26.455251:Chris Rorden's dcm2niiX version v1.0.20190410  GCC6.3.0 (64-bit Linux)
# INFO: stdout 2022-06-13T17:36:26.455251:Chris Rorden's dcm2niiX version v1.0.20190410  GCC6.3.0 (64-bit Linux)
# 220613-17:36:26,455 nipype.interface INFO:
# 	 stdout 2022-06-13T17:36:26.455251:Found 395 DICOM file(s)
# INFO: stdout 2022-06-13T17:36:26.455251:Found 395 DICOM file(s)
# 220613-17:36:26,455 nipype.interface INFO:
# 	 stdout 2022-06-13T17:36:26.455251:slices stacked despite varying acquisition numbers (if this is not desired recompile with 'mySegmentByAcq')
# INFO: stdout 2022-06-13T17:36:26.455251:slices stacked despite varying acquisition numbers (if this is not desired recompile with 'mySegmentByAcq')
# 220613-17:36:26,455 nipype.interface INFO:
# 	 stdout 2022-06-13T17:36:26.455251:Convert 395 DICOM as ./base/data/bids_data/sub-GEO078/ses-t3/func/sub-GEO078_ses-t3_task-image_run-2_bold (84x84x56x395)
# INFO: stdout 2022-06-13T17:36:26.455251:Convert 395 DICOM as ./base/data/bids_data/sub-GEO078/ses-t3/func/sub-GEO078_ses-t3_task-image_run-2_bold (84x84x56x395)
# 220613-17:36:29,925 nipype.interface INFO:
# 	 stdout 2022-06-13T17:36:29.925547:Compress: "/usr/bin/pigz" -b 960 -n -f -6 "./base/data/bids_data/sub-GEO078/ses-t3/func/sub-GEO078_ses-t3_task-image_run-2_bold.nii"
# INFO: stdout 2022-06-13T17:36:29.925547:Compress: "/usr/bin/pigz" -b 960 -n -f -6 "./base/data/bids_data/sub-GEO078/ses-t3/func/sub-GEO078_ses-t3_task-image_run-2_bold.nii"
# 220613-17:36:29,925 nipype.interface INFO:
# 	 stdout 2022-06-13T17:36:29.925547:Conversion required 5.689013 seconds (1.818500 for core code).
# INFO: stdout 2022-06-13T17:36:29.925547:Conversion required 5.689013 seconds (1.818500 for core code).
# 220613-17:36:29,998 nipype.workflow INFO:
# 	 [Node] Finished "convert".
# INFO: [Node] Finished "convert".
# 220613-17:36:31,239 nipype.workflow INFO:
# 	 [Node] Setting-up "embedder" in "/tmp/embedmetan030eevl/embedder".
# INFO: [Node] Setting-up "embedder" in "/tmp/embedmetan030eevl/embedder".
# 220613-17:36:31,292 nipype.workflow INFO:
# 	 [Node] Running "embedder" ("nipype.interfaces.utility.wrappers.Function")
# INFO: [Node] Running "embedder" ("nipype.interfaces.utility.wrappers.Function")
# 220613-17:36:55,905 nipype.workflow WARNING:
# 	 Storing result file without outputs
# WARNING: Storing result file without outputs
# 220613-17:36:55,907 nipype.workflow WARNING:
# 	 [Node] Error on "embedder" (/tmp/embedmetan030eevl/embedder)
# WARNING: [Node] Error on "embedder" (/tmp/embedmetan030eevl/embedder)
# ERROR: Embedding failed: 'NoneType' object is not subscriptable
# INFO: Post-treating /base/data/bids_data/sub-GEO078/ses-t3/func/sub-GEO078_ses-t3_task-image_run-2_bold.json file
# INFO: Converting /base/data/bids_data/sub-GEO078/ses-t3/func/sub-GEO078_ses-t3_task-image_run-3_bold (395 DICOMs) -> /base/data/bids_data/sub-GEO078/ses-t3/func . Converter: dcm2niix . Output types: ('nii.gz',)
# 220613-17:36:58,950 nipype.workflow INFO:
# 	 [Node] Setting-up "convert" in "/tmp/dcm2niixzlpk7vna/convert".
# INFO: [Node] Setting-up "convert" in "/tmp/dcm2niixzlpk7vna/convert".
# 220613-17:36:59,100 nipype.workflow INFO:
# 	 [Node] Running "convert" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z y -x n -t n -m n -f /base/data/bids_data/sub-GEO078/ses-t3/func/sub-GEO078_ses-t3_task-image_run-3_bold -o . -s n -v n /tmp/dcm2niixzlpk7vna/convert
# INFO: [Node] Running "convert" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z y -x n -t n -m n -f /base/data/bids_data/sub-GEO078/ses-t3/func/sub-GEO078_ses-t3_task-image_run-3_bold -o . -s n -v n /tmp/dcm2niixzlpk7vna/convert
# 220613-17:37:01,364 nipype.interface INFO:
# 	 stdout 2022-06-13T17:37:01.364668:Chris Rorden's dcm2niiX version v1.0.20190410  GCC6.3.0 (64-bit Linux)
# INFO: stdout 2022-06-13T17:37:01.364668:Chris Rorden's dcm2niiX version v1.0.20190410  GCC6.3.0 (64-bit Linux)
# 220613-17:37:01,365 nipype.interface INFO:
# 	 stdout 2022-06-13T17:37:01.364668:Found 395 DICOM file(s)
# INFO: stdout 2022-06-13T17:37:01.364668:Found 395 DICOM file(s)
# 220613-17:37:01,365 nipype.interface INFO:
# 	 stdout 2022-06-13T17:37:01.364668:slices stacked despite varying acquisition numbers (if this is not desired recompile with 'mySegmentByAcq')
# INFO: stdout 2022-06-13T17:37:01.364668:slices stacked despite varying acquisition numbers (if this is not desired recompile with 'mySegmentByAcq')
# 220613-17:37:01,365 nipype.interface INFO:
# 	 stdout 2022-06-13T17:37:01.364668:Convert 395 DICOM as ./base/data/bids_data/sub-GEO078/ses-t3/func/sub-GEO078_ses-t3_task-image_run-3_bold (84x84x56x395)
# INFO: stdout 2022-06-13T17:37:01.364668:Convert 395 DICOM as ./base/data/bids_data/sub-GEO078/ses-t3/func/sub-GEO078_ses-t3_task-image_run-3_bold (84x84x56x395)
# 220613-17:37:04,893 nipype.interface INFO:
# 	 stdout 2022-06-13T17:37:04.893747:Compress: "/usr/bin/pigz" -b 960 -n -f -6 "./base/data/bids_data/sub-GEO078/ses-t3/func/sub-GEO078_ses-t3_task-image_run-3_bold.nii"
# INFO: stdout 2022-06-13T17:37:04.893747:Compress: "/usr/bin/pigz" -b 960 -n -f -6 "./base/data/bids_data/sub-GEO078/ses-t3/func/sub-GEO078_ses-t3_task-image_run-3_bold.nii"
# 220613-17:37:04,894 nipype.interface INFO:
# 	 stdout 2022-06-13T17:37:04.893747:Conversion required 5.645959 seconds (1.758472 for core code).
# INFO: stdout 2022-06-13T17:37:04.893747:Conversion required 5.645959 seconds (1.758472 for core code).
# 220613-17:37:04,975 nipype.workflow INFO:
# 	 [Node] Finished "convert".
# INFO: [Node] Finished "convert".
# 220613-17:37:06,677 nipype.workflow INFO:
# 	 [Node] Setting-up "embedder" in "/tmp/embedmetaak1ld_fe/embedder".
# INFO: [Node] Setting-up "embedder" in "/tmp/embedmetaak1ld_fe/embedder".
# 220613-17:37:06,741 nipype.workflow INFO:
# 	 [Node] Running "embedder" ("nipype.interfaces.utility.wrappers.Function")
# INFO: [Node] Running "embedder" ("nipype.interfaces.utility.wrappers.Function")
# 220613-17:37:31,675 nipype.workflow WARNING:
# 	 Storing result file without outputs
# WARNING: Storing result file without outputs
# 220613-17:37:31,677 nipype.workflow WARNING:
# 	 [Node] Error on "embedder" (/tmp/embedmetaak1ld_fe/embedder)
# WARNING: [Node] Error on "embedder" (/tmp/embedmetaak1ld_fe/embedder)
# ERROR: Embedding failed: 'NoneType' object is not subscriptable
# INFO: Post-treating /base/data/bids_data/sub-GEO078/ses-t3/func/sub-GEO078_ses-t3_task-image_run-3_bold.json file
# INFO: Converting /base/data/bids_data/sub-GEO078/ses-t3/func/sub-GEO078_ses-t3_task-image_run-4_bold (395 DICOMs) -> /base/data/bids_data/sub-GEO078/ses-t3/func . Converter: dcm2niix . Output types: ('nii.gz',)
# 220613-17:37:33,506 nipype.workflow INFO:
# 	 [Node] Setting-up "convert" in "/tmp/dcm2niix2mcu7eab/convert".
# INFO: [Node] Setting-up "convert" in "/tmp/dcm2niix2mcu7eab/convert".
# 220613-17:37:33,655 nipype.workflow INFO:
# 	 [Node] Running "convert" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z y -x n -t n -m n -f /base/data/bids_data/sub-GEO078/ses-t3/func/sub-GEO078_ses-t3_task-image_run-4_bold -o . -s n -v n /tmp/dcm2niix2mcu7eab/convert
# INFO: [Node] Running "convert" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z y -x n -t n -m n -f /base/data/bids_data/sub-GEO078/ses-t3/func/sub-GEO078_ses-t3_task-image_run-4_bold -o . -s n -v n /tmp/dcm2niix2mcu7eab/convert
# 220613-17:37:35,937 nipype.interface INFO:
# 	 stdout 2022-06-13T17:37:35.937678:Chris Rorden's dcm2niiX version v1.0.20190410  GCC6.3.0 (64-bit Linux)
# INFO: stdout 2022-06-13T17:37:35.937678:Chris Rorden's dcm2niiX version v1.0.20190410  GCC6.3.0 (64-bit Linux)
# 220613-17:37:35,938 nipype.interface INFO:
# 	 stdout 2022-06-13T17:37:35.937678:Found 395 DICOM file(s)
# INFO: stdout 2022-06-13T17:37:35.937678:Found 395 DICOM file(s)
# 220613-17:37:35,938 nipype.interface INFO:
# 	 stdout 2022-06-13T17:37:35.937678:slices stacked despite varying acquisition numbers (if this is not desired recompile with 'mySegmentByAcq')
# INFO: stdout 2022-06-13T17:37:35.937678:slices stacked despite varying acquisition numbers (if this is not desired recompile with 'mySegmentByAcq')
# 220613-17:37:35,938 nipype.interface INFO:
# 	 stdout 2022-06-13T17:37:35.937678:Convert 395 DICOM as ./base/data/bids_data/sub-GEO078/ses-t3/func/sub-GEO078_ses-t3_task-image_run-4_bold (84x84x56x395)
# INFO: stdout 2022-06-13T17:37:35.937678:Convert 395 DICOM as ./base/data/bids_data/sub-GEO078/ses-t3/func/sub-GEO078_ses-t3_task-image_run-4_bold (84x84x56x395)
# 220613-17:37:39,370 nipype.interface INFO:
# 	 stdout 2022-06-13T17:37:39.370707:Compress: "/usr/bin/pigz" -b 960 -n -f -6 "./base/data/bids_data/sub-GEO078/ses-t3/func/sub-GEO078_ses-t3_task-image_run-4_bold.nii"
# INFO: stdout 2022-06-13T17:37:39.370707:Compress: "/usr/bin/pigz" -b 960 -n -f -6 "./base/data/bids_data/sub-GEO078/ses-t3/func/sub-GEO078_ses-t3_task-image_run-4_bold.nii"
# 220613-17:37:39,371 nipype.interface INFO:
# 	 stdout 2022-06-13T17:37:39.370707:Conversion required 5.574108 seconds (1.744732 for core code).
# INFO: stdout 2022-06-13T17:37:39.370707:Conversion required 5.574108 seconds (1.744732 for core code).
# 220613-17:37:39,458 nipype.workflow INFO:
# 	 [Node] Finished "convert".
# INFO: [Node] Finished "convert".
# 220613-17:37:40,779 nipype.workflow INFO:
# 	 [Node] Setting-up "embedder" in "/tmp/embedmetae8vh8d1x/embedder".
# INFO: [Node] Setting-up "embedder" in "/tmp/embedmetae8vh8d1x/embedder".
# 220613-17:37:40,821 nipype.workflow INFO:
# 	 [Node] Running "embedder" ("nipype.interfaces.utility.wrappers.Function")
# INFO: [Node] Running "embedder" ("nipype.interfaces.utility.wrappers.Function")
# 220613-17:38:06,78 nipype.workflow WARNING:
# 	 Storing result file without outputs
# WARNING: Storing result file without outputs
# 220613-17:38:06,80 nipype.workflow WARNING:
# 	 [Node] Error on "embedder" (/tmp/embedmetae8vh8d1x/embedder)
# WARNING: [Node] Error on "embedder" (/tmp/embedmetae8vh8d1x/embedder)
# ERROR: Embedding failed: 'NoneType' object is not subscriptable
# INFO: Post-treating /base/data/bids_data/sub-GEO078/ses-t3/func/sub-GEO078_ses-t3_task-image_run-4_bold.json file
# INFO: Converting /base/data/bids_data/sub-GEO078/ses-t3/func/sub-GEO078_ses-t3_task-image_run-5_bold (395 DICOMs) -> /base/data/bids_data/sub-GEO078/ses-t3/func . Converter: dcm2niix . Output types: ('nii.gz',)
# 220613-17:38:07,956 nipype.workflow INFO:
# 	 [Node] Setting-up "convert" in "/tmp/dcm2niixhaqxiruz/convert".
# INFO: [Node] Setting-up "convert" in "/tmp/dcm2niixhaqxiruz/convert".
# 220613-17:38:08,102 nipype.workflow INFO:
# 	 [Node] Running "convert" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z y -x n -t n -m n -f /base/data/bids_data/sub-GEO078/ses-t3/func/sub-GEO078_ses-t3_task-image_run-5_bold -o . -s n -v n /tmp/dcm2niixhaqxiruz/convert
# INFO: [Node] Running "convert" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z y -x n -t n -m n -f /base/data/bids_data/sub-GEO078/ses-t3/func/sub-GEO078_ses-t3_task-image_run-5_bold -o . -s n -v n /tmp/dcm2niixhaqxiruz/convert
# 220613-17:38:10,401 nipype.interface INFO:
# 	 stdout 2022-06-13T17:38:10.401658:Chris Rorden's dcm2niiX version v1.0.20190410  GCC6.3.0 (64-bit Linux)
# INFO: stdout 2022-06-13T17:38:10.401658:Chris Rorden's dcm2niiX version v1.0.20190410  GCC6.3.0 (64-bit Linux)
# 220613-17:38:10,402 nipype.interface INFO:
# 	 stdout 2022-06-13T17:38:10.401658:Found 395 DICOM file(s)
# INFO: stdout 2022-06-13T17:38:10.401658:Found 395 DICOM file(s)
# 220613-17:38:10,402 nipype.interface INFO:
# 	 stdout 2022-06-13T17:38:10.401658:slices stacked despite varying acquisition numbers (if this is not desired recompile with 'mySegmentByAcq')
# INFO: stdout 2022-06-13T17:38:10.401658:slices stacked despite varying acquisition numbers (if this is not desired recompile with 'mySegmentByAcq')
# 220613-17:38:10,402 nipype.interface INFO:
# 	 stdout 2022-06-13T17:38:10.401658:Convert 395 DICOM as ./base/data/bids_data/sub-GEO078/ses-t3/func/sub-GEO078_ses-t3_task-image_run-5_bold (84x84x56x395)
# INFO: stdout 2022-06-13T17:38:10.401658:Convert 395 DICOM as ./base/data/bids_data/sub-GEO078/ses-t3/func/sub-GEO078_ses-t3_task-image_run-5_bold (84x84x56x395)
# 220613-17:38:13,858 nipype.interface INFO:
# 	 stdout 2022-06-13T17:38:13.858633:Compress: "/usr/bin/pigz" -b 960 -n -f -6 "./base/data/bids_data/sub-GEO078/ses-t3/func/sub-GEO078_ses-t3_task-image_run-5_bold.nii"
# INFO: stdout 2022-06-13T17:38:13.858633:Compress: "/usr/bin/pigz" -b 960 -n -f -6 "./base/data/bids_data/sub-GEO078/ses-t3/func/sub-GEO078_ses-t3_task-image_run-5_bold.nii"
# 220613-17:38:13,858 nipype.interface INFO:
# 	 stdout 2022-06-13T17:38:13.858633:Conversion required 5.624602 seconds (1.766609 for core code).
# INFO: stdout 2022-06-13T17:38:13.858633:Conversion required 5.624602 seconds (1.766609 for core code).
# 220613-17:38:13,937 nipype.workflow INFO:
# 	 [Node] Finished "convert".
# INFO: [Node] Finished "convert".
# 220613-17:38:15,194 nipype.workflow INFO:
# 	 [Node] Setting-up "embedder" in "/tmp/embedmeta85inwkjn/embedder".
# INFO: [Node] Setting-up "embedder" in "/tmp/embedmeta85inwkjn/embedder".
# 220613-17:38:15,232 nipype.workflow INFO:
# 	 [Node] Running "embedder" ("nipype.interfaces.utility.wrappers.Function")
# INFO: [Node] Running "embedder" ("nipype.interfaces.utility.wrappers.Function")
# 220613-17:38:39,752 nipype.workflow WARNING:
# 	 Storing result file without outputs
# WARNING: Storing result file without outputs
# 220613-17:38:39,755 nipype.workflow WARNING:
# 	 [Node] Error on "embedder" (/tmp/embedmeta85inwkjn/embedder)
# WARNING: [Node] Error on "embedder" (/tmp/embedmeta85inwkjn/embedder)
# ERROR: Embedding failed: 'NoneType' object is not subscriptable
# INFO: Post-treating /base/data/bids_data/sub-GEO078/ses-t3/func/sub-GEO078_ses-t3_task-image_run-5_bold.json file
# INFO: Lock 140600311410024 acquired on /base/data/bids_data/heudiconv.lock
# INFO: Populating template files under /base/data/bids_data/
# INFO: Lock 140600311410024 released on /base/data/bids_data/heudiconv.lock
# INFO: PROCESSING DONE: {'subject': 'GEO078', 'outdir': '/base/data/bids_data/', 'session': 't3'}
# ~~~~=====~~~~ Sub GEO078 Completed ~~~~=====~~~~

# %% [markdown]
# ## Submit jobs using slurm
# The code below creates a job that can be run using slurm
#
# ### Define variables

# %%
project = 'Enter your project name here'
project_dir = os.path.join('/data00/projects/', project)
slurm_dir = os.path.join(project_dir, 'scripts/BIDS/jobs/heudiconv')
os.makedirs(slurm_dir, exist_ok=True)
subs = ['']

job_file_template = r'''#!/bin/bash
#SBATCH --job-name=heudiconv_{ID}.job
#SBATCH --output=out/heudiconv_{ID}.out
#SBATCH --error=out/heudiconv_{ID}.err
#SBATCH --time=02:00

srun singularity run --cleanenv \
    -B /data00/projects/{Your Project}:/base  \
    -B /fmriDataRaw/fmri_data_raw:/raw \
    /data00/tools/singularity_images/heudiconv_0.8.0 \
    -d /raw/{Your Project}/{ID}/*/*.dcm \
    -o /base/data/bids_data/ \
    -f heudiconv/code/heuristic.py -s {ID} -c dcm2niix -b --overwrite
'''

# %% [markdown]
# ### Loop through specified participants

# %%
for s in subs:
    print('-------------- Creating: {} -------------'.format(s))
    
    file_path = os.path.join(slurm_dir, 'heudiconv_{}.job').format(s)
    print(file_path)

    with open(file_path.format(s), 'w') as job:
        job.write(job_file_template.format(ID=s, subject='{subject}'))

# %% [markdown]
# ### Schedule the jobs on slurm
#
# Login to the slurm cluster:
#
# ```
# ssh <JANUS_UN>@asc.upenn.edu@cls000
# ```
#
# This will give you a terminal on the SLURM master node where you can look at the process queue and schedule jobs by pasting the output from the next chunk

# %%
print(f"cd {slurm_dir}")
for s in subs:
    print(f"sbatch -D {slurm_dir} -c 8 heudiconv_{s}.job")

# %%
# !ls /data00/slurm_jobs/slurm_bbprime/
