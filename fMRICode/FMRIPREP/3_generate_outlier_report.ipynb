# %% [markdown]
# # Generate outlier reports based on `fmriprep` outputs
#
#
#
# --------------------
#
#
# #### HISTORY
#
# * 27/9/2021 - created by hychan

# %%
import os, glob, imageio
import pandas as pd
import numpy as np

from nilearn import plotting, image
from sklearn.preprocessing import scale

import warnings 
warnings.simplefilter("ignore", UserWarning)
# Out:
# /usr/local/anaconda3/lib/python3.7/site-packages/nilearn/datasets/__init__.py:90: FutureWarning: Fetchers from the nilearn.datasets module will be updated in version 0.9 to return python strings instead of bytes and Pandas dataframes instead of Numpy arrays.
#   "Numpy arrays.", FutureWarning)

# %%
auto_motion_path = '/data00/tools/auto-motion-fmriprep'

fmriprep_path = '/data00/projects/geoscan_v2/data/bids_data/derivatives/fmriprep'
output_path = '/data00/projects/geoscan_v2/data/bids_data/derivatives/outlier'

nii_file = '../../data/bids_data/sub-{sub}/ses-t2/func/sub-{sub}_ses-t2_task-{task}_run-{run}_bold.nii.gz'

os.makedirs(output_path, exist_ok=True)

# %%
rules = {
    'gs>3': lambda df: np.abs(scale(df['global_signal'])) > 3,
    'fd>0.75': lambda df: df['framewise_displacement'] > 0.75
}

# %%
def extract_snakecase(bids_string):
    output = {}
    for key_value in bids_string.split("_"):
        if "-" in key_value:
            key, value = key_value.split('-')
            if key != "desc":
                output[key] = value
    return output

# %% [markdown]
# ## Automatic motion outlier detection
#
# Remember to update `confoundDir` and `outputDir` in `config.R`

# %%
cmd = f'cd {auto_motion_path} && Rscript auto_motion_fmriprep.R {os.path.abspath("config.R")}'
# !{cmd}
# Out:
# Loading required package: tidyverse
# Registered S3 methods overwritten by 'tibble':
#   method     from
#   format.tbl pillar
#   print.tbl  pillar
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.0 ──
# ✔ ggplot2 3.3.2     ✔ purrr   0.3.3
# ✔ tibble  2.1.3     ✔ dplyr   1.0.6
# ✔ tidyr   1.0.2     ✔ stringr 1.4.0
# ✔ readr   1.3.1     ✔ forcats 0.4.0
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# Loading required package: snakecase
# Loading required package: caret
# Loading required package: lattice
#
# Attaching package: ‘caret’
#
# The following object is masked from ‘package:purrr’:
#
#     lift
#
# Loading required package: randomForest
# randomForest 4.6-14
# Type rfNews() to see new features/changes/bug fixes.
#
# Attaching package: ‘randomForest’
#
# The following object is masked from ‘package:dplyr’:
#
#     combine
#
# The following object is masked from ‘package:ggplot2’:
#
#     margin
#
# --------Loading confound files--------
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   csf_derivative1 = col_character(),
#   csf_derivative1_power2 = col_character(),
#   white_matter_derivative1 = col_character(),
#   white_matter_derivative1_power2 = col_character(),
#   global_signal_derivative1 = col_character(),
#   global_signal_derivative1_power2 = col_character(),
#   std_dvars = col_character(),
#   dvars = col_character(),
#   framewise_displacement = col_character(),
#   trans_x_derivative1 = col_character(),
#   trans_x_derivative1_power2 = col_character(),
#   trans_y_derivative1 = col_character(),
#   trans_y_derivative1_power2 = col_character(),
#   trans_z_derivative1 = col_character(),
#   trans_z_derivative1_power2 = col_character(),
#   rot_x_derivative1 = col_character(),
#   rot_x_derivative1_power2 = col_character(),
#   rot_y_derivative1 = col_character(),
#   rot_y_derivative1_power2 = col_character(),
#   rot_z_derivative1 = col_character()
#   # ... with 1 more columns
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   csf_derivative1 = col_character(),
#   csf_derivative1_power2 = col_character(),
#   white_matter_derivative1 = col_character(),
#   white_matter_derivative1_power2 = col_character(),
#   global_signal_derivative1 = col_character(),
#   global_signal_derivative1_power2 = col_character(),
#   std_dvars = col_character(),
#   dvars = col_character(),
#   framewise_displacement = col_character(),
#   trans_x_derivative1 = col_character(),
#   trans_x_derivative1_power2 = col_character(),
#   trans_y_derivative1 = col_character(),
#   trans_y_derivative1_power2 = col_character(),
#   trans_z_derivative1 = col_character(),
#   trans_z_derivative1_power2 = col_character(),
#   rot_x_derivative1 = col_character(),
#   rot_x_derivative1_power2 = col_character(),
#   rot_y_derivative1 = col_character(),
#   rot_y_derivative1_power2 = col_character(),
#   rot_z_derivative1 = col_character()
#   # ... with 1 more columns
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   csf_derivative1 = col_character(),
#   csf_derivative1_power2 = col_character(),
#   white_matter_derivative1 = col_character(),
#   white_matter_derivative1_power2 = col_character(),
#   global_signal_derivative1 = col_character(),
#   global_signal_derivative1_power2 = col_character(),
#   std_dvars = col_character(),
#   dvars = col_character(),
#   framewise_displacement = col_character(),
#   trans_x_derivative1 = col_character(),
#   trans_x_derivative1_power2 = col_character(),
#   trans_y_derivative1 = col_character(),
#   trans_y_derivative1_power2 = col_character(),
#   trans_z_derivative1 = col_character(),
#   trans_z_derivative1_power2 = col_character(),
#   rot_x_derivative1 = col_character(),
#   rot_x_derivative1_power2 = col_character(),
#   rot_y_derivative1 = col_character(),
#   rot_y_derivative1_power2 = col_character(),
#   rot_z_derivative1 = col_character()
#   # ... with 1 more columns
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   csf_derivative1 = col_character(),
#   csf_derivative1_power2 = col_character(),
#   white_matter_derivative1 = col_character(),
#   white_matter_derivative1_power2 = col_character(),
#   global_signal_derivative1 = col_character(),
#   global_signal_derivative1_power2 = col_character(),
#   std_dvars = col_character(),
#   dvars = col_character(),
#   framewise_displacement = col_character(),
#   trans_x_derivative1 = col_character(),
#   trans_x_derivative1_power2 = col_character(),
#   trans_y_derivative1 = col_character(),
#   trans_y_derivative1_power2 = col_character(),
#   trans_z_derivative1 = col_character(),
#   trans_z_derivative1_power2 = col_character(),
#   rot_x_derivative1 = col_character(),
#   rot_x_derivative1_power2 = col_character(),
#   rot_y_derivative1 = col_character(),
#   rot_y_derivative1_power2 = col_character(),
#   rot_z_derivative1 = col_character()
#   # ... with 1 more columns
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   csf_derivative1 = col_character(),
#   csf_derivative1_power2 = col_character(),
#   white_matter_derivative1 = col_character(),
#   white_matter_derivative1_power2 = col_character(),
#   global_signal_derivative1 = col_character(),
#   global_signal_derivative1_power2 = col_character(),
#   std_dvars = col_character(),
#   dvars = col_character(),
#   framewise_displacement = col_character(),
#   trans_x_derivative1 = col_character(),
#   trans_x_derivative1_power2 = col_character(),
#   trans_y_derivative1 = col_character(),
#   trans_y_derivative1_power2 = col_character(),
#   trans_z_derivative1 = col_character(),
#   trans_z_derivative1_power2 = col_character(),
#   rot_x_derivative1 = col_character(),
#   rot_x_derivative1_power2 = col_character(),
#   rot_y_derivative1 = col_character(),
#   rot_y_derivative1_power2 = col_character(),
#   rot_z_derivative1 = col_character()
#   # ... with 1 more columns
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   csf_derivative1 = col_character(),
#   csf_derivative1_power2 = col_character(),
#   white_matter_derivative1 = col_character(),
#   white_matter_derivative1_power2 = col_character(),
#   global_signal_derivative1 = col_character(),
#   global_signal_derivative1_power2 = col_character(),
#   std_dvars = col_character(),
#   dvars = col_character(),
#   framewise_displacement = col_character(),
#   trans_x_derivative1 = col_character(),
#   trans_x_derivative1_power2 = col_character(),
#   trans_y_derivative1 = col_character(),
#   trans_y_derivative1_power2 = col_character(),
#   trans_z_derivative1 = col_character(),
#   trans_z_derivative1_power2 = col_character(),
#   rot_x_derivative1 = col_character(),
#   rot_x_derivative1_power2 = col_character(),
#   rot_y_derivative1 = col_character(),
#   rot_y_derivative1_power2 = col_character(),
#   rot_z_derivative1 = col_character()
#   # ... with 1 more columns
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   csf_derivative1 = col_character(),
#   csf_derivative1_power2 = col_character(),
#   white_matter_derivative1 = col_character(),
#   white_matter_derivative1_power2 = col_character(),
#   global_signal_derivative1 = col_character(),
#   global_signal_derivative1_power2 = col_character(),
#   std_dvars = col_character(),
#   dvars = col_character(),
#   framewise_displacement = col_character(),
#   trans_x_derivative1 = col_character(),
#   trans_x_derivative1_power2 = col_character(),
#   trans_y_derivative1 = col_character(),
#   trans_y_derivative1_power2 = col_character(),
#   trans_z_derivative1 = col_character(),
#   trans_z_derivative1_power2 = col_character(),
#   rot_x_derivative1 = col_character(),
#   rot_x_derivative1_power2 = col_character(),
#   rot_y_derivative1 = col_character(),
#   rot_y_derivative1_power2 = col_character(),
#   rot_z_derivative1 = col_character()
#   # ... with 1 more columns
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   csf_derivative1 = col_character(),
#   csf_derivative1_power2 = col_character(),
#   white_matter_derivative1 = col_character(),
#   white_matter_derivative1_power2 = col_character(),
#   global_signal_derivative1 = col_character(),
#   global_signal_derivative1_power2 = col_character(),
#   std_dvars = col_character(),
#   dvars = col_character(),
#   framewise_displacement = col_character(),
#   trans_x_derivative1 = col_character(),
#   trans_x_derivative1_power2 = col_character(),
#   trans_y_derivative1 = col_character(),
#   trans_y_derivative1_power2 = col_character(),
#   trans_z_derivative1 = col_character(),
#   trans_z_derivative1_power2 = col_character(),
#   rot_x_derivative1 = col_character(),
#   rot_x_derivative1_power2 = col_character(),
#   rot_y_derivative1 = col_character(),
#   rot_y_derivative1_power2 = col_character(),
#   rot_z_derivative1 = col_character()
#   # ... with 1 more columns
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   csf_derivative1 = col_character(),
#   csf_derivative1_power2 = col_character(),
#   white_matter_derivative1 = col_character(),
#   white_matter_derivative1_power2 = col_character(),
#   global_signal_derivative1 = col_character(),
#   global_signal_derivative1_power2 = col_character(),
#   std_dvars = col_character(),
#   dvars = col_character(),
#   framewise_displacement = col_character(),
#   trans_x_derivative1 = col_character(),
#   trans_x_derivative1_power2 = col_character(),
#   trans_y_derivative1 = col_character(),
#   trans_y_derivative1_power2 = col_character(),
#   trans_z_derivative1 = col_character(),
#   trans_z_derivative1_power2 = col_character(),
#   rot_x_derivative1 = col_character(),
#   rot_x_derivative1_power2 = col_character(),
#   rot_y_derivative1 = col_character(),
#   rot_y_derivative1_power2 = col_character(),
#   rot_z_derivative1 = col_character()
#   # ... with 1 more columns
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   csf_derivative1 = col_character(),
#   csf_derivative1_power2 = col_character(),
#   white_matter_derivative1 = col_character(),
#   white_matter_derivative1_power2 = col_character(),
#   global_signal_derivative1 = col_character(),
#   global_signal_derivative1_power2 = col_character(),
#   std_dvars = col_character(),
#   dvars = col_character(),
#   framewise_displacement = col_character(),
#   trans_x_derivative1 = col_character(),
#   trans_x_derivative1_power2 = col_character(),
#   trans_y_derivative1 = col_character(),
#   trans_y_derivative1_power2 = col_character(),
#   trans_z_derivative1 = col_character(),
#   trans_z_derivative1_power2 = col_character(),
#   rot_x_derivative1 = col_character(),
#   rot_x_derivative1_power2 = col_character(),
#   rot_y_derivative1 = col_character(),
#   rot_y_derivative1_power2 = col_character(),
#   rot_z_derivative1 = col_character()
#   # ... with 1 more columns
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   csf_derivative1 = col_character(),
#   csf_derivative1_power2 = col_character(),
#   white_matter_derivative1 = col_character(),
#   white_matter_derivative1_power2 = col_character(),
#   global_signal_derivative1 = col_character(),
#   global_signal_derivative1_power2 = col_character(),
#   std_dvars = col_character(),
#   dvars = col_character(),
#   framewise_displacement = col_character(),
#   trans_x_derivative1 = col_character(),
#   trans_x_derivative1_power2 = col_character(),
#   trans_y_derivative1 = col_character(),
#   trans_y_derivative1_power2 = col_character(),
#   trans_z_derivative1 = col_character(),
#   trans_z_derivative1_power2 = col_character(),
#   rot_x_derivative1 = col_character(),
#   rot_x_derivative1_power2 = col_character(),
#   rot_y_derivative1 = col_character(),
#   rot_y_derivative1_power2 = col_character(),
#   rot_z_derivative1 = col_character()
#   # ... with 1 more columns
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   csf_derivative1 = col_character(),
#   csf_derivative1_power2 = col_character(),
#   white_matter_derivative1 = col_character(),
#   white_matter_derivative1_power2 = col_character(),
#   global_signal_derivative1 = col_character(),
#   global_signal_derivative1_power2 = col_character(),
#   std_dvars = col_character(),
#   dvars = col_character(),
#   framewise_displacement = col_character(),
#   trans_x_derivative1 = col_character(),
#   trans_x_derivative1_power2 = col_character(),
#   trans_y_derivative1 = col_character(),
#   trans_y_derivative1_power2 = col_character(),
#   trans_z_derivative1 = col_character(),
#   trans_z_derivative1_power2 = col_character(),
#   rot_x_derivative1 = col_character(),
#   rot_x_derivative1_power2 = col_character(),
#   rot_y_derivative1 = col_character(),
#   rot_y_derivative1_power2 = col_character(),
#   rot_z_derivative1 = col_character()
#   # ... with 1 more columns
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   csf_derivative1 = col_character(),
#   csf_derivative1_power2 = col_character(),
#   white_matter_derivative1 = col_character(),
#   white_matter_derivative1_power2 = col_character(),
#   global_signal_derivative1 = col_character(),
#   global_signal_derivative1_power2 = col_character(),
#   std_dvars = col_character(),
#   dvars = col_character(),
#   framewise_displacement = col_character(),
#   trans_x_derivative1 = col_character(),
#   trans_x_derivative1_power2 = col_character(),
#   trans_y_derivative1 = col_character(),
#   trans_y_derivative1_power2 = col_character(),
#   trans_z_derivative1 = col_character(),
#   trans_z_derivative1_power2 = col_character(),
#   rot_x_derivative1 = col_character(),
#   rot_x_derivative1_power2 = col_character(),
#   rot_y_derivative1 = col_character(),
#   rot_y_derivative1_power2 = col_character(),
#   rot_z_derivative1 = col_character()
#   # ... with 1 more columns
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   csf_derivative1 = col_character(),
#   csf_derivative1_power2 = col_character(),
#   white_matter_derivative1 = col_character(),
#   white_matter_derivative1_power2 = col_character(),
#   global_signal_derivative1 = col_character(),
#   global_signal_derivative1_power2 = col_character(),
#   std_dvars = col_character(),
#   dvars = col_character(),
#   framewise_displacement = col_character(),
#   trans_x_derivative1 = col_character(),
#   trans_x_derivative1_power2 = col_character(),
#   trans_y_derivative1 = col_character(),
#   trans_y_derivative1_power2 = col_character(),
#   trans_z_derivative1 = col_character(),
#   trans_z_derivative1_power2 = col_character(),
#   rot_x_derivative1 = col_character(),
#   rot_x_derivative1_power2 = col_character(),
#   rot_y_derivative1 = col_character(),
#   rot_y_derivative1_power2 = col_character(),
#   rot_z_derivative1 = col_character()
#   # ... with 1 more columns
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   csf_derivative1 = col_character(),
#   csf_derivative1_power2 = col_character(),
#   white_matter_derivative1 = col_character(),
#   white_matter_derivative1_power2 = col_character(),
#   global_signal_derivative1 = col_character(),
#   global_signal_derivative1_power2 = col_character(),
#   std_dvars = col_character(),
#   dvars = col_character(),
#   framewise_displacement = col_character(),
#   trans_x_derivative1 = col_character(),
#   trans_x_derivative1_power2 = col_character(),
#   trans_y_derivative1 = col_character(),
#   trans_y_derivative1_power2 = col_character(),
#   trans_z_derivative1 = col_character(),
#   trans_z_derivative1_power2 = col_character(),
#   rot_x_derivative1 = col_character(),
#   rot_x_derivative1_power2 = col_character(),
#   rot_y_derivative1 = col_character(),
#   rot_y_derivative1_power2 = col_character(),
#   rot_z_derivative1 = col_character()
#   # ... with 1 more columns
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   csf_derivative1 = col_character(),
#   csf_derivative1_power2 = col_character(),
#   white_matter_derivative1 = col_character(),
#   white_matter_derivative1_power2 = col_character(),
#   global_signal_derivative1 = col_character(),
#   global_signal_derivative1_power2 = col_character(),
#   std_dvars = col_character(),
#   dvars = col_character(),
#   framewise_displacement = col_character(),
#   trans_x_derivative1 = col_character(),
#   trans_x_derivative1_power2 = col_character(),
#   trans_y_derivative1 = col_character(),
#   trans_y_derivative1_power2 = col_character(),
#   trans_z_derivative1 = col_character(),
#   trans_z_derivative1_power2 = col_character(),
#   rot_x_derivative1 = col_character(),
#   rot_x_derivative1_power2 = col_character(),
#   rot_y_derivative1 = col_character(),
#   rot_y_derivative1_power2 = col_character(),
#   rot_z_derivative1 = col_character()
#   # ... with 1 more columns
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   csf_derivative1 = col_character(),
#   csf_derivative1_power2 = col_character(),
#   white_matter_derivative1 = col_character(),
#   white_matter_derivative1_power2 = col_character(),
#   global_signal_derivative1 = col_character(),
#   global_signal_derivative1_power2 = col_character(),
#   std_dvars = col_character(),
#   dvars = col_character(),
#   framewise_displacement = col_character(),
#   trans_x_derivative1 = col_character(),
#   trans_x_derivative1_power2 = col_character(),
#   trans_y_derivative1 = col_character(),
#   trans_y_derivative1_power2 = col_character(),
#   trans_z_derivative1 = col_character(),
#   trans_z_derivative1_power2 = col_character(),
#   rot_x_derivative1 = col_character(),
#   rot_x_derivative1_power2 = col_character(),
#   rot_y_derivative1 = col_character(),
#   rot_y_derivative1_power2 = col_character(),
#   rot_z_derivative1 = col_character()
#   # ... with 1 more columns
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   csf_derivative1 = col_character(),
#   csf_derivative1_power2 = col_character(),
#   white_matter_derivative1 = col_character(),
#   white_matter_derivative1_power2 = col_character(),
#   global_signal_derivative1 = col_character(),
#   global_signal_derivative1_power2 = col_character(),
#   std_dvars = col_character(),
#   dvars = col_character(),
#   framewise_displacement = col_character(),
#   trans_x_derivative1 = col_character(),
#   trans_x_derivative1_power2 = col_character(),
#   trans_y_derivative1 = col_character(),
#   trans_y_derivative1_power2 = col_character(),
#   trans_z_derivative1 = col_character(),
#   trans_z_derivative1_power2 = col_character(),
#   rot_x_derivative1 = col_character(),
#   rot_x_derivative1_power2 = col_character(),
#   rot_y_derivative1 = col_character(),
#   rot_y_derivative1_power2 = col_character(),
#   rot_z_derivative1 = col_character()
#   # ... with 1 more columns
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   csf_derivative1 = col_character(),
#   csf_derivative1_power2 = col_character(),
#   white_matter_derivative1 = col_character(),
#   white_matter_derivative1_power2 = col_character(),
#   global_signal_derivative1 = col_character(),
#   global_signal_derivative1_power2 = col_character(),
#   std_dvars = col_character(),
#   dvars = col_character(),
#   framewise_displacement = col_character(),
#   trans_x_derivative1 = col_character(),
#   trans_x_derivative1_power2 = col_character(),
#   trans_y_derivative1 = col_character(),
#   trans_y_derivative1_power2 = col_character(),
#   trans_z_derivative1 = col_character(),
#   trans_z_derivative1_power2 = col_character(),
#   rot_x_derivative1 = col_character(),
#   rot_x_derivative1_power2 = col_character(),
#   rot_y_derivative1 = col_character(),
#   rot_y_derivative1_power2 = col_character(),
#   rot_z_derivative1 = col_character()
#   # ... with 1 more columns
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   csf_derivative1 = col_character(),
#   csf_derivative1_power2 = col_character(),
#   white_matter_derivative1 = col_character(),
#   white_matter_derivative1_power2 = col_character(),
#   global_signal_derivative1 = col_character(),
#   global_signal_derivative1_power2 = col_character(),
#   std_dvars = col_character(),
#   dvars = col_character(),
#   framewise_displacement = col_character(),
#   trans_x_derivative1 = col_character(),
#   trans_x_derivative1_power2 = col_character(),
#   trans_y_derivative1 = col_character(),
#   trans_y_derivative1_power2 = col_character(),
#   trans_z_derivative1 = col_character(),
#   trans_z_derivative1_power2 = col_character(),
#   rot_x_derivative1 = col_character(),
#   rot_x_derivative1_power2 = col_character(),
#   rot_y_derivative1 = col_character(),
#   rot_y_derivative1_power2 = col_character(),
#   rot_z_derivative1 = col_character()
#   # ... with 1 more columns
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   csf_derivative1 = col_character(),
#   csf_derivative1_power2 = col_character(),
#   white_matter_derivative1 = col_character(),
#   white_matter_derivative1_power2 = col_character(),
#   global_signal_derivative1 = col_character(),
#   global_signal_derivative1_power2 = col_character(),
#   std_dvars = col_character(),
#   dvars = col_character(),
#   framewise_displacement = col_character(),
#   trans_x_derivative1 = col_character(),
#   trans_x_derivative1_power2 = col_character(),
#   trans_y_derivative1 = col_character(),
#   trans_y_derivative1_power2 = col_character(),
#   trans_z_derivative1 = col_character(),
#   trans_z_derivative1_power2 = col_character(),
#   rot_x_derivative1 = col_character(),
#   rot_x_derivative1_power2 = col_character(),
#   rot_y_derivative1 = col_character(),
#   rot_y_derivative1_power2 = col_character(),
#   rot_z_derivative1 = col_character()
#   # ... with 1 more columns
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   csf_derivative1 = col_character(),
#   csf_derivative1_power2 = col_character(),
#   white_matter_derivative1 = col_character(),
#   white_matter_derivative1_power2 = col_character(),
#   global_signal_derivative1 = col_character(),
#   global_signal_derivative1_power2 = col_character(),
#   std_dvars = col_character(),
#   dvars = col_character(),
#   framewise_displacement = col_character(),
#   trans_x_derivative1 = col_character(),
#   trans_x_derivative1_power2 = col_character(),
#   trans_y_derivative1 = col_character(),
#   trans_y_derivative1_power2 = col_character(),
#   trans_z_derivative1 = col_character(),
#   trans_z_derivative1_power2 = col_character(),
#   rot_x_derivative1 = col_character(),
#   rot_x_derivative1_power2 = col_character(),
#   rot_y_derivative1 = col_character(),
#   rot_y_derivative1_power2 = col_character(),
#   rot_z_derivative1 = col_character()
#   # ... with 1 more columns
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   csf_derivative1 = col_character(),
#   csf_derivative1_power2 = col_character(),
#   white_matter_derivative1 = col_character(),
#   white_matter_derivative1_power2 = col_character(),
#   global_signal_derivative1 = col_character(),
#   global_signal_derivative1_power2 = col_character(),
#   std_dvars = col_character(),
#   dvars = col_character(),
#   framewise_displacement = col_character(),
#   trans_x_derivative1 = col_character(),
#   trans_x_derivative1_power2 = col_character(),
#   trans_y_derivative1 = col_character(),
#   trans_y_derivative1_power2 = col_character(),
#   trans_z_derivative1 = col_character(),
#   trans_z_derivative1_power2 = col_character(),
#   rot_x_derivative1 = col_character(),
#   rot_x_derivative1_power2 = col_character(),
#   rot_y_derivative1 = col_character(),
#   rot_y_derivative1_power2 = col_character(),
#   rot_z_derivative1 = col_character()
#   # ... with 1 more columns
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   csf_derivative1 = col_character(),
#   csf_derivative1_power2 = col_character(),
#   white_matter_derivative1 = col_character(),
#   white_matter_derivative1_power2 = col_character(),
#   global_signal_derivative1 = col_character(),
#   global_signal_derivative1_power2 = col_character(),
#   std_dvars = col_character(),
#   dvars = col_character(),
#   framewise_displacement = col_character(),
#   trans_x_derivative1 = col_character(),
#   trans_x_derivative1_power2 = col_character(),
#   trans_y_derivative1 = col_character(),
#   trans_y_derivative1_power2 = col_character(),
#   trans_z_derivative1 = col_character(),
#   trans_z_derivative1_power2 = col_character(),
#   rot_x_derivative1 = col_character(),
#   rot_x_derivative1_power2 = col_character(),
#   rot_y_derivative1 = col_character(),
#   rot_y_derivative1_power2 = col_character(),
#   rot_z_derivative1 = col_character()
#   # ... with 1 more columns
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   csf_derivative1 = col_character(),
#   csf_derivative1_power2 = col_character(),
#   white_matter_derivative1 = col_character(),
#   white_matter_derivative1_power2 = col_character(),
#   global_signal_derivative1 = col_character(),
#   global_signal_derivative1_power2 = col_character(),
#   std_dvars = col_character(),
#   dvars = col_character(),
#   framewise_displacement = col_character(),
#   trans_x_derivative1 = col_character(),
#   trans_x_derivative1_power2 = col_character(),
#   trans_y_derivative1 = col_character(),
#   trans_y_derivative1_power2 = col_character(),
#   trans_z_derivative1 = col_character(),
#   trans_z_derivative1_power2 = col_character(),
#   rot_x_derivative1 = col_character(),
#   rot_x_derivative1_power2 = col_character(),
#   rot_y_derivative1 = col_character(),
#   rot_y_derivative1_power2 = col_character(),
#   rot_z_derivative1 = col_character()
#   # ... with 1 more columns
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   csf_derivative1 = col_character(),
#   csf_derivative1_power2 = col_character(),
#   white_matter_derivative1 = col_character(),
#   white_matter_derivative1_power2 = col_character(),
#   global_signal_derivative1 = col_character(),
#   global_signal_derivative1_power2 = col_character(),
#   std_dvars = col_character(),
#   dvars = col_character(),
#   framewise_displacement = col_character(),
#   trans_x_derivative1 = col_character(),
#   trans_x_derivative1_power2 = col_character(),
#   trans_y_derivative1 = col_character(),
#   trans_y_derivative1_power2 = col_character(),
#   trans_z_derivative1 = col_character(),
#   trans_z_derivative1_power2 = col_character(),
#   rot_x_derivative1 = col_character(),
#   rot_x_derivative1_power2 = col_character(),
#   rot_y_derivative1 = col_character(),
#   rot_y_derivative1_power2 = col_character(),
#   rot_z_derivative1 = col_character()
#   # ... with 1 more columns
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   csf_derivative1 = col_character(),
#   csf_derivative1_power2 = col_character(),
#   white_matter_derivative1 = col_character(),
#   white_matter_derivative1_power2 = col_character(),
#   global_signal_derivative1 = col_character(),
#   global_signal_derivative1_power2 = col_character(),
#   std_dvars = col_character(),
#   dvars = col_character(),
#   framewise_displacement = col_character(),
#   trans_x_derivative1 = col_character(),
#   trans_x_derivative1_power2 = col_character(),
#   trans_y_derivative1 = col_character(),
#   trans_y_derivative1_power2 = col_character(),
#   trans_z_derivative1 = col_character(),
#   trans_z_derivative1_power2 = col_character(),
#   rot_x_derivative1 = col_character(),
#   rot_x_derivative1_power2 = col_character(),
#   rot_y_derivative1 = col_character(),
#   rot_y_derivative1_power2 = col_character(),
#   rot_z_derivative1 = col_character()
#   # ... with 1 more columns
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   csf_derivative1 = col_character(),
#   csf_derivative1_power2 = col_character(),
#   white_matter_derivative1 = col_character(),
#   white_matter_derivative1_power2 = col_character(),
#   global_signal_derivative1 = col_character(),
#   global_signal_derivative1_power2 = col_character(),
#   std_dvars = col_character(),
#   dvars = col_character(),
#   framewise_displacement = col_character(),
#   trans_x_derivative1 = col_character(),
#   trans_x_derivative1_power2 = col_character(),
#   trans_y_derivative1 = col_character(),
#   trans_y_derivative1_power2 = col_character(),
#   trans_z_derivative1 = col_character(),
#   trans_z_derivative1_power2 = col_character(),
#   rot_x_derivative1 = col_character(),
#   rot_x_derivative1_power2 = col_character(),
#   rot_y_derivative1 = col_character(),
#   rot_y_derivative1_power2 = col_character(),
#   rot_z_derivative1 = col_character()
#   # ... with 1 more columns
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   csf_derivative1 = col_character(),
#   csf_derivative1_power2 = col_character(),
#   white_matter_derivative1 = col_character(),
#   white_matter_derivative1_power2 = col_character(),
#   global_signal_derivative1 = col_character(),
#   global_signal_derivative1_power2 = col_character(),
#   std_dvars = col_character(),
#   dvars = col_character(),
#   framewise_displacement = col_character(),
#   trans_x_derivative1 = col_character(),
#   trans_x_derivative1_power2 = col_character(),
#   trans_y_derivative1 = col_character(),
#   trans_y_derivative1_power2 = col_character(),
#   trans_z_derivative1 = col_character(),
#   trans_z_derivative1_power2 = col_character(),
#   rot_x_derivative1 = col_character(),
#   rot_x_derivative1_power2 = col_character(),
#   rot_y_derivative1 = col_character(),
#   rot_y_derivative1_power2 = col_character(),
#   rot_z_derivative1 = col_character()
#   # ... with 1 more columns
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   csf_derivative1 = col_character(),
#   csf_derivative1_power2 = col_character(),
#   white_matter_derivative1 = col_character(),
#   white_matter_derivative1_power2 = col_character(),
#   global_signal_derivative1 = col_character(),
#   global_signal_derivative1_power2 = col_character(),
#   std_dvars = col_character(),
#   dvars = col_character(),
#   framewise_displacement = col_character(),
#   trans_x_derivative1 = col_character(),
#   trans_x_derivative1_power2 = col_character(),
#   trans_y_derivative1 = col_character(),
#   trans_y_derivative1_power2 = col_character(),
#   trans_z_derivative1 = col_character(),
#   trans_z_derivative1_power2 = col_character(),
#   rot_x_derivative1 = col_character(),
#   rot_x_derivative1_power2 = col_character(),
#   rot_y_derivative1 = col_character(),
#   rot_y_derivative1_power2 = col_character(),
#   rot_z_derivative1 = col_character()
#   # ... with 1 more columns
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   csf_derivative1 = col_character(),
#   csf_derivative1_power2 = col_character(),
#   white_matter_derivative1 = col_character(),
#   white_matter_derivative1_power2 = col_character(),
#   global_signal_derivative1 = col_character(),
#   global_signal_derivative1_power2 = col_character(),
#   std_dvars = col_character(),
#   dvars = col_character(),
#   framewise_displacement = col_character(),
#   trans_x_derivative1 = col_character(),
#   trans_x_derivative1_power2 = col_character(),
#   trans_y_derivative1 = col_character(),
#   trans_y_derivative1_power2 = col_character(),
#   trans_z_derivative1 = col_character(),
#   trans_z_derivative1_power2 = col_character(),
#   rot_x_derivative1 = col_character(),
#   rot_x_derivative1_power2 = col_character(),
#   rot_y_derivative1 = col_character(),
#   rot_y_derivative1_power2 = col_character(),
#   rot_z_derivative1 = col_character()
#   # ... with 1 more columns
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   csf_derivative1 = col_character(),
#   csf_derivative1_power2 = col_character(),
#   white_matter_derivative1 = col_character(),
#   white_matter_derivative1_power2 = col_character(),
#   global_signal_derivative1 = col_character(),
#   global_signal_derivative1_power2 = col_character(),
#   std_dvars = col_character(),
#   dvars = col_character(),
#   framewise_displacement = col_character(),
#   trans_x_derivative1 = col_character(),
#   trans_x_derivative1_power2 = col_character(),
#   trans_y_derivative1 = col_character(),
#   trans_y_derivative1_power2 = col_character(),
#   trans_z_derivative1 = col_character(),
#   trans_z_derivative1_power2 = col_character(),
#   rot_x_derivative1 = col_character(),
#   rot_x_derivative1_power2 = col_character(),
#   rot_y_derivative1 = col_character(),
#   rot_y_derivative1_power2 = col_character(),
#   rot_z_derivative1 = col_character()
#   # ... with 1 more columns
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   csf_derivative1 = col_character(),
#   csf_derivative1_power2 = col_character(),
#   white_matter_derivative1 = col_character(),
#   white_matter_derivative1_power2 = col_character(),
#   global_signal_derivative1 = col_character(),
#   global_signal_derivative1_power2 = col_character(),
#   std_dvars = col_character(),
#   dvars = col_character(),
#   framewise_displacement = col_character(),
#   trans_x_derivative1 = col_character(),
#   trans_x_derivative1_power2 = col_character(),
#   trans_y_derivative1 = col_character(),
#   trans_y_derivative1_power2 = col_character(),
#   trans_z_derivative1 = col_character(),
#   trans_z_derivative1_power2 = col_character(),
#   rot_x_derivative1 = col_character(),
#   rot_x_derivative1_power2 = col_character(),
#   rot_y_derivative1 = col_character(),
#   rot_y_derivative1_power2 = col_character(),
#   rot_z_derivative1 = col_character()
#   # ... with 1 more columns
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   csf_derivative1 = col_character(),
#   csf_derivative1_power2 = col_character(),
#   white_matter_derivative1 = col_character(),
#   white_matter_derivative1_power2 = col_character(),
#   global_signal_derivative1 = col_character(),
#   global_signal_derivative1_power2 = col_character(),
#   std_dvars = col_character(),
#   dvars = col_character(),
#   framewise_displacement = col_character(),
#   trans_x_derivative1 = col_character(),
#   trans_x_derivative1_power2 = col_character(),
#   trans_y_derivative1 = col_character(),
#   trans_y_derivative1_power2 = col_character(),
#   trans_z_derivative1 = col_character(),
#   trans_z_derivative1_power2 = col_character(),
#   rot_x_derivative1 = col_character(),
#   rot_x_derivative1_power2 = col_character(),
#   rot_y_derivative1 = col_character(),
#   rot_y_derivative1_power2 = col_character(),
#   rot_z_derivative1 = col_character()
#   # ... with 1 more columns
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   csf_derivative1 = col_character(),
#   csf_derivative1_power2 = col_character(),
#   white_matter_derivative1 = col_character(),
#   white_matter_derivative1_power2 = col_character(),
#   global_signal_derivative1 = col_character(),
#   global_signal_derivative1_power2 = col_character(),
#   std_dvars = col_character(),
#   dvars = col_character(),
#   framewise_displacement = col_character(),
#   trans_x_derivative1 = col_character(),
#   trans_x_derivative1_power2 = col_character(),
#   trans_y_derivative1 = col_character(),
#   trans_y_derivative1_power2 = col_character(),
#   trans_z_derivative1 = col_character(),
#   trans_z_derivative1_power2 = col_character(),
#   rot_x_derivative1 = col_character(),
#   rot_x_derivative1_power2 = col_character(),
#   rot_y_derivative1 = col_character(),
#   rot_y_derivative1_power2 = col_character(),
#   rot_z_derivative1 = col_character()
#   # ... with 1 more columns
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   csf_derivative1 = col_character(),
#   csf_derivative1_power2 = col_character(),
#   white_matter_derivative1 = col_character(),
#   white_matter_derivative1_power2 = col_character(),
#   global_signal_derivative1 = col_character(),
#   global_signal_derivative1_power2 = col_character(),
#   std_dvars = col_character(),
#   dvars = col_character(),
#   framewise_displacement = col_character(),
#   trans_x_derivative1 = col_character(),
#   trans_x_derivative1_power2 = col_character(),
#   trans_y_derivative1 = col_character(),
#   trans_y_derivative1_power2 = col_character(),
#   trans_z_derivative1 = col_character(),
#   trans_z_derivative1_power2 = col_character(),
#   rot_x_derivative1 = col_character(),
#   rot_x_derivative1_power2 = col_character(),
#   rot_y_derivative1 = col_character(),
#   rot_y_derivative1_power2 = col_character(),
#   rot_z_derivative1 = col_character()
#   # ... with 1 more columns
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   csf_derivative1 = col_character(),
#   csf_derivative1_power2 = col_character(),
#   white_matter_derivative1 = col_character(),
#   white_matter_derivative1_power2 = col_character(),
#   global_signal_derivative1 = col_character(),
#   global_signal_derivative1_power2 = col_character(),
#   std_dvars = col_character(),
#   dvars = col_character(),
#   framewise_displacement = col_character(),
#   trans_x_derivative1 = col_character(),
#   trans_x_derivative1_power2 = col_character(),
#   trans_y_derivative1 = col_character(),
#   trans_y_derivative1_power2 = col_character(),
#   trans_z_derivative1 = col_character(),
#   trans_z_derivative1_power2 = col_character(),
#   rot_x_derivative1 = col_character(),
#   rot_x_derivative1_power2 = col_character(),
#   rot_y_derivative1 = col_character(),
#   rot_y_derivative1_power2 = col_character(),
#   rot_z_derivative1 = col_character()
#   # ... with 1 more columns
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   csf_derivative1 = col_character(),
#   csf_derivative1_power2 = col_character(),
#   white_matter_derivative1 = col_character(),
#   white_matter_derivative1_power2 = col_character(),
#   global_signal_derivative1 = col_character(),
#   global_signal_derivative1_power2 = col_character(),
#   std_dvars = col_character(),
#   dvars = col_character(),
#   framewise_displacement = col_character(),
#   trans_x_derivative1 = col_character(),
#   trans_x_derivative1_power2 = col_character(),
#   trans_y_derivative1 = col_character(),
#   trans_y_derivative1_power2 = col_character(),
#   trans_z_derivative1 = col_character(),
#   trans_z_derivative1_power2 = col_character(),
#   rot_x_derivative1 = col_character(),
#   rot_x_derivative1_power2 = col_character(),
#   rot_y_derivative1 = col_character(),
#   rot_y_derivative1_power2 = col_character(),
#   rot_z_derivative1 = col_character()
#   # ... with 1 more columns
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   csf_derivative1 = col_character(),
#   csf_derivative1_power2 = col_character(),
#   white_matter_derivative1 = col_character(),
#   white_matter_derivative1_power2 = col_character(),
#   global_signal_derivative1 = col_character(),
#   global_signal_derivative1_power2 = col_character(),
#   std_dvars = col_character(),
#   dvars = col_character(),
#   framewise_displacement = col_character(),
#   trans_x_derivative1 = col_character(),
#   trans_x_derivative1_power2 = col_character(),
#   trans_y_derivative1 = col_character(),
#   trans_y_derivative1_power2 = col_character(),
#   trans_z_derivative1 = col_character(),
#   trans_z_derivative1_power2 = col_character(),
#   rot_x_derivative1 = col_character(),
#   rot_x_derivative1_power2 = col_character(),
#   rot_y_derivative1 = col_character(),
#   rot_y_derivative1_power2 = col_character(),
#   rot_z_derivative1 = col_character()
#   # ... with 1 more columns
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   csf_derivative1 = col_character(),
#   csf_derivative1_power2 = col_character(),
#   white_matter_derivative1 = col_character(),
#   white_matter_derivative1_power2 = col_character(),
#   global_signal_derivative1 = col_character(),
#   global_signal_derivative1_power2 = col_character(),
#   std_dvars = col_character(),
#   dvars = col_character(),
#   framewise_displacement = col_character(),
#   trans_x_derivative1 = col_character(),
#   trans_x_derivative1_power2 = col_character(),
#   trans_y_derivative1 = col_character(),
#   trans_y_derivative1_power2 = col_character(),
#   trans_z_derivative1 = col_character(),
#   trans_z_derivative1_power2 = col_character(),
#   rot_x_derivative1 = col_character(),
#   rot_x_derivative1_power2 = col_character(),
#   rot_y_derivative1 = col_character(),
#   rot_y_derivative1_power2 = col_character(),
#   rot_z_derivative1 = col_character()
#   # ... with 1 more columns
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   csf_derivative1 = col_character(),
#   csf_derivative1_power2 = col_character(),
#   white_matter_derivative1 = col_character(),
#   white_matter_derivative1_power2 = col_character(),
#   global_signal_derivative1 = col_character(),
#   global_signal_derivative1_power2 = col_character(),
#   std_dvars = col_character(),
#   dvars = col_character(),
#   framewise_displacement = col_character(),
#   trans_x_derivative1 = col_character(),
#   trans_x_derivative1_power2 = col_character(),
#   trans_y_derivative1 = col_character(),
#   trans_y_derivative1_power2 = col_character(),
#   trans_z_derivative1 = col_character(),
#   trans_z_derivative1_power2 = col_character(),
#   rot_x_derivative1 = col_character(),
#   rot_x_derivative1_power2 = col_character(),
#   rot_y_derivative1 = col_character(),
#   rot_y_derivative1_power2 = col_character(),
#   rot_z_derivative1 = col_character()
#   # ... with 1 more columns
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   csf_derivative1 = col_character(),
#   csf_derivative1_power2 = col_character(),
#   white_matter_derivative1 = col_character(),
#   white_matter_derivative1_power2 = col_character(),
#   global_signal_derivative1 = col_character(),
#   global_signal_derivative1_power2 = col_character(),
#   std_dvars = col_character(),
#   dvars = col_character(),
#   framewise_displacement = col_character(),
#   trans_x_derivative1 = col_character(),
#   trans_x_derivative1_power2 = col_character(),
#   trans_y_derivative1 = col_character(),
#   trans_y_derivative1_power2 = col_character(),
#   trans_z_derivative1 = col_character(),
#   trans_z_derivative1_power2 = col_character(),
#   rot_x_derivative1 = col_character(),
#   rot_x_derivative1_power2 = col_character(),
#   rot_y_derivative1 = col_character(),
#   rot_y_derivative1_power2 = col_character(),
#   rot_z_derivative1 = col_character()
#   # ... with 1 more columns
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   csf_derivative1 = col_character(),
#   csf_derivative1_power2 = col_character(),
#   white_matter_derivative1 = col_character(),
#   white_matter_derivative1_power2 = col_character(),
#   global_signal_derivative1 = col_character(),
#   global_signal_derivative1_power2 = col_character(),
#   std_dvars = col_character(),
#   dvars = col_character(),
#   framewise_displacement = col_character(),
#   trans_x_derivative1 = col_character(),
#   trans_x_derivative1_power2 = col_character(),
#   trans_y_derivative1 = col_character(),
#   trans_y_derivative1_power2 = col_character(),
#   trans_z_derivative1 = col_character(),
#   trans_z_derivative1_power2 = col_character(),
#   rot_x_derivative1 = col_character(),
#   rot_x_derivative1_power2 = col_character(),
#   rot_y_derivative1 = col_character(),
#   rot_y_derivative1_power2 = col_character(),
#   rot_z_derivative1 = col_character()
#   # ... with 1 more columns
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   csf_derivative1 = col_character(),
#   csf_derivative1_power2 = col_character(),
#   white_matter_derivative1 = col_character(),
#   white_matter_derivative1_power2 = col_character(),
#   global_signal_derivative1 = col_character(),
#   global_signal_derivative1_power2 = col_character(),
#   std_dvars = col_character(),
#   dvars = col_character(),
#   framewise_displacement = col_character(),
#   trans_x_derivative1 = col_character(),
#   trans_x_derivative1_power2 = col_character(),
#   trans_y_derivative1 = col_character(),
#   trans_y_derivative1_power2 = col_character(),
#   trans_z_derivative1 = col_character(),
#   trans_z_derivative1_power2 = col_character(),
#   rot_x_derivative1 = col_character(),
#   rot_x_derivative1_power2 = col_character(),
#   rot_y_derivative1 = col_character(),
#   rot_y_derivative1_power2 = col_character(),
#   rot_z_derivative1 = col_character()
#   # ... with 1 more columns
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   csf_derivative1 = col_character(),
#   csf_derivative1_power2 = col_character(),
#   white_matter_derivative1 = col_character(),
#   white_matter_derivative1_power2 = col_character(),
#   global_signal_derivative1 = col_character(),
#   global_signal_derivative1_power2 = col_character(),
#   std_dvars = col_character(),
#   dvars = col_character(),
#   framewise_displacement = col_character(),
#   trans_x_derivative1 = col_character(),
#   trans_x_derivative1_power2 = col_character(),
#   trans_y_derivative1 = col_character(),
#   trans_y_derivative1_power2 = col_character(),
#   trans_z_derivative1 = col_character(),
#   trans_z_derivative1_power2 = col_character(),
#   rot_x_derivative1 = col_character(),
#   rot_x_derivative1_power2 = col_character(),
#   rot_y_derivative1 = col_character(),
#   rot_y_derivative1_power2 = col_character(),
#   rot_z_derivative1 = col_character()
#   # ... with 1 more columns
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   csf_derivative1 = col_character(),
#   csf_derivative1_power2 = col_character(),
#   white_matter_derivative1 = col_character(),
#   white_matter_derivative1_power2 = col_character(),
#   global_signal_derivative1 = col_character(),
#   global_signal_derivative1_power2 = col_character(),
#   std_dvars = col_character(),
#   dvars = col_character(),
#   framewise_displacement = col_character(),
#   trans_x_derivative1 = col_character(),
#   trans_x_derivative1_power2 = col_character(),
#   trans_y_derivative1 = col_character(),
#   trans_y_derivative1_power2 = col_character(),
#   trans_z_derivative1 = col_character(),
#   trans_z_derivative1_power2 = col_character(),
#   rot_x_derivative1 = col_character(),
#   rot_x_derivative1_power2 = col_character(),
#   rot_y_derivative1 = col_character(),
#   rot_y_derivative1_power2 = col_character(),
#   rot_z_derivative1 = col_character()
#   # ... with 1 more columns
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   csf_derivative1 = col_character(),
#   csf_derivative1_power2 = col_character(),
#   white_matter_derivative1 = col_character(),
#   white_matter_derivative1_power2 = col_character(),
#   global_signal_derivative1 = col_character(),
#   global_signal_derivative1_power2 = col_character(),
#   std_dvars = col_character(),
#   dvars = col_character(),
#   framewise_displacement = col_character(),
#   trans_x_derivative1 = col_character(),
#   trans_x_derivative1_power2 = col_character(),
#   trans_y_derivative1 = col_character(),
#   trans_y_derivative1_power2 = col_character(),
#   trans_z_derivative1 = col_character(),
#   trans_z_derivative1_power2 = col_character(),
#   rot_x_derivative1 = col_character(),
#   rot_x_derivative1_power2 = col_character(),
#   rot_y_derivative1 = col_character(),
#   rot_y_derivative1_power2 = col_character(),
# ...
#   # ... with 1 more columns
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   std_dvars = col_character(),
#   dvars = col_character(),
#   framewise_displacement = col_character()
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   csf_derivative1 = col_character(),
#   csf_derivative1_power2 = col_character(),
#   white_matter_derivative1 = col_character(),
#   white_matter_derivative1_power2 = col_character(),
#   global_signal_derivative1 = col_character(),
#   global_signal_derivative1_power2 = col_character(),
#   std_dvars = col_character(),
#   dvars = col_character(),
#   framewise_displacement = col_character(),
#   trans_x_derivative1 = col_character(),
#   trans_x_derivative1_power2 = col_character(),
#   trans_y_derivative1 = col_character(),
#   trans_y_derivative1_power2 = col_character(),
#   trans_z_derivative1 = col_character(),
#   trans_z_derivative1_power2 = col_character(),
#   rot_x_derivative1 = col_character(),
#   rot_x_derivative1_power2 = col_character(),
#   rot_y_derivative1 = col_character(),
#   rot_y_derivative1_power2 = col_character(),
#   rot_z_derivative1 = col_character()
#   # ... with 1 more columns
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   csf_derivative1 = col_character(),
#   csf_derivative1_power2 = col_character(),
#   white_matter_derivative1 = col_character(),
#   white_matter_derivative1_power2 = col_character(),
#   global_signal_derivative1 = col_character(),
#   global_signal_derivative1_power2 = col_character(),
#   std_dvars = col_character(),
#   dvars = col_character(),
#   framewise_displacement = col_character(),
#   trans_x_derivative1 = col_character(),
#   trans_x_derivative1_power2 = col_character(),
#   trans_y_derivative1 = col_character(),
#   trans_y_derivative1_power2 = col_character(),
#   trans_z_derivative1 = col_character(),
#   trans_z_derivative1_power2 = col_character(),
#   rot_x_derivative1 = col_character(),
#   rot_x_derivative1_power2 = col_character(),
#   rot_y_derivative1 = col_character(),
#   rot_y_derivative1_power2 = col_character(),
#   rot_z_derivative1 = col_character()
#   # ... with 1 more columns
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   std_dvars = col_character(),
#   dvars = col_character(),
#   framewise_displacement = col_character()
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   csf_derivative1 = col_character(),
#   csf_derivative1_power2 = col_character(),
#   white_matter_derivative1 = col_character(),
#   white_matter_derivative1_power2 = col_character(),
#   global_signal_derivative1 = col_character(),
#   global_signal_derivative1_power2 = col_character(),
#   std_dvars = col_character(),
#   dvars = col_character(),
#   framewise_displacement = col_character(),
#   trans_x_derivative1 = col_character(),
#   trans_x_derivative1_power2 = col_character(),
#   trans_y_derivative1 = col_character(),
#   trans_y_derivative1_power2 = col_character(),
#   trans_z_derivative1 = col_character(),
#   trans_z_derivative1_power2 = col_character(),
#   rot_x_derivative1 = col_character(),
#   rot_x_derivative1_power2 = col_character(),
#   rot_y_derivative1 = col_character(),
#   rot_y_derivative1_power2 = col_character(),
#   rot_z_derivative1 = col_character()
#   # ... with 1 more columns
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   csf_derivative1 = col_character(),
#   csf_derivative1_power2 = col_character(),
#   white_matter_derivative1 = col_character(),
#   white_matter_derivative1_power2 = col_character(),
#   global_signal_derivative1 = col_character(),
#   global_signal_derivative1_power2 = col_character(),
#   std_dvars = col_character(),
#   dvars = col_character(),
#   framewise_displacement = col_character(),
#   trans_x_derivative1 = col_character(),
#   trans_x_derivative1_power2 = col_character(),
#   trans_y_derivative1 = col_character(),
#   trans_y_derivative1_power2 = col_character(),
#   trans_z_derivative1 = col_character(),
#   trans_z_derivative1_power2 = col_character(),
#   rot_x_derivative1 = col_character(),
#   rot_x_derivative1_power2 = col_character(),
#   rot_y_derivative1 = col_character(),
#   rot_y_derivative1_power2 = col_character(),
#   rot_z_derivative1 = col_character()
#   # ... with 1 more columns
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   std_dvars = col_character(),
#   dvars = col_character(),
#   framewise_displacement = col_character()
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   csf_derivative1 = col_character(),
#   csf_derivative1_power2 = col_character(),
#   white_matter_derivative1 = col_character(),
#   white_matter_derivative1_power2 = col_character(),
#   global_signal_derivative1 = col_character(),
#   global_signal_derivative1_power2 = col_character(),
#   std_dvars = col_character(),
#   dvars = col_character(),
#   framewise_displacement = col_character(),
#   trans_x_derivative1 = col_character(),
#   trans_x_derivative1_power2 = col_character(),
#   trans_y_derivative1 = col_character(),
#   trans_y_derivative1_power2 = col_character(),
#   trans_z_derivative1 = col_character(),
#   trans_z_derivative1_power2 = col_character(),
#   rot_x_derivative1 = col_character(),
#   rot_x_derivative1_power2 = col_character(),
#   rot_y_derivative1 = col_character(),
#   rot_y_derivative1_power2 = col_character(),
#   rot_z_derivative1 = col_character()
#   # ... with 1 more columns
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   csf_derivative1 = col_character(),
#   csf_derivative1_power2 = col_character(),
#   white_matter_derivative1 = col_character(),
#   white_matter_derivative1_power2 = col_character(),
#   global_signal_derivative1 = col_character(),
#   global_signal_derivative1_power2 = col_character(),
#   std_dvars = col_character(),
#   dvars = col_character(),
#   framewise_displacement = col_character(),
#   trans_x_derivative1 = col_character(),
#   trans_x_derivative1_power2 = col_character(),
#   trans_y_derivative1 = col_character(),
#   trans_y_derivative1_power2 = col_character(),
#   trans_z_derivative1 = col_character(),
#   trans_z_derivative1_power2 = col_character(),
#   rot_x_derivative1 = col_character(),
#   rot_x_derivative1_power2 = col_character(),
#   rot_y_derivative1 = col_character(),
#   rot_y_derivative1_power2 = col_character(),
#   rot_z_derivative1 = col_character()
#   # ... with 1 more columns
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   std_dvars = col_character(),
#   dvars = col_character(),
#   framewise_displacement = col_character()
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   csf_derivative1 = col_character(),
#   csf_derivative1_power2 = col_character(),
#   white_matter_derivative1 = col_character(),
#   white_matter_derivative1_power2 = col_character(),
#   global_signal_derivative1 = col_character(),
#   global_signal_derivative1_power2 = col_character(),
#   std_dvars = col_character(),
#   dvars = col_character(),
#   framewise_displacement = col_character(),
#   trans_x_derivative1 = col_character(),
#   trans_x_derivative1_power2 = col_character(),
#   trans_y_derivative1 = col_character(),
#   trans_y_derivative1_power2 = col_character(),
#   trans_z_derivative1 = col_character(),
#   trans_z_derivative1_power2 = col_character(),
#   rot_x_derivative1 = col_character(),
#   rot_x_derivative1_power2 = col_character(),
#   rot_y_derivative1 = col_character(),
#   rot_y_derivative1_power2 = col_character(),
#   rot_z_derivative1 = col_character()
#   # ... with 1 more columns
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   csf_derivative1 = col_character(),
#   csf_derivative1_power2 = col_character(),
#   white_matter_derivative1 = col_character(),
#   white_matter_derivative1_power2 = col_character(),
#   global_signal_derivative1 = col_character(),
#   global_signal_derivative1_power2 = col_character(),
#   std_dvars = col_character(),
#   dvars = col_character(),
#   framewise_displacement = col_character(),
#   trans_x_derivative1 = col_character(),
#   trans_x_derivative1_power2 = col_character(),
#   trans_y_derivative1 = col_character(),
#   trans_y_derivative1_power2 = col_character(),
#   trans_z_derivative1 = col_character(),
#   trans_z_derivative1_power2 = col_character(),
#   rot_x_derivative1 = col_character(),
#   rot_x_derivative1_power2 = col_character(),
#   rot_y_derivative1 = col_character(),
#   rot_y_derivative1_power2 = col_character(),
#   rot_z_derivative1 = col_character()
#   # ... with 1 more columns
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   std_dvars = col_character(),
#   dvars = col_character(),
#   framewise_displacement = col_character()
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   csf_derivative1 = col_character(),
#   csf_derivative1_power2 = col_character(),
#   white_matter_derivative1 = col_character(),
#   white_matter_derivative1_power2 = col_character(),
#   global_signal_derivative1 = col_character(),
#   global_signal_derivative1_power2 = col_character(),
#   std_dvars = col_character(),
#   dvars = col_character(),
#   framewise_displacement = col_character(),
#   trans_x_derivative1 = col_character(),
#   trans_x_derivative1_power2 = col_character(),
#   trans_y_derivative1 = col_character(),
#   trans_y_derivative1_power2 = col_character(),
#   trans_z_derivative1 = col_character(),
#   trans_z_derivative1_power2 = col_character(),
#   rot_x_derivative1 = col_character(),
#   rot_x_derivative1_power2 = col_character(),
#   rot_y_derivative1 = col_character(),
#   rot_y_derivative1_power2 = col_character(),
#   rot_z_derivative1 = col_character()
#   # ... with 1 more columns
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   csf_derivative1 = col_character(),
#   csf_derivative1_power2 = col_character(),
#   white_matter_derivative1 = col_character(),
#   white_matter_derivative1_power2 = col_character(),
#   global_signal_derivative1 = col_character(),
#   global_signal_derivative1_power2 = col_character(),
#   std_dvars = col_character(),
#   dvars = col_character(),
#   framewise_displacement = col_character(),
#   trans_x_derivative1 = col_character(),
#   trans_x_derivative1_power2 = col_character(),
#   trans_y_derivative1 = col_character(),
#   trans_y_derivative1_power2 = col_character(),
#   trans_z_derivative1 = col_character(),
#   trans_z_derivative1_power2 = col_character(),
#   rot_x_derivative1 = col_character(),
#   rot_x_derivative1_power2 = col_character(),
#   rot_y_derivative1 = col_character(),
#   rot_y_derivative1_power2 = col_character(),
#   rot_z_derivative1 = col_character()
#   # ... with 1 more columns
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   std_dvars = col_character(),
#   dvars = col_character(),
#   framewise_displacement = col_character()
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   csf_derivative1 = col_character(),
#   csf_derivative1_power2 = col_character(),
#   white_matter_derivative1 = col_character(),
#   white_matter_derivative1_power2 = col_character(),
#   global_signal_derivative1 = col_character(),
#   global_signal_derivative1_power2 = col_character(),
#   std_dvars = col_character(),
#   dvars = col_character(),
#   framewise_displacement = col_character(),
#   trans_x_derivative1 = col_character(),
#   trans_x_derivative1_power2 = col_character(),
#   trans_y_derivative1 = col_character(),
#   trans_y_derivative1_power2 = col_character(),
#   trans_z_derivative1 = col_character(),
#   trans_z_derivative1_power2 = col_character(),
#   rot_x_derivative1 = col_character(),
#   rot_x_derivative1_power2 = col_character(),
#   rot_y_derivative1 = col_character(),
#   rot_y_derivative1_power2 = col_character(),
#   rot_z_derivative1 = col_character()
#   # ... with 1 more columns
# )
# See spec(...) for full column specifications.
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   csf_derivative1 = col_character(),
#   csf_derivative1_power2 = col_character(),
#   white_matter_derivative1 = col_character(),
#   white_matter_derivative1_power2 = col_character(),
#   global_signal_derivative1 = col_character(),
#   global_signal_derivative1_power2 = col_character(),
#   std_dvars = col_character(),
#   dvars = col_character(),
#   framewise_displacement = col_character(),
#   trans_x_derivative1 = col_character(),
#   trans_x_derivative1_power2 = col_character(),
#   trans_y_derivative1 = col_character(),
#   trans_y_derivative1_power2 = col_character(),
#   trans_z_derivative1 = col_character(),
#   trans_z_derivative1_power2 = col_character(),
#   rot_x_derivative1 = col_character(),
#   rot_x_derivative1_power2 = col_character(),
#   rot_y_derivative1 = col_character(),
#   rot_y_derivative1_power2 = col_character(),
#   rot_z_derivative1 = col_character()
#   # ... with 1 more columns
# )
# See spec(...) for full column specifications.
# --------Applying classifier--------
# --------Writing summaries to /data00/projects/geoscan_v2/data/bids_data/derivatives/outlier/auto-motion-fmriprep--------
# `summarise()` has grouped output by 'subjectID', 'wave', 'task'. You can override using the `.groups` argument.
# `summarise()` has grouped output by 'subjectID', 'wave'. You can override using the `.groups` argument.
# Transforming realignment parameters to Euclidean distance
# --------Writing text files to /data00/projects/geoscan_v2/data/bids_data/derivatives/outlier/auto-motion-fmriprep--------
# /data00/projects/geoscan_v2/data/bids_data/derivatives/outlier/auto-motion-fmriprep/sub-GEO021 does not exist. Creating it now.
# /data00/projects/geoscan_v2/data/bids_data/derivatives/outlier/auto-motion-fmriprep/sub-GEO033 does not exist. Creating it now.
# /data00/projects/geoscan_v2/data/bids_data/derivatives/outlier/auto-motion-fmriprep/sub-GEO036 does not exist. Creating it now.
# /data00/projects/geoscan_v2/data/bids_data/derivatives/outlier/auto-motion-fmriprep/sub-GEO037 does not exist. Creating it now.
# /data00/projects/geoscan_v2/data/bids_data/derivatives/outlier/auto-motion-fmriprep/sub-GEO053 does not exist. Creating it now.
# /data00/projects/geoscan_v2/data/bids_data/derivatives/outlier/auto-motion-fmriprep/sub-GEO061 does not exist. Creating it now.
# /data00/projects/geoscan_v2/data/bids_data/derivatives/outlier/auto-motion-fmriprep/sub-GEO064 does not exist. Creating it now.
# /data00/projects/geoscan_v2/data/bids_data/derivatives/outlier/auto-motion-fmriprep/sub-GEO067 does not exist. Creating it now.
# /data00/projects/geoscan_v2/data/bids_data/derivatives/outlier/auto-motion-fmriprep/sub-GEO068 does not exist. Creating it now.
# /data00/projects/geoscan_v2/data/bids_data/derivatives/outlier/auto-motion-fmriprep/sub-GEO071 does not exist. Creating it now.
# /data00/projects/geoscan_v2/data/bids_data/derivatives/outlier/auto-motion-fmriprep/sub-GEO073 does not exist. Creating it now.
# /data00/projects/geoscan_v2/data/bids_data/derivatives/outlier/auto-motion-fmriprep/sub-GEO074 does not exist. Creating it now.
# /data00/projects/geoscan_v2/data/bids_data/derivatives/outlier/auto-motion-fmriprep/sub-GEO078 does not exist. Creating it now.
# --------Writing plots to /data00/projects/geoscan_v2/data/bids_data/derivatives/outlier/auto-motion-fmriprep--------
# Note: Using an external vector in selections is ambiguous.
# ℹ Use `all_of(figIndicators)` instead of `figIndicators` to silence this message.
# ℹ See <https://tidyselect.r-lib.org/reference/faq-external-vector.html>.
# This message is displayed once per session.

# %%
outlier = []
for reg_txt in glob.glob('../../data/bids_data/derivatives/outlier/auto-motion-fmriprep/sub-*/sub-*_regressors.txt'):
    
    reg_df = pd.read_csv(reg_txt, sep='\t')
    bids_vars = extract_snakecase(os.path.basename(reg_txt))

    idx = np.where(reg_df['trash'] == 1)[0]
    
    if len(idx) > 0:

        bids_vars['outlier_type'] = 'auto'
        bids_vars['outlier_vol'] = idx

        outlier.append(pd.DataFrame(bids_vars))    

outlier = pd.concat(outlier, ignore_index=True)
outlier.to_csv(os.path.join(output_path, 'outlier_auto.csv'), index=False)

# %% [markdown]
# ## Rule-based outlier detection
#
# ### Generate combined file and separate motion regressor files

# %%
outlier = []

for f in glob.glob(os.path.join(fmriprep_path, 'sub-*/ses-t2/func/*confounds_regressors.tsv')):
    print("*", end="")
    
    bn = os.path.basename(f)
    
    bids_vars = extract_snakecase(bn)
    
    confounds = pd.read_csv(f, sep="\t")   
    
    # motion regressor file
    motion_file = bn.replace("confounds", "motion")
    motion_dir = os.path.join(output_path, 'regressors', 'sub-' + bids_vars['sub'])
    
    confounds['trash'] = np.where((np.abs(scale(confounds['global_signal'])) > 3) | (confounds['framewise_displacement'] > 0.75), 1, 0)
    motion_df = confounds[["trans_x", "trans_y", "trans_z", "rot_x", "rot_y", "rot_z", "csf", "trash"]].copy()
    
    motion_df['euclidean_trans'] = np.linalg.norm(confounds[["trans_x", "trans_y", "trans_z"]], axis=1)
    motion_df['euclidean_rot'] = np.linalg.norm(confounds[["rot_x", "rot_y", "rot_z"]] * 50, axis=1)
    motion_df['euclidean_trans_deriv'] = motion_df['euclidean_trans'].diff().fillna(0)
    motion_df['euclidean_rot_deriv'] = motion_df['euclidean_rot'].diff().fillna(0)
    
    os.makedirs(motion_dir, exist_ok=True)
        
    motion_df.to_csv(os.path.join(motion_dir, motion_file), sep='\t', index=False)
    
    # combined outlier file
    for rule_name, rule_expr in rules.items():
        idx = np.where(rule_expr(confounds))[0]
        
        bids_vars['outlier_type'] = rule_name
        bids_vars['outlier_vol'] = idx
        
        outlier.append(pd.DataFrame(bids_vars))    

outlier = pd.concat(outlier, ignore_index=True)
outlier.to_csv(os.path.join(output_path, 'outlier_manual.csv'), index=False)
# Out:
# *****************************************************************************************************

# %% [markdown]
# ## Generate reports

# %%
outlier = (pd.concat([pd.read_csv(x) for x in ['outlier_auto.csv', 'outlier_manual.csv']], ignore_index=True)
            .pivot_table(index=['sub','task','run','outlier_vol'], 
                              values='outlier_type', 
                              aggfunc=lambda x: ', '.join(x))
            .reset_index())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-8-e6a96bf8307a> in <module>
# ----> 1 outlier = (pd.concat([pd.read_csv(x) for x in ['outlier_auto.csv', 'outlier_manual.csv']], ignore_index=True)
#       2             .pivot_table(index=['sub','task','run','outlier_vol'],
#       3                               values='outlier_type',
#       4                               aggfunc=lambda x: ', '.join(x))
#       5             .reset_index())
#
# <ipython-input-8-e6a96bf8307a> in <listcomp>(.0)
# ----> 1 outlier = (pd.concat([pd.read_csv(x) for x in ['outlier_auto.csv', 'outlier_manual.csv']], ignore_index=True)
#       2             .pivot_table(index=['sub','task','run','outlier_vol'],
#       3                               values='outlier_type',
#       4                               aggfunc=lambda x: ', '.join(x))
#       5             .reset_index())
#
# /usr/local/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     608     kwds.update(kwds_defaults)
#     609
# --> 610     return _read(filepath_or_buffer, kwds)
#     611
#     612
#
# /usr/local/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     460
#     461     # Create the parser.
# --> 462     parser = TextFileReader(filepath_or_buffer, **kwds)
#     463
#     464     if chunksize or iterator:
#
# /usr/local/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     817             self.options["has_index_names"] = kwds["has_index_names"]
#     818
# --> 819         self._engine = self._make_engine(self.engine)
#     820
#     821     def close(self):
#
# /usr/local/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1048             )
#    1049         # error: Too many arguments for "ParserBase"
# -> 1050         return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#    1051
#    1052     def _failover_to_python(self):
#
# /usr/local/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1865
#    1866         # open handles
# -> 1867         self._open_handles(src, kwds)
#    1868         assert self.handles is not None
#    1869         for key in ("storage_options", "encoding", "memory_map", "compression"):
#
# /usr/local/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in _open_handles(self, src, kwds)
#    1366             compression=kwds.get("compression", None),
#    1367             memory_map=kwds.get("memory_map", False),
# -> 1368             storage_options=kwds.get("storage_options", None),
#    1369         )
#    1370
#
# /usr/local/anaconda3/lib/python3.7/site-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     645                 encoding=ioargs.encoding,
#     646                 errors=errors,
# --> 647                 newline="",
#     648             )
#     649         else:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'outlier_auto.csv'

# %%
os.makedirs(os.path.join(output_path, 'outlier_imgs'), exist_ok=True)

for (sub, task, run), outlier_df in outlier.groupby(['sub','task','run']):
    
    print(sub, task, run)
    
    outlier_imgs = image.index_img(nii_file.format(sub=sub, task=task, run=int(run)), outlier_df['outlier_vol'])
    
    for img, vol, otype in zip(image.iter_img(outlier_imgs), outlier_df['outlier_vol'], outlier_df['outlier_type']):
        plotting.plot_anat(anat_img=img, 
                           cut_coords=[0,0,0], 
                           output_file=f'temp{vol:04d}.png', 
                           display_mode='ortho', 
                           title=f'Vol {vol:04d} - {otype}', 
                           annotate=False, draw_cross=False, black_bg='auto', dim='auto')
    
    images = []
    for vol in outlier_df['outlier_vol']:
        images.append(imageio.imread(f'temp{vol:04d}.png'))
    imageio.mimsave(os.path.join(output_path, f'outlier_imgs/sub-{sub}_task-{task}_run-{run}.gif'), images, fps=1)
    
    for img in glob.glob('temp*.png'):
        os.remove(img)

# %%
outlier_summary = outlier.pivot_table(index=['sub','task','run'], values='outlier_vol', aggfunc='count').reset_index().pivot(index='sub', columns=['task','run']).fillna(0)
outlier_summary.to_csv(os.path.join(output_path, 'outlier_summary.csv'), index=False)

# %% [markdown]
# ## Create nuisance regressor files

# %%
outlier = pd.read_csv(os.path.join(output_path, 'outlier_manual.csv'))

# %%
outlier = []

for f in glob.glob(os.path.join(fmriprep_path, 'sub-*/ses-t2/func/*confounds_regressors.tsv')):
    print("*", end="")
# Out:
# **********************************************

# %%
glob.glob(os.path.join(fmriprep_path, 'sub-*/ses-t2/func/*confounds_regressors.tsv'))
# Out:
# ['/data00/projects/geoscan_v2/data/bids_data/derivatives/fmriprep/sub-GEO015/ses-t2/func/sub-GEO015_ses-t2_task-image_run-1_desc-confounds_regressors.tsv',
#  '/data00/projects/geoscan_v2/data/bids_data/derivatives/fmriprep/sub-GEO015/ses-t2/func/sub-GEO015_ses-t2_task-image_run-2_desc-confounds_regressors.tsv',
#  '/data00/projects/geoscan_v2/data/bids_data/derivatives/fmriprep/sub-GEO015/ses-t2/func/sub-GEO015_ses-t2_task-image_run-3_desc-confounds_regressors.tsv',
#  '/data00/projects/geoscan_v2/data/bids_data/derivatives/fmriprep/sub-GEO015/ses-t2/func/sub-GEO015_ses-t2_task-image_run-4_desc-confounds_regressors.tsv',
#  '/data00/projects/geoscan_v2/data/bids_data/derivatives/fmriprep/sub-GEO015/ses-t2/func/sub-GEO015_ses-t2_task-image_run-5_desc-confounds_regressors.tsv',
#  '/data00/projects/geoscan_v2/data/bids_data/derivatives/fmriprep/sub-GS005/ses-t2/func/sub-GS005_ses-t2_task-image_run-1_desc-confounds_regressors.tsv',
#  '/data00/projects/geoscan_v2/data/bids_data/derivatives/fmriprep/sub-GS005/ses-t2/func/sub-GS005_ses-t2_task-image_run-2_desc-confounds_regressors.tsv',
#  '/data00/projects/geoscan_v2/data/bids_data/derivatives/fmriprep/sub-GS005/ses-t2/func/sub-GS005_ses-t2_task-image_run-3_desc-confounds_regressors.tsv',
#  '/data00/projects/geoscan_v2/data/bids_data/derivatives/fmriprep/sub-GS005/ses-t2/func/sub-GS005_ses-t2_task-image_run-4_desc-confounds_regressors.tsv',
#  '/data00/projects/geoscan_v2/data/bids_data/derivatives/fmriprep/sub-GS005/ses-t2/func/sub-GS005_ses-t2_task-image_run-5_desc-confounds_regressors.tsv',
#  '/data00/projects/geoscan_v2/data/bids_data/derivatives/fmriprep/sub-GS005/ses-t2/func/sub-GS005_ses-t2_task-rest_desc-confounds_regressors.tsv',
#  '/data00/projects/geoscan_v2/data/bids_data/derivatives/fmriprep/sub-GS017/ses-t2/func/sub-GS017_ses-t2_task-image_run-2_desc-confounds_regressors.tsv',
#  '/data00/projects/geoscan_v2/data/bids_data/derivatives/fmriprep/sub-GS017/ses-t2/func/sub-GS017_ses-t2_task-image_run-3_desc-confounds_regressors.tsv',
#  '/data00/projects/geoscan_v2/data/bids_data/derivatives/fmriprep/sub-GS017/ses-t2/func/sub-GS017_ses-t2_task-image_run-4_desc-confounds_regressors.tsv',
#  '/data00/projects/geoscan_v2/data/bids_data/derivatives/fmriprep/sub-GS017/ses-t2/func/sub-GS017_ses-t2_task-image_run-5_desc-confounds_regressors.tsv',
#  '/data00/projects/geoscan_v2/data/bids_data/derivatives/fmriprep/sub-GS017/ses-t2/func/sub-GS017_ses-t2_task-rest_desc-confounds_regressors.tsv',
#  '/data00/projects/geoscan_v2/data/bids_data/derivatives/fmriprep/sub-GS022/ses-t2/func/sub-GS022_ses-t2_task-image_run-1_desc-confounds_regressors.tsv',
#  '/data00/projects/geoscan_v2/data/bids_data/derivatives/fmriprep/sub-GS022/ses-t2/func/sub-GS022_ses-t2_task-image_run-2_desc-confounds_regressors.tsv',
#  '/data00/projects/geoscan_v2/data/bids_data/derivatives/fmriprep/sub-GS022/ses-t2/func/sub-GS022_ses-t2_task-image_run-3_desc-confounds_regressors.tsv',
#  '/data00/projects/geoscan_v2/data/bids_data/derivatives/fmriprep/sub-GS022/ses-t2/func/sub-GS022_ses-t2_task-image_run-4_desc-confounds_regressors.tsv',
#  '/data00/projects/geoscan_v2/data/bids_data/derivatives/fmriprep/sub-GS022/ses-t2/func/sub-GS022_ses-t2_task-image_run-5_desc-confounds_regressors.tsv',
#  '/data00/projects/geoscan_v2/data/bids_data/derivatives/fmriprep/sub-GS024/ses-t2/func/sub-GS024_ses-t2_task-image_run-1_desc-confounds_regressors.tsv',
#  '/data00/projects/geoscan_v2/data/bids_data/derivatives/fmriprep/sub-GS024/ses-t2/func/sub-GS024_ses-t2_task-image_run-2_desc-confounds_regressors.tsv',
#  '/data00/projects/geoscan_v2/data/bids_data/derivatives/fmriprep/sub-GS024/ses-t2/func/sub-GS024_ses-t2_task-image_run-3_desc-confounds_regressors.tsv',
#  '/data00/projects/geoscan_v2/data/bids_data/derivatives/fmriprep/sub-GS024/ses-t2/func/sub-GS024_ses-t2_task-image_run-4_desc-confounds_regressors.tsv',
#  '/data00/projects/geoscan_v2/data/bids_data/derivatives/fmriprep/sub-GS024/ses-t2/func/sub-GS024_ses-t2_task-image_run-5_desc-confounds_regressors.tsv',
#  '/data00/projects/geoscan_v2/data/bids_data/derivatives/fmriprep/sub-GS025/ses-t2/func/sub-GS025_ses-t2_task-image_run-1_desc-confounds_regressors.tsv',
#  '/data00/projects/geoscan_v2/data/bids_data/derivatives/fmriprep/sub-GS025/ses-t2/func/sub-GS025_ses-t2_task-image_run-2_desc-confounds_regressors.tsv',
#  '/data00/projects/geoscan_v2/data/bids_data/derivatives/fmriprep/sub-GS025/ses-t2/func/sub-GS025_ses-t2_task-image_run-3_desc-confounds_regressors.tsv',
#  '/data00/projects/geoscan_v2/data/bids_data/derivatives/fmriprep/sub-GS025/ses-t2/func/sub-GS025_ses-t2_task-image_run-4_desc-confounds_regressors.tsv',
#  '/data00/projects/geoscan_v2/data/bids_data/derivatives/fmriprep/sub-GS025/ses-t2/func/sub-GS025_ses-t2_task-image_run-5_desc-confounds_regressors.tsv',
#  '/data00/projects/geoscan_v2/data/bids_data/derivatives/fmriprep/sub-GS028/ses-t2/func/sub-GS028_ses-t2_task-image_run-1_desc-confounds_regressors.tsv',
#  '/data00/projects/geoscan_v2/data/bids_data/derivatives/fmriprep/sub-GS028/ses-t2/func/sub-GS028_ses-t2_task-image_run-2_desc-confounds_regressors.tsv',
#  '/data00/projects/geoscan_v2/data/bids_data/derivatives/fmriprep/sub-GS028/ses-t2/func/sub-GS028_ses-t2_task-image_run-3_desc-confounds_regressors.tsv',
#  '/data00/projects/geoscan_v2/data/bids_data/derivatives/fmriprep/sub-GS028/ses-t2/func/sub-GS028_ses-t2_task-image_run-4_desc-confounds_regressors.tsv',
#  '/data00/projects/geoscan_v2/data/bids_data/derivatives/fmriprep/sub-GS028/ses-t2/func/sub-GS028_ses-t2_task-image_run-5_desc-confounds_regressors.tsv',
#  '/data00/projects/geoscan_v2/data/bids_data/derivatives/fmriprep/sub-GS031/ses-t2/func/sub-GS031_ses-t2_task-image_run-1_desc-confounds_regressors.tsv',
#  '/data00/projects/geoscan_v2/data/bids_data/derivatives/fmriprep/sub-GS031/ses-t2/func/sub-GS031_ses-t2_task-image_run-2_desc-confounds_regressors.tsv',
#  '/data00/projects/geoscan_v2/data/bids_data/derivatives/fmriprep/sub-GS031/ses-t2/func/sub-GS031_ses-t2_task-image_run-3_desc-confounds_regressors.tsv',
#  '/data00/projects/geoscan_v2/data/bids_data/derivatives/fmriprep/sub-GS031/ses-t2/func/sub-GS031_ses-t2_task-image_run-4_desc-confounds_regressors.tsv',
#  '/data00/projects/geoscan_v2/data/bids_data/derivatives/fmriprep/sub-GS031/ses-t2/func/sub-GS031_ses-t2_task-image_run-5_desc-confounds_regressors.tsv',
#  '/data00/projects/geoscan_v2/data/bids_data/derivatives/fmriprep/sub-GS032/ses-t2/func/sub-GS032_ses-t2_task-image_run-1_desc-confounds_regressors.tsv',
#  '/data00/projects/geoscan_v2/data/bids_data/derivatives/fmriprep/sub-GS032/ses-t2/func/sub-GS032_ses-t2_task-image_run-2_desc-confounds_regressors.tsv',
#  '/data00/projects/geoscan_v2/data/bids_data/derivatives/fmriprep/sub-GS032/ses-t2/func/sub-GS032_ses-t2_task-image_run-3_desc-confounds_regressors.tsv',
#  '/data00/projects/geoscan_v2/data/bids_data/derivatives/fmriprep/sub-GS032/ses-t2/func/sub-GS032_ses-t2_task-image_run-4_desc-confounds_regressors.tsv',
#  '/data00/projects/geoscan_v2/data/bids_data/derivatives/fmriprep/sub-GS032/ses-t2/func/sub-GS032_ses-t2_task-image_run-5_desc-confounds_regressors.tsv']

# %%
fmriprep_path
# Out:
# '/data00/projects/geoscan_v2/data/bids_data/derivatives/fmriprep'
