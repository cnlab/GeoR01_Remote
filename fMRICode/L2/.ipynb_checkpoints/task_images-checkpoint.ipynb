# %% [markdown]
# ### Instructions
#
# 1. Plug in the `model_path`
# 2. From `Run` menu, select `Restart Kernel and Run All Cells`
# 3. From `View` menu, select `Collapse All Code`

# %%
model_path = '/data00/projects/geoscan_v2/scripts/L1/model_images.json'

# %%
import os, glob, re, sys, json, copy  

import nipype.interfaces.io as nio           
import nipype.interfaces.spm as spm    
import nipype.interfaces.matlab as mlab     
import nipype.pipeline.engine as pe 
import nipype.interfaces.utility as util

import pandas as pd
import numpy as np
import scipy as sp
import scipy.io as sio

from nilearn import plotting

# %%
def ensure_list(obj):
    if type(obj) is not list:
        return [obj]
    else:
        return obj

def copy_from_template(target, template):
    for key, item in template.items():
        if key not in target.keys():
            target[key] = copy.deepcopy(template[key])
        elif type(item) is dict:
            copy_from_template(target[key], template[key])

# %%
with open(model_path, 'r') as f:
    model = json.load(f)

for template_path in ensure_list(model.get("Template", [])):
    with open(template_path, 'r') as f:
        template = json.load(f)
    copy_from_template(model, template)
    
env = model['Environment']
job_name = 'task-{}_model-{}'.format(model['Info']['task'], model['Info']['model'])

# %%
env
# Out:
# {'job_path': 'models',
#  'spm_path': '/data00/tools/spm12mega',
#  'fsl_path': '/data00/tools/fsl',
#  'data_path': '/data00/projects/geoscan_v2',
#  'output_path': '/data00/projects/geoscan_v2/data/bids_data/derivatives/nipype',
#  'working_path': '/data00/projects/geoscan_v2/data/bids_data/working/nipype'}

# %%
mlab.MatlabCommand.set_default_matlab_cmd("matlab -nodesktop -nosplash")
mlab.MatlabCommand.set_default_paths(env["spm_path"])

# %%
con_df = []
print("Aggregating contrast files...")

for sub_folder in glob.glob(os.path.join(env['output_path'], job_name, 'sub-*')):
    
    if not os.path.isdir(sub_folder):
        continue
    
    sub = os.path.basename(sub_folder)
    
    spm_file = os.path.join(sub_folder, 'SPM.mat')
    if not os.path.exists(spm_file):
        continue
    
    spm_mat = sio.loadmat(spm_file, 
               squeeze_me=True, struct_as_record=False)
    
    for n, con in enumerate(spm_mat['SPM'].xCon, start=1):
        con_file = os.path.join(sub_folder, f"con_{n:04d}.nii")
        if os.path.exists(con_file):
            con_df.append({'sub': sub,
                          'con': con.name,
                          'path': con_file})
        
con_df = pd.DataFrame(con_df)
con_df.to_csv(os.path.join(env['output_path'], job_name, 'contrasts.csv'), index=False)
con_df.pivot_table(index='con', values='sub', aggfunc='count')
# Out:
# Aggregating contrast files...
#                                               sub
# con
# rating                                          8
# rest                                            5
# retailSmokeRegister_v_retailNonsmokeRegister    8
# retailSmoke_v_retailNonsmoke                    8
# retail_nonsmoke_promo                           8
# retail_nonsmoke_promo_v_rest                    5
# retail_nonsmoke_register                        8
# retail_nonsmoke_register_v_rest                 5
# retail_smoke_branded                            8
# retail_smoke_branded_v_rest                     5
# retail_smoke_promo                              8
# retail_smoke_promo_v_rest                       5
# retail_smoke_register                           8
# retail_smoke_register_v_rest                    5
# standardSmoke_v_rest                            5
# standardSmoke_v_standardNonsmoke                8
# standard_nonsmoke                               8
# standard_nonsmoke_v_rest                        5
# standard_smoke                                  8
# stimuli_personal_nonsmoke                       1
# stimuli_personal_smoke                          1

# %%
def get_contrast_files(contrast_name, contrast_df):
    return contrast_df.query(f'con == "{contrast_name}"').path.tolist()

# %%
l2analysis_path = os.path.join(env['output_path'], job_name, "l2analysis")

# %%
l2analysis = pe.Workflow(base_dir=os.path.join(env['working_path'], job_name), name='l2analysis')

infosource = pe.Node(util.IdentityInterface(fields=['contrast_name']),
                  name="infosource")
infosource.iterables = ('contrast_name', con_df.con.unique().tolist())

getcontrastfiles = pe.Node(util.Function(input_names=['contrast_name', 'contrast_df'],
                                        output_names=['contrast_files'],
                                        function=get_contrast_files),
                    name='getcontrastfiles')
getcontrastfiles.inputs.contrast_df = con_df

# One Sample T-Test Design - creates one sample T-Test Design
onesamplettestdes = pe.Node(spm.OneSampleTTestDesign(),
                         name="onesampttestdes")

# EstimateModel - estimate the parameters of the model
level2estimate = pe.Node(spm.EstimateModel(estimation_method={'Classical': 1}),
                      name="level2estimate")

# EstimateContrast - estimates simple group contrast
level2conestimate = pe.Node(spm.EstimateContrast(group_contrast=True), 
                            name="level2conestimate")
cont = ['Group', 'T', ['mean'], [1]]
level2conestimate.inputs.contrasts = [cont]

# Datasink - creates output folder for important outputs
datasink = pe.Node(nio.DataSink(base_directory=l2analysis_path), 
                   name="datasink")
datasink.inputs.substitutions = [('_contrast_name_', '')]

# Connect workflow
l2analysis.connect([(infosource, getcontrastfiles, [('contrast_name', 'contrast_name')]),
                    (getcontrastfiles, onesamplettestdes, [('contrast_files', 'in_files')]),
                    (onesamplettestdes, level2estimate, [('spm_mat_file',
                                                          'spm_mat_file')] ),
                    (level2estimate, level2conestimate, [('spm_mat_file',
                                                          'spm_mat_file'),
                                                         ('beta_images',
                                                          'beta_images'),
                                                         ('residual_image',
                                                          'residual_image')]),
                    (level2conestimate, datasink, [('spm_mat_file',
                                                    '@spm_mat'),
                                                   ('spmT_images',
                                                    '@T'),
                                                   ('con_images',
                                                    '@con')])
                   ])

l2analysis.run()
# Out:
# 220707-14:33:57,191 nipype.workflow INFO:
# 	 Workflow l2analysis settings: ['check', 'execution', 'logging', 'monitoring']
# 220707-14:33:57,821 nipype.workflow INFO:
# 	 Running serially.
# 220707-14:33:57,823 nipype.workflow INFO:
# 	 [Node] Setting-up "l2analysis.getcontrastfiles" in "/fmriNASTest/data00/projects/geoscan_v2/data/bids_data/working/nipype/task-image_model-condition-hp160/l2analysis/_contrast_name_standard_nonsmoke_v_rest/getcontrastfiles".
# 220707-14:33:58,34 nipype.workflow INFO:
# 	 [Node] Running "getcontrastfiles" ("nipype.interfaces.utility.wrappers.Function")
# 220707-14:33:58,109 nipype.workflow INFO:
# 	 [Node] Finished "l2analysis.getcontrastfiles".
# 220707-14:33:58,111 nipype.workflow INFO:
# 	 [Node] Setting-up "l2analysis.onesampttestdes" in "/fmriNASTest/data00/projects/geoscan_v2/data/bids_data/working/nipype/task-image_model-condition-hp160/l2analysis/_contrast_name_standard_nonsmoke_v_rest/onesampttestdes".
# 220707-14:33:58,275 nipype.workflow INFO:
# 	 [Node] Running "onesampttestdes" ("nipype.interfaces.spm.model.OneSampleTTestDesign")
# 220707-14:34:22,784 nipype.workflow INFO:
# 	 [Node] Finished "l2analysis.onesampttestdes".
# 220707-14:34:22,786 nipype.workflow INFO:
# 	 [Node] Setting-up "l2analysis.level2estimate" in "/fmriNASTest/data00/projects/geoscan_v2/data/bids_data/working/nipype/task-image_model-condition-hp160/l2analysis/_contrast_name_standard_nonsmoke_v_rest/level2estimate".
# 220707-14:34:22,934 nipype.workflow INFO:
# 	 [Node] Running "level2estimate" ("nipype.interfaces.spm.model.EstimateModel")
# 220707-14:34:48,3 nipype.workflow INFO:
# 	 [Node] Finished "l2analysis.level2estimate".
# 220707-14:34:48,6 nipype.workflow INFO:
# 	 [Node] Setting-up "l2analysis.level2conestimate" in "/fmriNASTest/data00/projects/geoscan_v2/data/bids_data/working/nipype/task-image_model-condition-hp160/l2analysis/_contrast_name_standard_nonsmoke_v_rest/level2conestimate".
# 220707-14:34:48,203 nipype.workflow INFO:
# 	 [Node] Running "level2conestimate" ("nipype.interfaces.spm.model.EstimateContrast")
# 220707-14:35:06,469 nipype.workflow INFO:
# 	 [Node] Finished "l2analysis.level2conestimate".
# 220707-14:35:06,471 nipype.workflow INFO:
# 	 [Node] Setting-up "l2analysis.datasink" in "/fmriNASTest/data00/projects/geoscan_v2/data/bids_data/working/nipype/task-image_model-condition-hp160/l2analysis/_contrast_name_standard_nonsmoke_v_rest/datasink".
# 220707-14:35:06,618 nipype.workflow INFO:
# 	 [Node] Running "datasink" ("nipype.interfaces.io.DataSink")
# 220707-14:35:06,621 nipype.interface INFO:
# 	 sub: /data00/projects/geoscan_v2/data/bids_data/derivatives/nipype/task-image_model-condition-hp160/l2analysis/_contrast_name_standard_nonsmoke_v_rest/SPM.mat -> /data00/projects/geoscan_v2/data/bids_data/derivatives/nipype/task-image_model-condition-hp160/l2analysis/standard_nonsmoke_v_rest/SPM.mat
# 220707-14:35:06,664 nipype.interface INFO:
# 	 sub: /data00/projects/geoscan_v2/data/bids_data/derivatives/nipype/task-image_model-condition-hp160/l2analysis/_contrast_name_standard_nonsmoke_v_rest/spmT_0001.nii -> /data00/projects/geoscan_v2/data/bids_data/derivatives/nipype/task-image_model-condition-hp160/l2analysis/standard_nonsmoke_v_rest/spmT_0001.nii
# 220707-14:35:06,681 nipype.interface INFO:
# 	 sub: /data00/projects/geoscan_v2/data/bids_data/derivatives/nipype/task-image_model-condition-hp160/l2analysis/_contrast_name_standard_nonsmoke_v_rest/con_0001.nii -> /data00/projects/geoscan_v2/data/bids_data/derivatives/nipype/task-image_model-condition-hp160/l2analysis/standard_nonsmoke_v_rest/con_0001.nii
# 220707-14:35:06,757 nipype.workflow INFO:
# 	 [Node] Finished "l2analysis.datasink".
# 220707-14:35:06,759 nipype.workflow INFO:
# 	 [Node] Setting-up "l2analysis.getcontrastfiles" in "/fmriNASTest/data00/projects/geoscan_v2/data/bids_data/working/nipype/task-image_model-condition-hp160/l2analysis/_contrast_name_standardSmoke_v_rest/getcontrastfiles".
# 220707-14:35:06,926 nipype.workflow INFO:
# 	 [Node] Running "getcontrastfiles" ("nipype.interfaces.utility.wrappers.Function")
# 220707-14:35:07,31 nipype.workflow INFO:
# 	 [Node] Finished "l2analysis.getcontrastfiles".
# 220707-14:35:07,32 nipype.workflow INFO:
# 	 [Node] Setting-up "l2analysis.onesampttestdes" in "/fmriNASTest/data00/projects/geoscan_v2/data/bids_data/working/nipype/task-image_model-condition-hp160/l2analysis/_contrast_name_standardSmoke_v_rest/onesampttestdes".
# 220707-14:35:07,158 nipype.workflow INFO:
# 	 [Node] Running "onesampttestdes" ("nipype.interfaces.spm.model.OneSampleTTestDesign")
# 220707-14:35:25,584 nipype.workflow INFO:
# 	 [Node] Finished "l2analysis.onesampttestdes".
# 220707-14:35:25,587 nipype.workflow INFO:
# 	 [Node] Setting-up "l2analysis.level2estimate" in "/fmriNASTest/data00/projects/geoscan_v2/data/bids_data/working/nipype/task-image_model-condition-hp160/l2analysis/_contrast_name_standardSmoke_v_rest/level2estimate".
# 220707-14:35:25,729 nipype.workflow INFO:
# 	 [Node] Running "level2estimate" ("nipype.interfaces.spm.model.EstimateModel")
# 220707-14:35:49,75 nipype.workflow INFO:
# 	 [Node] Finished "l2analysis.level2estimate".
# 220707-14:35:49,77 nipype.workflow INFO:
# 	 [Node] Setting-up "l2analysis.level2conestimate" in "/fmriNASTest/data00/projects/geoscan_v2/data/bids_data/working/nipype/task-image_model-condition-hp160/l2analysis/_contrast_name_standardSmoke_v_rest/level2conestimate".
# 220707-14:35:49,262 nipype.workflow INFO:
# 	 [Node] Running "level2conestimate" ("nipype.interfaces.spm.model.EstimateContrast")
# 220707-14:36:06,895 nipype.workflow INFO:
# 	 [Node] Finished "l2analysis.level2conestimate".
# 220707-14:36:06,896 nipype.workflow INFO:
# 	 [Node] Setting-up "l2analysis.datasink" in "/fmriNASTest/data00/projects/geoscan_v2/data/bids_data/working/nipype/task-image_model-condition-hp160/l2analysis/_contrast_name_standardSmoke_v_rest/datasink".
# 220707-14:36:07,48 nipype.workflow INFO:
# 	 [Node] Running "datasink" ("nipype.interfaces.io.DataSink")
# 220707-14:36:07,51 nipype.interface INFO:
# 	 sub: /data00/projects/geoscan_v2/data/bids_data/derivatives/nipype/task-image_model-condition-hp160/l2analysis/_contrast_name_standardSmoke_v_rest/SPM.mat -> /data00/projects/geoscan_v2/data/bids_data/derivatives/nipype/task-image_model-condition-hp160/l2analysis/standardSmoke_v_rest/SPM.mat
# 220707-14:36:07,93 nipype.interface INFO:
# 	 sub: /data00/projects/geoscan_v2/data/bids_data/derivatives/nipype/task-image_model-condition-hp160/l2analysis/_contrast_name_standardSmoke_v_rest/spmT_0001.nii -> /data00/projects/geoscan_v2/data/bids_data/derivatives/nipype/task-image_model-condition-hp160/l2analysis/standardSmoke_v_rest/spmT_0001.nii
# 220707-14:36:07,109 nipype.interface INFO:
# 	 sub: /data00/projects/geoscan_v2/data/bids_data/derivatives/nipype/task-image_model-condition-hp160/l2analysis/_contrast_name_standardSmoke_v_rest/con_0001.nii -> /data00/projects/geoscan_v2/data/bids_data/derivatives/nipype/task-image_model-condition-hp160/l2analysis/standardSmoke_v_rest/con_0001.nii
# 220707-14:36:07,193 nipype.workflow INFO:
# 	 [Node] Finished "l2analysis.datasink".
# 220707-14:36:07,194 nipype.workflow INFO:
# 	 [Node] Setting-up "l2analysis.getcontrastfiles" in "/fmriNASTest/data00/projects/geoscan_v2/data/bids_data/working/nipype/task-image_model-condition-hp160/l2analysis/_contrast_name_retail_smoke_branded_v_rest/getcontrastfiles".
# 220707-14:36:07,374 nipype.workflow INFO:
# 	 [Node] Running "getcontrastfiles" ("nipype.interfaces.utility.wrappers.Function")
# 220707-14:36:07,472 nipype.workflow INFO:
# 	 [Node] Finished "l2analysis.getcontrastfiles".
# 220707-14:36:07,474 nipype.workflow INFO:
# 	 [Node] Setting-up "l2analysis.onesampttestdes" in "/fmriNASTest/data00/projects/geoscan_v2/data/bids_data/working/nipype/task-image_model-condition-hp160/l2analysis/_contrast_name_retail_smoke_branded_v_rest/onesampttestdes".
# 220707-14:36:07,632 nipype.workflow INFO:
# 	 [Node] Running "onesampttestdes" ("nipype.interfaces.spm.model.OneSampleTTestDesign")
# 220707-14:36:25,904 nipype.workflow INFO:
# 	 [Node] Finished "l2analysis.onesampttestdes".
# 220707-14:36:25,907 nipype.workflow INFO:
# 	 [Node] Setting-up "l2analysis.level2estimate" in "/fmriNASTest/data00/projects/geoscan_v2/data/bids_data/working/nipype/task-image_model-condition-hp160/l2analysis/_contrast_name_retail_smoke_branded_v_rest/level2estimate".
# 220707-14:36:26,77 nipype.workflow INFO:
# 	 [Node] Running "level2estimate" ("nipype.interfaces.spm.model.EstimateModel")
# 220707-14:36:50,784 nipype.workflow INFO:
# 	 [Node] Finished "l2analysis.level2estimate".
# 220707-14:36:50,786 nipype.workflow INFO:
# 	 [Node] Setting-up "l2analysis.level2conestimate" in "/fmriNASTest/data00/projects/geoscan_v2/data/bids_data/working/nipype/task-image_model-condition-hp160/l2analysis/_contrast_name_retail_smoke_branded_v_rest
nipype.interface INFO:
# 	 sub: /data00/projects/geoscan_v2/data/bids_data/derivatives/nipype/task-image_model-condition-hp160/l2analysis/_contrast_name_standard_smoke/con_0001.nii -> /data00/projects/geoscan_v2/data/bids_data/derivatives/nipype/task-image_model-condition-hp160/l2analysis/standard_smoke/con_0001.nii
# 220707-14:47:51,532 nipype.workflow INFO:
# 	 [Node] Finished "l2analysis.datasink".
# 220707-14:47:51,533 nipype.workflow INFO:
# 	 [Node] Setting-up "l2analysis.getcontrastfiles" in "/fmriNASTest/data00/projects/geoscan_v2/data/bids_data/working/nipype/task-image_model-condition-hp160/l2analysis/_contrast_name_retail_nonsmoke_register/getcontrastfiles".
# 220707-14:47:51,562 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "l2analysis.getcontrastfiles".
# ...
# 220707-14:51:14,96 nipype.workflow INFO:
# 	 [Node] Running "onesampttestdes" ("nipype.interfaces.spm.model.OneSampleTTestDesign")
# 220707-14:51:32,449 nipype.workflow INFO:
# 	 [Node] Finished "l2analysis.onesampttestdes".
# 220707-14:51:32,451 nipype.workflow INFO:
# 	 [Node] Setting-up "l2analysis.level2estimate" in "/fmriNASTest/data00/projects/geoscan_v2/data/bids_data/working/nipype/task-image_model-condition-hp160/l2analysis/_contrast_name_retail_smoke_register/level2estimate".
# 220707-14:51:32,473 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "l2analysis.level2estimate".
# 220707-14:51:32,879 nipype.workflow INFO:
# 	 [Node] Running "level2estimate" ("nipype.interfaces.spm.model.EstimateModel")
# 220707-14:51:59,536 nipype.workflow INFO:
# 	 [Node] Finished "l2analysis.level2estimate".
# 220707-14:51:59,538 nipype.workflow INFO:
# 	 [Node] Setting-up "l2analysis.level2conestimate" in "/fmriNASTest/data00/projects/geoscan_v2/data/bids_data/working/nipype/task-image_model-condition-hp160/l2analysis/_contrast_name_retail_smoke_register/level2conestimate".
# 220707-14:51:59,557 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "l2analysis.level2conestimate".
# 220707-14:51:59,962 nipype.workflow INFO:
# 	 [Node] Running "level2conestimate" ("nipype.interfaces.spm.model.EstimateContrast")
# 220707-14:52:17,708 nipype.workflow INFO:
# 	 [Node] Finished "l2analysis.level2conestimate".
# 220707-14:52:17,712 nipype.workflow INFO:
# 	 [Node] Setting-up "l2analysis.datasink" in "/fmriNASTest/data00/projects/geoscan_v2/data/bids_data/working/nipype/task-image_model-condition-hp160/l2analysis/_contrast_name_retail_smoke_register/datasink".
# 220707-14:52:17,740 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "l2analysis.datasink".
# 220707-14:52:17,996 nipype.workflow INFO:
# 	 [Node] Running "datasink" ("nipype.interfaces.io.DataSink")
# 220707-14:52:17,999 nipype.interface INFO:
# 	 sub: /data00/projects/geoscan_v2/data/bids_data/derivatives/nipype/task-image_model-condition-hp160/l2analysis/_contrast_name_retail_smoke_register/SPM.mat -> /data00/projects/geoscan_v2/data/bids_data/derivatives/nipype/task-image_model-condition-hp160/l2analysis/retail_smoke_register/SPM.mat
# 220707-14:52:18,65 nipype.interface INFO:
# 	 sub: /data00/projects/geoscan_v2/data/bids_data/derivatives/nipype/task-image_model-condition-hp160/l2analysis/_contrast_name_retail_smoke_register/spmT_0001.nii -> /data00/projects/geoscan_v2/data/bids_data/derivatives/nipype/task-image_model-condition-hp160/l2analysis/retail_smoke_register/spmT_0001.nii
# 220707-14:52:18,210 nipype.interface INFO:
# 	 sub: /data00/projects/geoscan_v2/data/bids_data/derivatives/nipype/task-image_model-condition-hp160/l2analysis/_contrast_name_retail_smoke_register/con_0001.nii -> /data00/projects/geoscan_v2/data/bids_data/derivatives/nipype/task-image_model-condition-hp160/l2analysis/retail_smoke_register/con_0001.nii
# 220707-14:52:18,415 nipype.workflow INFO:
# 	 [Node] Finished "l2analysis.datasink".
# 220707-14:52:18,416 nipype.workflow INFO:
# 	 [Node] Setting-up "l2analysis.getcontrastfiles" in "/fmriNASTest/data00/projects/geoscan_v2/data/bids_data/working/nipype/task-image_model-condition-hp160/l2analysis/_contrast_name_stimuli_personal_nonsmoke/getcontrastfiles".
# 220707-14:52:18,438 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "l2analysis.getcontrastfiles".
# 220707-14:52:18,783 nipype.workflow INFO:
# 	 [Node] Running "getcontrastfiles" ("nipype.interfaces.utility.wrappers.Function")
# 220707-14:52:18,859 nipype.workflow INFO:
# 	 [Node] Finished "l2analysis.getcontrastfiles".
# 220707-14:52:18,860 nipype.workflow INFO:
# 	 [Node] Setting-up "l2analysis.onesampttestdes" in "/fmriNASTest/data00/projects/geoscan_v2/data/bids_data/working/nipype/task-image_model-condition-hp160/l2analysis/_contrast_name_stimuli_personal_nonsmoke/onesampttestdes".
# 220707-14:52:18,869 nipype.workflow ERROR:
# 	 Node onesampttestdes.a02 failed to run on host fmrisrv2.
# 220707-14:52:18,871 nipype.workflow ERROR:
# 	 Saving crash info to /fmriNASTest/data00/projects/geoscan_v2/scripts/L2/crash-20220707-145218-aresnick@asc.upenn.edu-onesampttestdes.a02-dff25864-2046-418c-a116-f6e950808a66.pklz
# Traceback (most recent call last):
#   File "/usr/local/anaconda3/lib/python3.7/site-packages/nipype/pipeline/plugins/linear.py", line 46, in run
#     node.run(updatehash=updatehash)
#   File "/usr/local/anaconda3/lib/python3.7/site-packages/nipype/pipeline/engine/nodes.py", line 486, in run
#     self._get_hashval()
#   File "/usr/local/anaconda3/lib/python3.7/site-packages/nipype/pipeline/engine/nodes.py", line 538, in _get_hashval
#     self._get_inputs()
#   File "/usr/local/anaconda3/lib/python3.7/site-packages/nipype/pipeline/engine/nodes.py", line 609, in _get_inputs
#     self.set_input(key, deepcopy(output_value))
#   File "/usr/local/anaconda3/lib/python3.7/site-packages/nipype/pipeline/engine/nodes.py", line 302, in set_input
#     setattr(self.inputs, parameter, deepcopy(val))
#   File "/usr/local/anaconda3/lib/python3.7/site-packages/traits/trait_types.py", line 2363, in validate
#     self.error(object, name, value)
#   File "/usr/local/anaconda3/lib/python3.7/site-packages/traits/base_trait_handler.py", line 77, in error
#     object, name, self.full_info(object, name, value), value
# traits.trait_errors.TraitError: The 'in_files' trait of an OneSampleTTestDesignInputSpec instance must be a list of at least 2 items which are a pathlike object or string representing an existing file, but a value of ['/data00/projects/geoscan_v2/data/bids_data/derivatives/nipype/task-image_model-condition-hp160/sub-GS005/con_0003.nii'] <class 'list'> was specified.
#
# Error setting node input:
# Node: onesampttestdes
# input: in_files
# results_file: /fmriNASTest/data00/projects/geoscan_v2/data/bids_data/working/nipype/task-image_model-condition-hp160/l2analysis/_contrast_name_stimuli_personal_nonsmoke/getcontrastfiles/result_getcontrastfiles.pklz
# value: ['/data00/projects/geoscan_v2/data/bids_data/derivatives/nipype/task-image_model-condition-hp160/sub-GS005/con_0003.nii']
#
#
# When creating this crashfile, the results file corresponding
# to the node could not be found.
# 220707-14:52:18,914 nipype.workflow INFO:
# 	 [Node] Setting-up "l2analysis.getcontrastfiles" in "/fmriNASTest/data00/projects/geoscan_v2/data/bids_data/working/nipype/task-image_model-condition-hp160/l2analysis/_contrast_name_rating/getcontrastfiles".
# 220707-14:52:18,931 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "l2analysis.getcontrastfiles".
# 220707-14:52:19,245 nipype.workflow INFO:
# 	 [Node] Running "getcontrastfiles" ("nipype.interfaces.utility.wrappers.Function")
# 220707-14:52:19,354 nipype.workflow INFO:
# 	 [Node] Finished "l2analysis.getcontrastfiles".
# 220707-14:52:19,355 nipype.workflow INFO:
# 	 [Node] Setting-up "l2analysis.onesampttestdes" in "/fmriNASTest/data00/projects/geoscan_v2/data/bids_data/working/nipype/task-image_model-condition-hp160/l2analysis/_contrast_name_rating/onesampttestdes".
# 220707-14:52:19,369 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "l2analysis.onesampttestdes".
# 220707-14:52:19,661 nipype.workflow INFO:
# 	 [Node] Running "onesampttestdes" ("nipype.interfaces.spm.model.OneSampleTTestDesign")
# 220707-14:52:37,968 nipype.workflow INFO:
# 	 [Node] Finished "l2analysis.onesampttestdes".
# 220707-14:52:37,970 nipype.workflow INFO:
# 	 [Node] Setting-up "l2analysis.level2estimate" in "/fmriNASTest/data00/projects/geoscan_v2/data/bids_data/working/nipype/task-image_model-condition-hp160/l2analysis/_contrast_name_rating/level2estimate".
# 220707-14:52:37,991 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "l2analysis.level2estimate".
# 220707-14:52:38,463 nipype.workflow INFO:
# 	 [Node] Running "level2estimate" ("nipype.interfaces.spm.model.EstimateModel")
# 220707-14:53:05,426 nipype.workflow INFO:
# 	 [Node] Finished "l2analysis.level2estimate".
# 220707-14:53:05,428 nipype.workflow INFO:
# 	 [Node] Setting-up "l2analysis.level2conestimate" in "/fmriNASTest/data00/projects/geoscan_v2/data/bids_data/working/nipype/task-image_model-condition-hp160/l2analysis/_contrast_name_rating/level2conestimate".
# 220707-14:53:05,450 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "l2analysis.level2conestimate".
# 220707-14:53:05,862 nipype.workflow INFO:
# 	 [Node] Running "level2conestimate" ("nipype.interfaces.spm.model.EstimateContrast")
# 220707-14:53:23,926 nipype.workflow INFO:
# 	 [Node] Finished "l2analysis.level2conestimate".
# 220707-14:53:23,928 nipype.workflow INFO:
# 	 [Node] Setting-up "l2analysis.datasink" in "/fmriNASTest/data00/projects/geoscan_v2/data/bids_data/working/nipype/task-image_model-condition-hp160/l2analysis/_contrast_name_rating/datasink".
# 220707-14:53:23,951 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "l2analysis.datasink".
# 220707-14:53:24,247 nipype.workflow INFO:
# 	 [Node] Running "datasink" ("nipype.interfaces.io.DataSink")
# 220707-14:53:24,251 nipype.interface INFO:
# 	 sub: /data00/projects/geoscan_v2/data/bids_data/derivatives/nipype/task-image_model-condition-hp160/l2analysis/_contrast_name_rating/SPM.mat -> /data00/projects/geoscan_v2/data/bids_data/derivatives/nipype/task-image_model-condition-hp160/l2analysis/rating/SPM.mat
# 220707-14:53:24,333 nipype.interface INFO:
# 	 sub: /data00/projects/geoscan_v2/data/bids_data/derivatives/nipype/task-image_model-condition-hp160/l2analysis/_contrast_name_rating/spmT_0001.nii -> /data00/projects/geoscan_v2/data/bids_data/derivatives/nipype/task-image_model-condition-hp160/l2analysis/rating/spmT_0001.nii
# 220707-14:53:24,512 nipype.interface INFO:
# 	 sub: /data00/projects/geoscan_v2/data/bids_data/derivatives/nipype/task-image_model-condition-hp160/l2analysis/_contrast_name_rating/con_0001.nii -> /data00/projects/geoscan_v2/data/bids_data/derivatives/nipype/task-image_model-condition-hp160/l2analysis/rating/con_0001.nii
# 220707-14:53:25,239 nipype.workflow INFO:
# 	 [Node] Finished "l2analysis.datasink".
# 220707-14:53:25,241 nipype.workflow INFO:
# 	 [Node] Setting-up "l2analysis.getcontrastfiles" in "/fmriNASTest/data00/projects/geoscan_v2/data/bids_data/working/nipype/task-image_model-condition-hp160/l2analysis/_contrast_name_retail_nonsmoke_promo/getcontrastfiles".
# 220707-14:53:25,265 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "l2analysis.getcontrastfiles".
# 220707-14:53:25,511 nipype.workflow INFO:
# 	 [Node] Running "getcontrastfiles" ("nipype.interfaces.utility.wrappers.Function")
# 220707-14:53:25,609 nipype.workflow INFO:
# 	 [Node] Finished "l2analysis.getcontrastfiles".
# 220707-14:53:25,610 nipype.workflow INFO:
# 	 [Node] Setting-up "l2analysis.onesampttestdes" in "/fmriNASTest/data00/projects/geoscan_v2/data/bids_data/working/nipype/task-image_model-condition-hp160/l2analysis/_contrast_name_retail_nonsmoke_promo/onesampttestdes".
# 220707-14:53:25,624 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "l2analysis.onesampttestdes".
# 220707-14:53:26,26 nipype.workflow INFO:
# 	 [Node] Running "onesampttestdes" ("nipype.interfaces.spm.model.OneSampleTTestDesign")
# 220707-14:53:45,7 nipype.workflow INFO:
# 	 [Node] Finished "l2analysis.onesampttestdes".
# 220707-14:53:45,9 nipype.workflow INFO:
# 	 [Node] Setting-up "l2analysis.level2estimate" in "/fmriNASTest/data00/projects/geoscan_v2/data/bids_data/working/nipype/task-image_model-condition-hp160/l2analysis/_contrast_name_retail_nonsmoke_promo/level2estimate".
# 220707-14:53:45,25 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "l2analysis.level2estimate".
# 220707-14:53:45,430 nipype.workflow INFO:
# 	 [Node] Running "level2estimate" ("nipype.interfaces.spm.model.EstimateModel")
# 220707-14:54:12,601 nipype.workflow INFO:
# 	 [Node] Finished "l2analysis.level2estimate".
# 220707-14:54:12,604 nipype.workflow INFO:
# 	 [Node] Setting-up "l2analysis.level2conestimate" in "/fmriNASTest/data00/projects/geoscan_v2/data/bids_data/working/nipype/task-image_model-condition-hp160/l2analysis/_contrast_name_retail_nonsmoke_promo/level2conestimate".
# 220707-14:54:12,625 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "l2analysis.level2conestimate".
# 220707-14:54:13,71 nipype.workflow INFO:
# 	 [Node] Running "level2conestimate" ("nipype.interfaces.spm.model.EstimateContrast")
# 220707-14:54:31,337 nipype.workflow INFO:
# 	 [Node] Finished "l2analysis.level2conestimate".
# 220707-14:54:31,340 nipype.workflow INFO:
# 	 [Node] Setting-up "l2analysis.datasink" in "/fmriNASTest/data00/projects/geoscan_v2/data/bids_data/working/nipype/task-image_model-condition-hp160/l2analysis/_contrast_name_retail_nonsmoke_promo/datasink".
# 220707-14:54:31,368 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "l2analysis.datasink".
# 220707-14:54:31,653 nipype.workflow INFO:
# 	 [Node] Running "datasink" ("nipype.interfaces.io.DataSink")
# 220707-14:54:31,657 nipype.interface INFO:
# 	 sub: /data00/projects/geoscan_v2/data/bids_data/derivatives/nipype/task-image_model-condition-hp160/l2analysis/_contrast_name_retail_nonsmoke_promo/SPM.mat -> /data00/projects/geoscan_v2/data/bids_data/derivatives/nipype/task-image_model-condition-hp160/l2analysis/retail_nonsmoke_promo/SPM.mat
# 220707-14:54:31,756 nipype.interface INFO:
# 	 sub: /data00/projects/geoscan_v2/data/bids_data/derivatives/nipype/task-image_model-condition-hp160/l2analysis/_contrast_name_retail_nonsmoke_promo/spmT_0001.nii -> /data00/projects/geoscan_v2/data/bids_data/derivatives/nipype/task-image_model-condition-hp160/l2analysis/retail_nonsmoke_promo/spmT_0001.nii
# 220707-14:54:31,918 nipype.interface INFO:
# 	 sub: /data00/projects/geoscan_v2/data/bids_data/derivatives/nipype/task-image_model-condition-hp160/l2analysis/_contrast_name_retail_nonsmoke_promo/con_0001.nii -> /data00/projects/geoscan_v2/data/bids_data/derivatives/nipype/task-image_model-condition-hp160/l2analysis/retail_nonsmoke_promo/con_0001.nii
# 220707-14:54:32,81 nipype.workflow INFO:
# 	 [Node] Finished "l2analysis.datasink".
# 220707-14:54:32,82 nipype.workflow INFO:
# 	 ***********************************
# 220707-14:54:32,84 nipype.workflow ERROR:
# 	 could not run node: l2analysis.onesampttestdes.a04
# 220707-14:54:32,85 nipype.workflow INFO:
# 	 crashfile: /fmriNASTest/data00/projects/geoscan_v2/scripts/L2/crash-20220707-145113-aresnick@asc.upenn.edu-onesampttestdes.a04-5e0c9268-6cc7-47e8-b2c2-8d1fda9b0301.pklz
# 220707-14:54:32,85 nipype.workflow ERROR:
# 	 could not run node: l2analysis.onesampttestdes.a02
# 220707-14:54:32,86 nipype.workflow INFO:
# 	 crashfile: /fmriNASTest/data00/projects/geoscan_v2/scripts/L2/crash-20220707-145218-aresnick@asc.upenn.edu-onesampttestdes.a02-dff25864-2046-418c-a116-f6e950808a66.pklz
# 220707-14:54:32,87 nipype.workflow INFO:
# 	 ***********************************
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-36-d3feb9433041> in <module>
#      49                    ])
#      50
# ---> 51 l2analysis.run()
#
# /usr/local/anaconda3/lib/python3.7/site-packages/nipype/pipeline/engine/workflows.py in run(self, plugin, plugin_args, updatehash)
#     630         if str2bool(self.config["execution"]["create_report"]):
#     631             self._write_report_info(self.base_dir, self.name, execgraph)
# --> 632         runner.run(execgraph, updatehash=updatehash, config=self.config)
#     633         datestr = datetime.utcnow().strftime("%Y%m%dT%H%M%S")
#     634         if str2bool(self.config["execution"]["write_provenance"]):
#
# /usr/local/anaconda3/lib/python3.7/site-packages/nipype/pipeline/plugins/linear.py in run(self, graph, config, updatehash)
#      68
#      69         os.chdir(old_wd)  # Return wherever we were before
# ---> 70         report_nodes_not_run(notrun)
#
# /usr/local/anaconda3/lib/python3.7/site-packages/nipype/pipeline/plugins/tools.py in report_nodes_not_run(notrun)
#      96         logger.info("***********************************")
#      97         raise RuntimeError(
# ---> 98             ("Workflow did not execute cleanly. " "Check log for details")
#      99         )
#     100
#
# RuntimeError: Workflow did not execute cleanly. Check log for details

# %%
p_val = 0.0001
p001_uncorrected = sp.stats.norm.isf(p_val)

for con_folder in glob.glob(os.path.join(l2analysis_path, "*")):
    if not os.path.isdir(con_folder):
        continue
    
    con_name = os.path.basename(con_folder)
    t_map = os.path.join(con_folder, "spmT_0001.nii")
    
    if not os.path.exists(t_map):
        continue
    
    plotting.plot_stat_map(
        t_map, threshold=p001_uncorrected, colorbar=True, display_mode='z',
        title=f'{con_name} (uncorr p < 0.0001)')
    
    plotting.show()

# %%
#!nipypecli crash /fmriMURI/scripts/jupyterhub_users/CNLab/second_level_models/cuereact/crash-20210223-123628-dcosme@asc.upenn.edu-onesampttestdes.a9-d958e803-b1a5-48c7-8126-672179cd7f12.pklz
